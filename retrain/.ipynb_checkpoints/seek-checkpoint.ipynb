# %%
import argparse
from SoccerNet.utils import getListGames
import os
import json
from tqdm import tqdm
import numpy as np

# %%
parser = argparse.ArgumentParser()
# parser.add_argument("--anno_file",default='')
parser.add_argument("--source_test_path",default='/youtu_pedestrian_detection/chengzhilin/program/soccernet/models/MVIT_WIN5/outputs_test')#输入test文件夹 
parser.add_argument("--source_test_path",default='/youtu_pedestrian_detection/chengzhilin/program/soccernet/process/test')  #筛选后test文件夹

parser.add_argument("--source_challenge_path",default='/youtu_pedestrian_detection/chengzhilin/program/soccernet/models/MVIT_WIN5/outputs_challenge')#输入challenge文件夹 
parser.add_argument("--output_challenge_path", default="/youtu_pedestrian_detection/chengzhilin/program/soccernet/process/challenge")  #输出challenge文件夹
parser.add_argument('--window_start', type=int,   default=4,     help='Size of the chunk (in seconds)' )
parser.add_argument('--window_end', type=int,   default=6,     help='Size of the chunk (in seconds)' )
parser.add_argument('--window_gap',  type=int,   default=0.5,     help='Size of the chunk (in seconds)' )

args=parser.parse_args([])

# %%
os.makedirs(args.output_challenge_path,exist_ok='True')

# %%
window_size=5

# %%
for cata in getListGames(split="test"):

    
    
    
    file=os.path.join(args.source_test_path,cata,'results_spotting.json')
    with open(file,'r') as f:
        data=json.load(f)
    pres=data['predictions']
    
    json_data = {} 
    total_pre={}
    json_data["UrlLocal"]=data['UrlLocal']
    json_data["predictions"]=[]
    
    
    start,end=0,window_size
    window=[]
    for pre in pres:
        if start<= int(pre['position'])/1000.0 <end:
            window.append(pre)
        else:
            json_data["predictions"]+=window
            window=[]
    
    os.makedirs(os.path.join(args.output_challenge_path,cata),exist_ok='True')
    with open(os.path.join(args.output_challenge_path,cata,'results_spotting.json'),'w') as f:
        json.dump(json_data,f,indent=2)
    
    
    break

# %%
int(pre['position'])/1000.0
# Out:
# 721.268

# %%
data
# Out:
# {'UrlLocal': 'england_epl/2014-2015/2015-05-17 - 18-00 Manchester United 1 - 1 Arsenal',
#  'predictions': [{'gameTime': '1 - 14:16',
#    'label': 'Penalty',
#    'position': '856474',
#    'half': '1',
#    'confidence': '0.006846137344837189'},
#   {'gameTime': '1 - 1:45',
#    'label': 'Penalty',
#    'position': '105564',
#    'half': '1',
#    'confidence': '0.0015244742389768362'},
#   {'gameTime': '1 - 29:20',
#    'label': 'Penalty',
#    'position': '1760270',
#    'half': '1',
#    'confidence': '0.0011110763298347592'},
#   {'gameTime': '1 - 23:31',
#    'label': 'Penalty',
#    'position': '1411336',
#    'half': '1',
#    'confidence': '0.0006935555720701814'},
#   {'gameTime': '1 - 35:0',
#    'label': 'Penalty',
#    'position': '2100884',
#    'half': '1',
#    'confidence': '0.0006670397706329823'},
#   {'gameTime': '1 - 11:22',
#    'label': 'Penalty',
#    'position': '682787',
#    'half': '1',
#    'confidence': '0.0006399552221409976'},
#   {'gameTime': '1 - 39:29',
#    'label': 'Penalty',
#    'position': '2369214',
#    'half': '1',
#    'confidence': '0.0006146698724478483'},
#   {'gameTime': '1 - 1:21',
#    'label': 'Penalty',
#    'position': '81643',
#    'half': '1',
#    'confidence': '0.00026217332924716175'},
#   {'gameTime': '1 - 9:19',
#    'label': 'Penalty',
#    'position': '559542',
#    'half': '1',
#    'confidence': '0.0002607161004561931'},
#   {'gameTime': '1 - 15:42',
#    'label': 'Penalty',
#    'position': '942797',
#    'half': '1',
#    'confidence': '0.00023109978064894676'},
#   {'gameTime': '1 - 9:42',
#    'label': 'Penalty',
#    'position': '582943',
#    'half': '1',
#    'confidence': '0.0002201692695962265'},
#   {'gameTime': '1 - 5:21',
#    'label': 'Penalty',
#    'position': '321892',
#    'half': '1',
#    'confidence': '0.00021712335001211613'},
#   {'gameTime': '1 - 3:54',
#    'label': 'Penalty',
#    'position': '234529',
#    'half': '1',
#    'confidence': '0.00021032981749158353'},
#   {'gameTime': '1 - 40:56',
#    'label': 'Penalty',
#    'position': '2456578',
#    'half': '1',
#    'confidence': '0.00017056186334230006'},
#   {'gameTime': '1 - 8:8',
#    'label': 'Penalty',
#    'position': '488819',
#    'half': '1',
#    'confidence': '0.0001658522232901305'},
#   {'gameTime': '1 - 44:46',
#    'label': 'Penalty',
#    'position': '2686427',
#    'half': '1',
#    'confidence': '0.00015481443551834673'},
#   {'gameTime': '1 - 26:31',
#    'label': 'Penalty',
#    'position': '1591783',
#    'half': '1',
#    'confidence': '0.00012810734915547073'},
#   {'gameTime': '1 - 28:15',
#    'label': 'Penalty',
#    'position': '1695787',
#    'half': '1',
#    'confidence': '9.111769031733274e-05'},
#   {'gameTime': '1 - 16:22',
#    'label': 'Penalty',
#    'position': '982839',
#    'half': '1',
#    'confidence': '7.905145321274176e-05'},
#   {'gameTime': '1 - 41:35',
#    'label': 'Penalty',
#    'position': '2495059',
#    'half': '1',
#    'confidence': '6.409495836123824e-05'},
#   {'gameTime': '1 - 38:10',
#    'label': 'Penalty',
#    'position': '2290171',
#    'half': '1',
#    'confidence': '5.4397205531131476e-05'},
#   {'gameTime': '1 - 40:31',
#    'label': 'Penalty',
#    'position': '2431097',
#    'half': '1',
#    'confidence': '4.574222111841664e-05'},
#   {'gameTime': '1 - 19:57',
#    'label': 'Penalty',
#    'position': '1197607',
#    'half': '1',
#    'confidence': '3.9984228351386264e-05'},
#   {'gameTime': '1 - 6:15',
#    'label': 'Penalty',
#    'position': '375975',
#    'half': '1',
#    'confidence': '3.952312545152381e-05'},
#   {'gameTime': '1 - 34:23',
#    'label': 'Penalty',
#    'position': '2063962',
#    'half': '1',
#    'confidence': '3.459355502855033e-05'},
#   {'gameTime': '1 - 44:12',
#    'label': 'Penalty',
#    'position': '2652106',
#    'half': '1',
#    'confidence': '3.359121910762042e-05'},
#   {'gameTime': '1 - 25:59',
#    'label': 'Penalty',
#    'position': '1559022',
#    'half': '1',
#    'confidence': '2.507745193724986e-05'},
#   {'gameTime': '1 - 20:32',
#    'label': 'Penalty',
#    'position': '1232449',
#    'half': '1',
#    'confidence': '2.4249635316664353e-05'},
#   {'gameTime': '1 - 19:39',
#    'label': 'Penalty',
#    'position': '1179927',
#    'half': '1',
#    'confidence': '2.302145367139019e-05'},
#   {'gameTime': '1 - 37:34',
#    'label': 'Penalty',
#    'position': '2254290',
#    'half': '1',
#    'confidence': '2.1296254999469966e-05'},
#   {'gameTime': '1 - 38:30',
#    'label': 'Penalty',
#    'position': '2310452',
#    'half': '1',
#    'confidence': '1.910197352117393e-05'},
#   {'gameTime': '1 - 35:53',
#    'label': 'Penalty',
#    'position': '2153926',
#    'half': '1',
#    'confidence': '1.9088207409367897e-05'},
#   {'gameTime': '1 - 5:36',
#    'label': 'Penalty',
#    'position': '336453',
#    'half': '1',
#    'confidence': '1.7221009329659864e-05'},
#   {'gameTime': '1 - 13:17',
#    'label': 'Penalty',
#    'position': '797711',
#    'half': '1',
#    'confidence': '1.503171370131895e-05'},
#   {'gameTime': '1 - 13:46',
#    'label': 'Penalty',
#    'position': '826833',
#    'half': '1',
#    'confidence': '1.4186437510943506e-05'},
#   {'gameTime': '1 - 5:58',
#    'label': 'Penalty',
#    'position': '358294',
#    'half': '1',
#    'confidence': '1.369915025861701e-05'},
#   {'gameTime': '1 - 43:33',
#    'label': 'Penalty',
#    'position': '2613624',
#    'half': '1',
#    'confidence': '1.3588850379164796e-05'},
#   {'gameTime': '1 - 32:12',
#    'label': 'Penalty',
#    'position': '1932917',
#    'half': '1',
#    'confidence': '1.3441621376841795e-05'},
#   {'gameTime': '1 - 35:32',
#    'label': 'Penalty',
#    'position': '2132085',
#    'half': '1',
#    'confidence': '1.3093962479615584e-05'},
#   {'gameTime': '1 - 4:13',
#    'label': 'Penalty',
#    'position': '253770',
#    'half': '1',
#    'confidence': '1.258158044947777e-05'},
#   {'gameTime': '1 - 29:51',
#    'label': 'Penalty',
#    'position': '1791471',
#    'half': '1',
#    'confidence': '1.2444681487977505e-05'},
#   {'gameTime': '1 - 21:11',
#    'label': 'Penalty',
#    'position': '1271450',
#    'half': '1',
#    'confidence': '1.1246396752540022e-05'},
#   {'gameTime': '1 - 22:43',
#    'label': 'Penalty',
#    'position': '1363494',
#    'half': '1',
#    'confidence': '1.0647088856785558e-05'},
#   {'gameTime': '1 - 30:7',
#    'label': 'Penalty',
#    'position': '1807072',
#    'half': '1',
#    'confidence': '9.968386621039826e-06'},
#   {'gameTime': '1 - 17:32',
#    'label': 'Penalty',
#    'position': '1052002',
#    'half': '1',
#    'confidence': '9.342513294541277e-06'},
#   {'gameTime': '1 - 39:57',
#    'label': 'Penalty',
#    'position': '2397295',
#    'half': '1',
#    'confidence': '8.966480891103856e-06'},
#   {'gameTime': '1 - 34:39',
#    'label': 'Penalty',
#    'position': '2079043',
#    'half': '1',
#    'confidence': '7.488121354981558e-06'},
#   {'gameTime': '1 - 10:43',
#    'label': 'Penalty',
#    'position': '643265',
#    'half': '1',
#    'confidence': '7.447982625308214e-06'},
#   {'gameTime': '1 - 30:27',
#    'label': 'Penalty',
#    'position': '1827353',
#    'half': '1',
#    'confidence': '7.3791761678876355e-06'},
#   {'gameTime': '1 - 24:10',
#    'label': 'Penalty',
#    'position': '1450338',
#    'half': '1',
#    'confidence': '6.646652764175087e-06'},
#   {'gameTime': '1 - 25:30',
#    'label': 'Penalty',
#    'position': '1530941',
#    'half': '1',
#    'confidence': '6.135233434179099e-06'},
#   {'gameTime': '1 - 33:30',
#    'label': 'Penalty',
#    'position': '2010400',
#    'half': '1',
#    'confidence': '5.932918611506466e-06'},
#   {'gameTime': '1 - 34:8',
#    'label': 'Penalty',
#    'position': '2048361',
#    'half': '1',
#    'confidence': '5.625093763228506e-06'},
#   {'gameTime': '1 - 42:1',
#    'label': 'Penalty',
#    'position': '2521580',
#    'half': '1',
#    'confidence': '5.153246547706658e-06'},
#   {'gameTime': '1 - 17:8',
#    'label': 'Penalty',
#    'position': '1028601',
#    'half': '1',
#    'confidence': '4.2976043914677575e-06'},
#   {'gameTime': '1 - 26:46',
#    'label': 'Penalty',
#    'position': '1606344',
#    'half': '1',
#    'confidence': '4.111650468985317e-06'},
#   {'gameTime': '1 - 21:26',
#    'label': 'Penalty',
#    'position': '1286011',
#    'half': '1',
#    'confidence': '4.075551260029897e-06'},
#   {'gameTime': '1 - 31:55',
#    'label': 'Penalty',
#    'position': '1915756',
#    'half': '1',
#    'confidence': '3.916938567272155e-06'},
#   {'gameTime': '1 - 18:9',
#    'label': 'Penalty',
#    'position': '1089443',
#    'half': '1',
#    'confidence': '3.887476395902922e-06'},
#   {'gameTime': '1 - 28:37',
#    'label': 'Penalty',
#    'position': '1717108',
#    'half': '1',
#    'confidence': '3.861596269416623e-06'},
#   {'gameTime': '1 - 33:45',
#    'label': 'Penalty',
#    'position': '2025481',
#    'half': '1',
#    'confidence': '3.6488938803813653e-06'},
#   {'gameTime': '1 - 41:18',
#    'label': 'Penalty',
#    'position': '2478419',
#    'half': '1',
#    'confidence': '3.5223577015131013e-06'},
#   {'gameTime': '1 - 21:46',
#    'label': 'Penalty',
#    'position': '1306292',
#    'half': '1',
#    'confidence': '3.4798113119904883e-06'},
#   {'gameTime': '1 - 36:38',
#    'label': 'Penalty',
#    'position': '2198647',
#    'half': '1',
#    'confidence': '3.382047452760162e-06'},
#   {'gameTime': '1 - 7:48',
#    'label': 'Penalty',
#    'position': '468018',
#    'half': '1',
#    'confidence': '3.0268301998148672e-06'},
#   {'gameTime': '1 - 5:6',
#    'label': 'Penalty',
#    'position': '306292',
#    'half': '1',
#    'confidence': '2.7916216822632123e-06'},
#   {'gameTime': '1 - 11:7',
#    'label': 'Penalty',
#    'position': '667186',
#    'half': '1',
#    'confidence': '2.6499724299355876e-06'},
#   {'gameTime': '1 - 9:3',
#    'label': 'Penalty',
#    'position': '543941',
#    'half': '1',
#    'confidence': '2.6226664431305835e-06'},
#   {'gameTime': '1 - 22:58',
#    'label': 'Penalty',
#    'position': '1378055',
#    'half': '1',
#    'confidence': '2.5294418719568057e-06'},
#   {'gameTime': '1 - 4:42',
#    'label': 'Penalty',
#    'position': '282891',
#    'half': '1',
#    'confidence': '2.3841766960686073e-06'},
#   {'gameTime': '1 - 27:48',
#    'label': 'Penalty',
#    'position': '1668746',
#    'half': '1',
#    'confidence': '2.345197572140023e-06'},
#   {'gameTime': '1 - 30:47',
#    'label': 'Penalty',
#    'position': '1847633',
#    'half': '1',
#    'confidence': '2.1436253518913873e-06'},
#   {'gameTime': '1 - 36:21',
#    'label': 'Penalty',
#    'position': '2181487',
#    'half': '1',
#    'confidence': '2.0048969417985063e-06'},
#   {'gameTime': '1 - 42:18',
#    'label': 'Penalty',
#    'position': '2538221',
#    'half': '1',
#    'confidence': '1.9507976958266227e-06'},
#   {'gameTime': '1 - 6:48',
#    'label': 'Penalty',
#    'position': '408216',
#    'half': '1',
#    'confidence': '1.9326432720845332e-06'},
#   {'gameTime': '1 - 42:36',
#    'label': 'Penalty',
#    'position': '2556422',
#    'half': '1',
#    'confidence': '1.9179508399247425e-06'},
#   {'gameTime': '1 - 43:6',
#    'label': 'Penalty',
#    'position': '2586063',
#    'half': '1',
#    'confidence': '1.915961775011965e-06'},
#   {'gameTime': '1 - 0:49',
#    'label': 'Penalty',
#    'position': '49401',
#    'half': '1',
#    'confidence': '1.7866428834167891e-06'},
#   {'gameTime': '1 - 32:27',
#    'label': 'Penalty',
#    'position': '1947997',
#    'half': '1',
#    'confidence': '1.6853056195031968e-06'},
#   {'gameTime': '1 - 8:44',
#    'label': 'Penalty',
#    'position': '524700',
#    'half': '1',
#    'confidence': '1.4972005146773881e-06'},
#   {'gameTime': '1 - 28:59',
#    'label': 'Penalty',
#    'position': '1739989',
#    'half': '1',
#    'confidence': '1.4790507520956453e-06'},
#   {'gameTime': '1 - 37:50',
#    'label': 'Penalty',
#    'position': '2270930',
#    'half': '1',
#    'confidence': '1.3700657746085199e-06'},
#   {'gameTime': '1 - 16:41',
#    'label': 'Penalty',
#    'position': '1001560',
#    'half': '1',
#    'confidence': '1.356179495815013e-06'},
#   {'gameTime': '1 - 12:56',
#    'label': 'Penalty',
#    'position': '776911',
#    'half': '1',
#    'confidence': '1.3466643622450647e-06'},
#   {'gameTime': '1 - 17:48',
#    'label': 'Penalty',
#    'position': '1068642',
#    'half': '1',
#    'confidence': '1.3101167724016705e-06'},
#   {'gameTime': '1 - 19:1',
#    'label': 'Penalty',
#    'position': '1141965',
#    'half': '1',
#    'confidence': '1.1971452522629988e-06'},
#   {'gameTime': '1 - 25:2',
#    'label': 'Penalty',
#    'position': '1502340',
#    'half': '1',
#    'confidence': '1.1116666200905456e-06'},
#   {'gameTime': '1 - 33:12',
#    'label': 'Penalty',
#    'position': '1992199',
#    'half': '1',
#    'confidence': '1.11045437733992e-06'},
#   {'gameTime': '1 - 12:11',
#    'label': 'Penalty',
#    'position': '731669',
#    'half': '1',
#    'confidence': '1.0901474070124095e-06'},
#   {'gameTime': '1 - 29:34',
#    'label': 'Penalty',
#    'position': '1774830',
#    'half': '1',
#    'confidence': '1.044776468006603e-06'},
#   {'gameTime': '1 - 31:19',
#    'label': 'Penalty',
#    'position': '1879355',
#    'half': '1',
#    'confidence': '8.027275271160761e-07'},
#   {'gameTime': '1 - 2:43',
#    'label': 'Penalty',
#    'position': '163806',
#    'half': '1',
#    'confidence': '7.713662171227043e-07'},
#   {'gameTime': '1 - 11:37',
#    'label': 'Penalty',
#    'position': '697867',
#    'half': '1',
#    'confidence': '7.038436251605162e-07'},
#   {'gameTime': '1 - 7:5',
#    'label': 'Penalty',
#    'position': '425897',
#    'half': '1',
#    'confidence': '7.032558642094955e-07'},
#   {'gameTime': '1 - 27:6',
#    'label': 'Penalty',
#    'position': '1626625',
#    'half': '1',
#    'confidence': '6.73763963732199e-07'},
#   {'gameTime': '1 - 20:12',
#    'label': 'Penalty',
#    'position': '1212168',
#    'half': '1',
#    'confidence': '6.553515277119004e-07'},
#   {'gameTime': '1 - 15:1',
#    'label': 'Penalty',
#    'position': '901196',
#    'half': '1',
#    'confidence': '6.355229515975225e-07'},
#   {'gameTime': '1 - 27:25',
#    'label': 'Penalty',
#    'position': '1645345',
#    'half': '1',
#    'confidence': '5.882152436242905e-07'},
#   {'gameTime': '1 - 37:15',
#    'label': 'Penalty',
#    'position': '2235569',
#    'half': '1',
#    'confidence': '5.734565888815268e-07'},
#   {'gameTime': '1 - 3:9',
#    'label': 'Penalty',
#    'position': '189287',
#    'half': '1',
#    'confidence': '5.019396098759898e-07'},
#   {'gameTime': '1 - 12:27',
#    'label': 'Penalty',
#    'position': '747269',
#    'half': '1',
#    'confidence': '4.936325694870902e-07'},
#   {'gameTime': '1 - 44:26',
#    'label': 'Penalty',
#    'position': '2666666',
#    'half': '1',
#    'confidence': '4.883014526058105e-07'},
#   {'gameTime': '1 - 14:33',
#    'label': 'Penalty',
#    'position': '873634',
#    'half': '1',
#    'confidence': '4.773385171574773e-07'},
#   {'gameTime': '1 - 23:48',
#    'label': 'Penalty',
#    'position': '1428497',
#    'half': '1',
#    'confidence': '4.266273094799544e-07'},
#   {'gameTime': '1 - 8:24',
#    'label': 'Penalty',
#    'position': '504420',
#    'half': '1',
#    'confidence': '3.652256168606982e-07'},
#   {'gameTime': '1 - 0:7',
#    'label': 'Penalty',
#    'position': '7280',
#    'half': '1',
#    'confidence': '3.5695987321560096e-07'},
#   {'gameTime': '1 - 20:51',
#    'label': 'Penalty',
#    'position': '1251690',
#    'half': '1',
#    'confidence': '3.2694592277948686e-07'},
#   {'gameTime': '1 - 35:15',
#    'label': 'Penalty',
#    'position': '2115444',
#    'half': '1',
#    'confidence': '3.2486352097294e-07'},
#   {'gameTime': '1 - 15:22',
#    'label': 'Penalty',
#    'position': '922516',
#    'half': '1',
#    'confidence': '3.1687596901974757e-07'},
#   {'gameTime': '1 - 10:2',
#    'label': 'Penalty',
#    'position': '602704',
#    'half': '1',
#    'confidence': '3.099677030604653e-07'},
#   {'gameTime': '1 - 38:50',
#    'label': 'Penalty',
#    'position': '2330213',
#    'half': '1',
#    'confidence': '2.377645813567142e-07'},
#   {'gameTime': '1 - 10:24',
#    'label': 'Penalty',
#    'position': '624544',
#    'half': '1',
#    'confidence': '2.1295301166901481e-07'},
#   {'gameTime': '1 - 6:31',
#    'label': 'Penalty',
#    'position': '391055',
#    'half': '1',
#    'confidence': '2.0499209085755865e-07'},
#   {'gameTime': '1 - 0:22',
#    'label': 'Penalty',
#    'position': '22880',
#    'half': '1',
#    'confidence': '1.8243747490487294e-07'},
#   {'gameTime': '1 - 16:2',
#    'label': 'Penalty',
#    'position': '962038',
#    'half': '1',
#    'confidence': '1.7458199863540358e-07'},
#   {'gameTime': '1 - 18:28',
#    'label': 'Penalty',
#    'position': '1108164',
#    'half': '1',
#    'confidence': '1.6675706149271718e-07'},
#   {'gameTime': '1 - 24:24',
#    'label': 'Penalty',
#    'position': '1464898',
#    'half': '1',
#    'confidence': '1.6399835089941917e-07'},
#   {'gameTime': '1 - 19:24',
#    'label': 'Penalty',
#    'position': '1164326',
#    'half': '1',
#    'confidence': '1.1587322745754136e-07'},
#   {'gameTime': '1 - 3:37',
#    'label': 'Penalty',
#    'position': '217888',
#    'half': '1',
#    'confidence': '1.1533499844063044e-07'},
#   {'gameTime': '1 - 31:2',
#    'label': 'Penalty',
#    'position': '1862194',
#    'half': '1',
#    'confidence': '1.0914523329574877e-07'},
#   {'gameTime': '1 - 18:43',
#    'label': 'Penalty',
#    'position': '1123764',
#    'half': '1',
#    'confidence': '1.0567366359737207e-07'},
#   {'gameTime': '1 - 32:45',
#    'label': 'Penalty',
#    'position': '1965158',
#    'half': '1',
#    'confidence': '1.0244431081218863e-07'},
#   {'gameTime': '1 - 36:56',
#    'label': 'Penalty',
#    'position': '2216328',
#    'half': '1',
#    'confidence': '1.0175434539405614e-07'},
#   {'gameTime': '1 - 2:12',
#    'label': 'Penalty',
#    'position': '132085',
#    'half': '1',
#    'confidence': '8.509016424795846e-08'},
#   {'gameTime': '1 - 22:9',
#    'label': 'Penalty',
#    'position': '1329693',
#    'half': '1',
#    'confidence': '6.796594220759289e-08'},
#   {'gameTime': '1 - 43:48',
#    'label': 'Penalty',
#    'position': '2628185',
#    'half': '1',
#    'confidence': '5.804936975550845e-08'},
#   {'gameTime': '1 - 23:15',
#    'label': 'Penalty',
#    'position': '1395215',
#    'half': '1',
#    'confidence': '5.797820890052208e-08'},
#   {'gameTime': '1 - 39:4',
#    'label': 'Penalty',
#    'position': '2344773',
#    'half': '1',
#    'confidence': '5.388703172570786e-08'},
#   {'gameTime': '1 - 11:52',
#    'label': 'Penalty',
#    'position': '712948',
#    'half': '1',
#    'confidence': '5.291082416647441e-08'},
#   {'gameTime': '1 - 7:28',
#    'label': 'Penalty',
#    'position': '448777',
#    'half': '1',
#    'confidence': '4.822605248477885e-08'},
#   {'gameTime': '1 - 24:39',
#    'label': 'Penalty',
#    'position': '1479459',
#    'half': '1',
#    'confidence': '4.121021390801616e-08'},
#   {'gameTime': '1 - 31:40',
#    'label': 'Penalty',
#    'position': '1900156',
#    'half': '1',
#    'confidence': '2.6992371005007953e-08'},
#   {'gameTime': '1 - 40:14',
#    'label': 'Penalty',
#    'position': '2414976',
#    'half': '1',
#    'confidence': '2.0753322615973957e-08'},
#   {'gameTime': '1 - 22:27',
#    'label': 'Penalty',
#    'position': '1347893',
#    'half': '1',
#    'confidence': '2.0212535645214302e-08'},
#   {'gameTime': '1 - 26:13',
#    'label': 'Penalty',
#    'position': '1573582',
#    'half': '1',
#    'confidence': '1.548499106718282e-08'},
#   {'gameTime': '1 - 1:3',
#    'label': 'Penalty',
#    'position': '63962',
#    'half': '1',
#    'confidence': '1.2838928142855366e-08'},
#   {'gameTime': '1 - 2:26',
#    'label': 'Penalty',
#    'position': '146645',
#    'half': '1',
#    'confidence': '3.837588025135119e-09'},
#   {'gameTime': '1 - 0:3',
#    'label': 'Kick-off',
#    'position': '3640',
#    'half': '1',
#    'confidence': '0.8227239847183228'},
#   {'gameTime': '1 - 34:32',
#    'label': 'Kick-off',
#    'position': '2072282',
#    'half': '1',
#    'confidence': '0.629787266254425'},
#   {'gameTime': '1 - 30:32',
#    'label': 'Kick-off',
#    'position': '1832553',
#    'half': '1',
#    'confidence': '0.563677191734314'},
#   {'gameTime': '1 - 30:10',
#    'label': 'Kick-off',
#    'position': '1810712',
#    'half': '1',
#    'confidence': '0.17333339154720306'},
#   {'gameTime': '1 - 40:48',
#    'label': 'Kick-off',
#    'position': '2448257',
#    'half': '1',
#    'confidence': '0.1327262818813324'},
#   {'gameTime': '1 - 37:51',
#    'label': 'Kick-off',
#    'position': '2271450',
#    'half': '1',
#    'confidence': '0.1071808859705925'},
#   {'gameTime': '1 - 29:51',
#    'label': 'Kick-off',
#    'position': '1791471',
#    'half': '1',
#    'confidence': '0.025893084704875946'},
#   {'gameTime': '1 - 29:23',
#    'label': 'Kick-off',
#    'position': '1763390',
#    'half': '1',
#    'confidence': '0.023289820179343224'},
#   {'gameTime': '1 - 32:20',
#    'label': 'Kick-off',
#    'position': '1940717',
#    'half': '1',
#    'confidence': '0.017049934715032578'},
#   {'gameTime': '1 - 17:11',
#    'label': 'Kick-off',
#    'position': '1031201',
#    'half': '1',
#    'confidence': '0.016889099031686783'},
#   {'gameTime': '1 - 1:48',
#    'label': 'Kick-off',
#    'position': '108164',
#    'half': '1',
#    'confidence': '0.016105707734823227'},
#   {'gameTime': '1 - 34:47',
#    'label': 'Kick-off',
#    'position': '2087363',
#    'half': '1',
#    'confidence': '0.015975814312696457'},
#   {'gameTime': '1 - 21:46',
#    'label': 'Kick-off',
#    'position': '1306812',
#    'half': '1',
#    'confidence': '0.01215140987187624'},
#   {'gameTime': '1 - 8:57',
#    'label': 'Kick-off',
#    'position': '537701',
#    'half': '1',
#    'confidence': '0.010846549645066261'},
#   {'gameTime': '1 - 36:35',
#    'label': 'Kick-off',
#    'position': '2195527',
#    'half': '1',
#    'confidence': '0.010215315967798233'},
#   {'gameTime': '1 - 21:31',
#    'label': 'Kick-off',
#    'position': '1291211',
#    'half': '1',
#    'confidence': '0.01012840773910284'},
#   {'gameTime': '1 - 13:30',
#    'label': 'Kick-off',
#    'position': '810192',
#    'half': '1',
#    'confidence': '0.009231092408299446'},
#   {'gameTime': '1 - 25:51',
#    'label': 'Kick-off',
#    'position': '1551222',
#    'half': '1',
#    'confidence': '0.008768356405198574'},
#   {'gameTime': '1 - 10:21',
#    'label': 'Kick-off',
#    'position': '621944',
#    'half': '1',
#    'confidence': '0.008733829483389854'},
#   {'gameTime': '1 - 5:44',
#    'label': 'Kick-off',
#    'position': '344253',
#    'half': '1',
#    'confidence': '0.008678598329424858'},
#   {'gameTime': '1 - 1:28',
#    'label': 'Kick-off',
#    'position': '88403',
#    'half': '1',
#    'confidence': '0.008590775541961193'},
#   {'gameTime': '1 - 37:12',
#    'label': 'Kick-off',
#    'position': '2232449',
#    'half': '1',
#    'confidence': '0.008585833944380283'},
#   {'gameTime': '1 - 38:23',
#    'label': 'Kick-off',
#    'position': '2303692',
#    'half': '1',
#    'confidence': '0.008439830504357815'},
#   {'gameTime': '1 - 14:22',
#    'label': 'Kick-off',
#    'position': '862714',
#    'half': '1',
#    'confidence': '0.008417521603405476'},
#   {'gameTime': '1 - 26:7',
#    'label': 'Kick-off',
#    'position': '1567342',
#    'half': '1',
#    'confidence': '0.008370599709451199'},
#   {'gameTime': '1 - 41:9',
#    'label': 'Kick-off',
#    'position': '2469578',
#    'half': '1',
#    'confidence': '0.006670542526990175'},
#   {'gameTime': '1 - 26:21',
#    'label': 'Kick-off',
#    'position': '1581903',
#    'half': '1',
#    'confidence': '0.006417859811335802'},
#   {'gameTime': '1 - 9:33',
#    'label': 'Kick-off',
#    'position': '573062',
#    'half': '1',
#    'confidence': '0.005785392597317696'},
#   {'gameTime': '1 - 34:2',
#    'label': 'Kick-off',
#    'position': '2042121',
#    'half': '1',
#    'confidence': '0.005684868898242712'},
#   {'gameTime': '1 - 11:7',
#    'label': 'Kick-off',
#    'position': '667706',
#    'half': '1',
#    'confidence': '0.005298256874084473'},
#   {'gameTime': '1 - 29:7',
#    'label': 'Kick-off',
#    'position': '1747269',
#    'half': '1',
#    'confidence': '0.004964878316968679'},
#   {'gameTime': '1 - 39:31',
#    'label': 'Kick-off',
#    'position': '2371814',
#    'half': '1',
#    'confidence': '0.004683171398937702'},
#   {'gameTime': '1 - 5:25',
#    'label': 'Kick-off',
#    'position': '325013',
#    'half': '1',
#    'confidence': '0.004503646399825811'},
#   {'gameTime': '1 - 41:25',
#    'label': 'Kick-off',
#    'position': '2485699',
#    'half': '1',
#    'confidence': '0.0041840155608952045'},
#   {'gameTime': '1 - 28:40',
#    'label': 'Kick-off',
#    'position': '1720228',
#    'half': '1',
#    'confidence': '0.004044514615088701'},
#   {'gameTime': '1 - 16:55',
#    'label': 'Kick-off',
#    'position': '1015080',
#    'half': '1',
#    'confidence': '0.0037464171182364225'},
#   {'gameTime': '1 - 36:5',
#    'label': 'Kick-off',
#    'position': '2165366',
#    'half': '1',
#    'confidence': '0.003691013203933835'},
#   {'gameTime': '1 - 12:11',
#    'label': 'Kick-off',
#    'position': '731669',
#    'half': '1',
#    'confidence': '0.00357580604031682'},
#   {'gameTime': '1 - 44:47',
#    'label': 'Kick-off',
#    'position': '2687467',
#    'half': '1',
#    'confidence': '0.0033732042647898197'},
#   {'gameTime': '1 - 19:59',
#    'label': 'Kick-off',
#    'position': '1199167',
#    'half': '1',
#    'confidence': '0.003367007477208972'},
#   {'gameTime': '1 - 31:56',
#    'label': 'Kick-off',
#    'position': '1916276',
#    'half': '1',
#    'confidence': '0.003273556474596262'},
#   {'gameTime': '1 - 11:22',
#    'label': 'Kick-off',
#    'position': '682787',
#    'half': '1',
#    'confidence': '0.0031570664141327143'},
#   {'gameTime': '1 - 16:15',
#    'label': 'Kick-off',
#    'position': '975559',
#    'half': '1',
#    'confidence': '0.0030603851191699505'},
#   {'gameTime': '1 - 6:5',
#    'label': 'Kick-off',
#    'position': '365054',
#    'half': '1',
#    'confidence': '0.003030788851901889'},
#   {'gameTime': '1 - 19:1',
#    'label': 'Kick-off',
#    'position': '1141445',
#    'half': '1',
#    'confidence': '0.0029256967827677727'},
#   {'gameTime': '1 - 42:15',
#    'label': 'Kick-off',
#    'position': '2535101',
#    'half': '1',
#    'confidence': '0.0026359541807323694'},
#   {'gameTime': '1 - 24:24',
#    'label': 'Kick-off',
#    'position': '1464378',
#    'half': '1',
#    'confidence': '0.0022800355218350887'},
#   {'gameTime': '1 - 13:58',
#    'label': 'Kick-off',
#    'position': '838273',
#    'half': '1',
#    'confidence': '0.00217813509516418'},
#   {'gameTime': '1 - 15:53',
#    'label': 'Kick-off',
#    'position': '953198',
#    'half': '1',
#    'confidence': '0.0021771518513560295'},
#   {'gameTime': '1 - 35:2',
#    'label': 'Kick-off',
#    'position': '2102964',
#    'half': '1',
#    'confidence': '0.0019417374860495329'},
#   {'gameTime': '1 - 23:37',
#    'label': 'Kick-off',
#    'position': '1417056',
#    'half': '1',
#    'confidence': '0.001932341605424881'},
#   {'gameTime': '1 - 27:49',
#    'label': 'Kick-off',
#    'position': '1669786',
#    'half': '1',
#    'confidence': '0.0018806663574650884'},
#   {'gameTime': '1 - 20:57',
#    'label': 'Kick-off',
#    'position': '1257410',
#    'half': '1',
#    'confidence': '0.0017975567607209086'},
#   {'gameTime': '1 - 41:47',
#    'label': 'Kick-off',
#    'position': '2507540',
#    'half': '1',
#    'confidence': '0.001777368364855647'},
#   {'gameTime': '1 - 24:52',
#    'label': 'Kick-off',
#    'position': '1492979',
#    'half': '1',
#    'confidence': '0.0017125607701018453'},
#   {'gameTime': '1 - 5:8',
#    'label': 'Kick-off',
#    'position': '308372',
#    'half': '1',
#    'confidence': '0.0015293930191546679'},
#   {'gameTime': '1 - 3:24',
#    'label': 'Kick-off',
#    'position': '204888',
#    'half': '1',
#    'confidence': '0.0013225121656432748'},
#   {'gameTime': '1 - 43:23',
#    'label': 'Kick-off',
#    'position': '2603224',
#    'half': '1',
#    'confidence': '0.0013013564748689532'},
#   {'gameTime': '1 - 35:47',
#    'label': 'Kick-off',
#    'position': '2147685',
#    'half': '1',
#    'confidence': '0.0012880837311968207'},
#   {'gameTime': '1 - 42:59',
#    'label': 'Kick-off',
#    'position': '2579303',
#    'half': '1',
#    'confidence': '0.001269470783881843'},
#   {'gameTime': '1 - 4:16',
#    'label': 'Kick-off',
#    'position': '256370',
#    'half': '1',
#    'confidence': '0.0012398260878399014'},
#   {'gameTime': '1 - 15:22',
#    'label': 'Kick-off',
#    'position': '922516',
#    'half': '1',
#    'confidence': '0.0012281062081456184'},
#   {'gameTime': '1 - 28:18',
#    'label': 'Kick-off',
#    'position': '1698387',
#    'half': '1',
#    'confidence': '0.0011426650453358889'},
#   {'gameTime': '1 - 35:28',
#    'label': 'Kick-off',
#    'position': '2128965',
#    'half': '1',
#    'confidence': '0.001130438526161015'},
#   {'gameTime': '1 - 22:59',
#    'label': 'Kick-off',
#    'position': '1379615',
#    'half': '1',
#    'confidence': '0.001101760077290237'},
#   {'gameTime': '1 - 30:47',
#    'label': 'Kick-off',
#    'position': '1847633',
#    'half': '1',
#    'confidence': '0.0010126680135726929'},
#   {'gameTime': '1 - 37:35',
#    'label': 'Kick-off',
#    'position': '2255850',
#    'half': '1',
#    'confidence': '0.0009953409899026155'},
#   {'gameTime': '1 - 40:16',
#    'label': 'Kick-off',
#    'position': '2416016',
#    'half': '1',
#    'confidence': '0.0009647483821026981'},
#   {'gameTime': '1 - 3:45',
#    'label': 'Kick-off',
#    'position': '225689',
#    'half': '1',
#    'confidence': '0.0009419210837222636'},
#   {'gameTime': '1 - 23:56',
#    'label': 'Kick-off',
#    'position': '1436297',
#    'half': '1',
#    'confidence': '0.0009035221301019192'},
#   {'gameTime': '1 - 33:32',
#    'label': 'Kick-off',
#    'position': '2012480',
#    'half': '1',
#    'confidence': '0.0008739245240576565'},
#   {'gameTime': '1 - 17:32',
#    'label': 'Kick-off',
#    'position': '1052522',
#    'half': '1',
#    'confidence': '0.0008436550269834697'},
#   {'gameTime': '1 - 27:27',
#    'label': 'Kick-off',
#    'position': '1647425',
#    'half': '1',
#    'confidence': '0.0008210606756620109'},
#   {'gameTime': '1 - 7:1',
#    'label': 'Kick-off',
#    'position': '421216',
#    'half': '1',
#    'confidence': '0.000816616287920624'},
#   {'gameTime': '1 - 21:13',
#    'label': 'Kick-off',
#    'position': '1273530',
#    'half': '1',
#    'confidence': '0.0007731980876997113'},
#   {'gameTime': '1 - 11:45',
#    'label': 'Kick-off',
#    'position': '705668',
#    'half': '1',
#    'confidence': '0.00069490319583565'},
#   {'gameTime': '1 - 32:58',
#    'label': 'Kick-off',
#    'position': '1978679',
#    'half': '1',
#    'confidence': '0.0006912588141858578'},
#   {'gameTime': '1 - 22:39',
#    'label': 'Kick-off',
#    'position': '1359334',
#    'half': '1',
#    'confidence': '0.0006894788239151239'},
#   {'gameTime': '1 - 12:56',
#    'label': 'Kick-off',
#    'position': '776911',
#    'half': '1',
#    'confidence': '0.0006642569787800312'},
#   {'gameTime': '1 - 15:5',
#    'label': 'Kick-off',
#    'position': '905356',
#    'half': '1',
#    'confidence': '0.000663356448058039'},
#   {'gameTime': '1 - 8:33',
#    'label': 'Kick-off',
#    'position': '513260',
#    'half': '1',
#    'confidence': '0.0006571455160155892'},
#   {'gameTime': '1 - 27:9',
#    'label': 'Kick-off',
#    'position': '1629745',
#    'half': '1',
#    'confidence': '0.000656111107673496'},
#   {'gameTime': '1 - 44:12',
#    'label': 'Kick-off',
#    'position': '2652106',
#    'half': '1',
#    'confidence': '0.000653033668641001'},
#   {'gameTime': '1 - 43:48',
#    'label': 'Kick-off',
#    'position': '2628705',
#    'half': '1',
#    'confidence': '0.0006442570011131465'},
#   {'gameTime': '1 - 19:29',
#    'label': 'Kick-off',
#    'position': '1169006',
#    'half': '1',
#    'confidence': '0.0006337744416669011'},
#   {'gameTime': '1 - 38:7',
#    'label': 'Kick-off',
#    'position': '2287571',
#    'half': '1',
#    'confidence': '0.0006290921592153609'},
#   {'gameTime': '1 - 0:50',
#    'label': 'Kick-off',
#    'position': '50442',
#    'half': '1',
#    'confidence': '0.000606427900493145'},
#   {'gameTime': '1 - 20:32',
#    'label': 'Kick-off',
#    'position': '1232969',
#    'half': '1',
#    'confidence': '0.0006013694801367819'},
#   {'gameTime': '1 - 4:40',
#    'label': 'Kick-off',
#    'position': '280811',
#    'half': '1',
#    'confidence': '0.0005983536248095334'},
#   {'gameTime': '1 - 9:17',
#    'label': 'Kick-off',
#    'position': '557462',
#    'half': '1',
#    'confidence': '0.0005917498492635787'},
#   {'gameTime': '1 - 40:31',
#    'label': 'Kick-off',
#    'position': '2431097',
#    'half': '1',
#    'confidence': '0.0005796288605779409'},
#   {'gameTime': '1 - 42:36',
#    'label': 'Kick-off',
#    'position': '2556942',
#    'half': '1',
#    'confidence': '0.0005782708758488297'},
#   {'gameTime': '1 - 18:23',
#    'label': 'Kick-off',
#    'position': '1103484',
#    'half': '1',
#    'confidence': '0.0005321222124621272'},
#   {'gameTime': '1 - 39:57',
#    'label': 'Kick-off',
#    'position': '2397815',
#    'half': '1',
#    'confidence': '0.0004934347234666348'},
#   {'gameTime': '1 - 17:53',
#    'label': 'Kick-off',
#    'position': '1073842',
#    'half': '1',
#    'confidence': '0.000437448441516608'},
#   {'gameTime': '1 - 10:39',
#    'label': 'Kick-off',
#    'position': '639105',
#    'half': '1',
#    'confidence': '0.0004231007187627256'},
#   {'gameTime': '1 - 39:16',
#    'label': 'Kick-off',
#    'position': '2356214',
#    'half': '1',
#    'confidence': '0.00042274920269846916'},
#   {'gameTime': '1 - 33:16',
#    'label': 'Kick-off',
#    'position': '1996359',
#    'half': '1',
#    'confidence': '0.0004175201174803078'},
#   {'gameTime': '1 - 25:8',
#    'label': 'Kick-off',
#    'position': '1508580',
#    'half': '1',
#    'confidence': '0.0004083089006599039'},
#   {'gameTime': '1 - 12:30',
#    'label': 'Kick-off',
#    'position': '750910',
#    'half': '1',
#    'confidence': '0.00037627865094691515'},
#   {'gameTime': '1 - 9:50',
#    'label': 'Kick-off',
#    'position': '590223',
#    'half': '1',
#    'confidence': '0.0003699893713928759'},
#   {'gameTime': '1 - 16:30',
#    'label': 'Kick-off',
#    'position': '990639',
#    'half': '1',
#    'confidence': '0.0003538327000569552'},
#   {'gameTime': '1 - 31:35',
#    'label': 'Kick-off',
#    'position': '1895995',
#    'half': '1',
#    'confidence': '0.00033114408142864704'},
#   {'gameTime': '1 - 8:16',
#    'label': 'Kick-off',
#    'position': '496099',
#    'half': '1',
#    'confidence': '0.00031615799525752664'},
#   {'gameTime': '1 - 6:24',
#    'label': 'Kick-off',
#    'position': '384295',
#    'half': '1',
#    'confidence': '0.0003137429303023964'},
#   {'gameTime': '1 - 2:57',
#    'label': 'Kick-off',
#    'position': '177847',
#    'half': '1',
#    'confidence': '0.0003078096779063344'},
#   {'gameTime': '1 - 31:12',
#    'label': 'Kick-off',
#    'position': '1872074',
#    'half': '1',
#    'confidence': '0.0002785642573144287'},
#   {'gameTime': '1 - 20:13',
#    'label': 'Kick-off',
#    'position': '1213728',
#    'half': '1',
#    'confidence': '0.00027119959122501314'},
#   {'gameTime': '1 - 38:57',
#    'label': 'Kick-off',
#    'position': '2337493',
#    'half': '1',
#    'confidence': '0.00024115829728543758'},
#   {'gameTime': '1 - 18:39',
#    'label': 'Kick-off',
#    'position': '1119084',
#    'half': '1',
#    'confidence': '0.00023904898262117058'},
#   {'gameTime': '1 - 25:26',
#    'label': 'Kick-off',
#    'position': '1526781',
#    'half': '1',
#    'confidence': '0.00022650562459602952'},
#   {'gameTime': '1 - 0:25',
#    'label': 'Kick-off',
#    'position': '25481',
#    'half': '1',
#    'confidence': '0.00022129480203147978'},
#   {'gameTime': '1 - 32:39',
#    'label': 'Kick-off',
#    'position': '1959958',
#    'half': '1',
#    'confidence': '0.00020066714205313474'},
#   {'gameTime': '1 - 2:24',
#    'label': 'Kick-off',
#    'position': '144045',
#    'half': '1',
#    'confidence': '0.00019429464009590447'},
#   {'gameTime': '1 - 7:32',
#    'label': 'Kick-off',
#    'position': '452418',
#    'half': '1',
#    'confidence': '0.0001938085915753618'},
#   {'gameTime': '1 - 7:46',
#    'label': 'Kick-off',
#    'position': '466978',
#    'half': '1',
#    'confidence': '0.00019342736050020903'},
#   {'gameTime': '1 - 6:39',
#    'label': 'Kick-off',
#    'position': '399895',
#    'half': '1',
#    'confidence': '0.00019228048040531576'},
#   {'gameTime': '1 - 23:18',
#    'label': 'Kick-off',
#    'position': '1398855',
#    'half': '1',
#    'confidence': '0.00019096951291430742'},
#   {'gameTime': '1 - 7:16',
#    'label': 'Kick-off',
#    'position': '436297',
#    'half': '1',
#    'confidence': '0.00018881635332945734'},
#   {'gameTime': '1 - 10:5',
#    'label': 'Kick-off',
#    'position': '605824',
#    'half': '1',
#    'confidence': '0.00016584937111474574'},
#   {'gameTime': '1 - 36:19',
#    'label': 'Kick-off',
#    'position': '2179927',
#    'half': '1',
#    'confidence': '0.00015806304872967303'},
#   {'gameTime': '1 - 26:52',
#    'label': 'Kick-off',
#    'position': '1612064',
#    'half': '1',
#    'confidence': '0.00013651321933139116'},
#   {'gameTime': '1 - 2:5',
#    'label': 'Kick-off',
#    'position': '125325',
#    'half': '1',
#    'confidence': '0.00012974855781067163'},
#   {'gameTime': '1 - 1:12',
#    'label': 'Kick-off',
#    'position': '72802',
#    'half': '1',
#    'confidence': '0.00012280659575480968'},
#   {'gameTime': '1 - 14:49',
#    'label': 'Kick-off',
#    'position': '889755',
#    'half': '1',
#    'confidence': '0.00012232543667778373'},
#   {'gameTime': '1 - 38:38',
#    'label': 'Kick-off',
#    'position': '2318772',
#    'half': '1',
#    'confidence': '9.834517550189048e-05'},
#   {'gameTime': '1 - 13:11',
#    'label': 'Kick-off',
#    'position': '791991',
#    'half': '1',
#    'confidence': '9.475518891122192e-05'},
#   {'gameTime': '1 - 22:11',
#    'label': 'Kick-off',
#    'position': '1331253',
#    'half': '1',
#    'confidence': '9.316405339632183e-05'},
#   {'gameTime': '1 - 36:56',
#    'label': 'Kick-off',
#    'position': '2216848',
#    'half': '1',
#    'confidence': '9.218664490617812e-05'},
#   {'gameTime': '1 - 2:39',
#    'label': 'Kick-off',
#    'position': '159126',
#    'half': '1',
#    'confidence': '7.783703040331602e-05'},
#   {'gameTime': '1 - 15:37',
#    'label': 'Kick-off',
#    'position': '937077',
#    'half': '1',
#    'confidence': '7.634700159542263e-05'},
#   {'gameTime': '1 - 44:26',
#    'label': 'Kick-off',
#    'position': '2666666',
#    'half': '1',
#    'confidence': '6.247621058719233e-05'},
#   {'gameTime': '1 - 19:43',
#    'label': 'Kick-off',
#    'position': '1183567',
#    'half': '1',
#    'confidence': '4.737475683214143e-05'},
#   {'gameTime': '1 - 34:16',
#    'label': 'Kick-off',
#    'position': '2056682',
#    'half': '1',
#    'confidence': '4.5446122385328636e-05'},
#   {'gameTime': '1 - 26:36',
#    'label': 'Kick-off',
#    'position': '1596463',
#    'half': '1',
#    'confidence': '3.065117562073283e-05'},
#   {'gameTime': '1 - 4:0',
#    'label': 'Kick-off',
#    'position': '240249',
#    'half': '1',
#    'confidence': '1.3445391232380643e-05'},
#   {'gameTime': '1 - 29:18',
#    'label': 'Goal',
#    'position': '1758710',
#    'half': '1',
#    'confidence': '0.9090672731399536'},
#   {'gameTime': '1 - 38:9',
#    'label': 'Goal',
#    'position': '2289131',
#    'half': '1',
#    'confidence': '0.6094940304756165'},
#   {'gameTime': '1 - 34:39',
#    'label': 'Goal',
#    'position': '2079043',
#    'half': '1',
#    'confidence': '0.31079378724098206'},
#   {'gameTime': '1 - 14:16',
#    'label': 'Goal',
#    'position': '856474',
#    'half': '1',
#    'confidence': '0.07277961075305939'},
#   {'gameTime': '1 - 1:44',
#    'label': 'Goal',
#    'position': '104004',
#    'half': '1',
#    'confidence': '0.03936433419585228'},
#   {'gameTime': '1 - 34:17',
#    'label': 'Goal',
#    'position': '2057722',
#    'half': '1',
#    'confidence': '0.025584500283002853'},
#   {'gameTime': '1 - 17:30',
#    'label': 'Goal',
#    'position': '1050962',
#    'half': '1',
#    'confidence': '0.013703158125281334'},
#   {'gameTime': '1 - 8:45',
#    'label': 'Goal',
#    'position': '525221',
#    'half': '1',
#    'confidence': '0.012913712300360203'},
#   {'gameTime': '1 - 42:14',
#    'label': 'Goal',
#    'position': '2534061',
#    'half': '1',
#    'confidence': '0.012075785547494888'},
#   {'gameTime': '1 - 32:6',
#    'label': 'Goal',
#    'position': '1926677',
#    'half': '1',
#    'confidence': '0.008597568608820438'},
#   {'gameTime': '1 - 21:11',
#    'label': 'Goal',
#    'position': '1271970',
#    'half': '1',
#    'confidence': '0.0074130697175860405'},
#   {'gameTime': '1 - 37:31',
#    'label': 'Goal',
#    'position': '2251690',
#    'half': '1',
#    'confidence': '0.005706348456442356'},
#   {'gameTime': '1 - 43:8',
#    'label': 'Goal',
#    'position': '2588143',
#    'half': '1',
#    'confidence': '0.003967789933085442'},
#   {'gameTime': '1 - 5:36',
#    'label': 'Goal',
#    'position': '336973',
#    'half': '1',
#    'confidence': '0.003585884580388665'},
#   {'gameTime': '1 - 40:56',
#    'label': 'Goal',
#    'position': '2456058',
#    'half': '1',
#    'confidence': '0.0028360930737107992'},
#   {'gameTime': '1 - 9:23',
#    'label': 'Goal',
#    'position': '563702',
#    'half': '1',
#    'confidence': '0.0022442257031798363'},
#   {'gameTime': '1 - 44:47',
#    'label': 'Goal',
#    'position': '2687987',
#    'half': '1',
#    'confidence': '0.0020196845289319754'},
#   {'gameTime': '1 - 19:34',
#    'label': 'Goal',
#    'position': '1174206',
#    'half': '1',
#    'confidence': '0.0020168167538940907'},
#   {'gameTime': '1 - 44:16',
#    'label': 'Goal',
#    'position': '2656786',
#    'half': '1',
#    'confidence': '0.001652008737437427'},
#   {'gameTime': '1 - 25:31',
#    'label': 'Goal',
#    'position': '1531461',
#    'half': '1',
#    'confidence': '0.0015455348184332252'},
#   {'gameTime': '1 - 33:29',
#    'label': 'Goal',
#    'position': '2009360',
#    'half': '1',
#    'confidence': '0.0010780113516375422'},
#   {'gameTime': '1 - 16:12',
#    'label': 'Goal',
#    'position': '972438',
#    'half': '1',
#    'confidence': '0.0009277274366468191'},
#   {'gameTime': '1 - 3:43',
#    'label': 'Goal',
#    'position': '223088',
#    'half': '1',
#    'confidence': '0.0007455943268723786'},
#   {'gameTime': '1 - 29:50',
#    'label': 'Goal',
#    'position': '1790951',
#    'half': '1',
#    'confidence': '0.0006795339286327362'},
#   {'gameTime': '1 - 26:26',
#    'label': 'Goal',
#    'position': '1586583',
#    'half': '1',
#    'confidence': '0.0006724072736687958'},
#   {'gameTime': '1 - 41:15',
#    'label': 'Goal',
#    'position': '2475819',
#    'half': '1',
#    'confidence': '0.0005738334730267525'},
#   {'gameTime': '1 - 15:30',
#    'label': 'Goal',
#    'position': '930317',
#    'half': '1',
#    'confidence': '0.000489833066239953'},
#   {'gameTime': '1 - 15:44',
#    'label': 'Goal',
#    'position': '944877',
#    'half': '1',
#    'confidence': '0.00047896517207846045'},
#   {'gameTime': '1 - 10:42',
#    'label': 'Goal',
#    'position': '642225',
#    'half': '1',
#    'confidence': '0.00044775637798011303'},
#   {'gameTime': '1 - 38:28',
#    'label': 'Goal',
#    'position': '2308372',
#    'half': '1',
#    'confidence': '0.0004414842987898737'},
#   {'gameTime': '1 - 9:47',
#    'label': 'Goal',
#    'position': '587103',
#    'half': '1',
#    'confidence': '0.00041037981281988323'},
#   {'gameTime': '1 - 16:38',
#    'label': 'Goal',
#    'position': '998959',
#    'half': '1',
#    'confidence': '0.0003943475312553346'},
#   {'gameTime': '1 - 41:33',
#    'label': 'Goal',
#    'position': '2493499',
#    'half': '1',
#    'confidence': '0.0003608142433222383'},
#   {'gameTime': '1 - 34:59',
#    'label': 'Goal',
#    'position': '2099843',
#    'half': '1',
#    'confidence': '0.00034077579039148986'},
#   {'gameTime': '1 - 6:50',
#    'label': 'Goal',
#    'position': '410816',
#    'half': '1',
#    'confidence': '0.00033324796822853386'},
#   {'gameTime': '1 - 4:38',
#    'label': 'Goal',
#    'position': '278211',
#    'half': '1',
#    'confidence': '0.0003299233503639698'},
#   {'gameTime': '1 - 33:43',
#    'label': 'Goal',
#    'position': '2023920',
#    'half': '1',
#    'confidence': '0.0003243402752559632'},
#   {'gameTime': '1 - 4:7',
#    'label': 'Goal',
#    'position': '247009',
#    'half': '1',
#    'confidence': '0.00031307036988437176'},
#   {'gameTime': '1 - 36:27',
#    'label': 'Goal',
#    'position': '2187727',
#    'half': '1',
#    'confidence': '0.00030803101253695786'},
#   {'gameTime': '1 - 30:5',
#    'label': 'Goal',
#    'position': '1805512',
#    'half': '1',
#    'confidence': '0.0003075087442994118'},
#   {'gameTime': '1 - 12:54',
#    'label': 'Goal',
#    'position': '774310',
#    'half': '1',
#    'confidence': '0.00030402810079976916'},
#   {'gameTime': '1 - 31:8',
#    'label': 'Goal',
#    'position': '1868434',
#    'half': '1',
#    'confidence': '0.00030231926939450204'},
#   {'gameTime': '1 - 7:48',
#    'label': 'Goal',
#    'position': '468018',
#    'half': '1',
#    'confidence': '0.00030203579808585346'},
#   {'gameTime': '1 - 34:0',
#    'label': 'Goal',
#    'position': '2040561',
#    'half': '1',
#    'confidence': '0.00030136475106701255'},
#   {'gameTime': '1 - 5:16',
#    'label': 'Goal',
#    'position': '316692',
#    'half': '1',
#    'confidence': '0.00029723692568950355'},
#   {'gameTime': '1 - 17:58',
#    'label': 'Goal',
#    'position': '1078523',
#    'half': '1',
#    'confidence': '0.00027374905766919255'},
#   {'gameTime': '1 - 30:50',
#    'label': 'Goal',
#    'position': '1850234',
#    'half': '1',
#    'confidence': '0.0002667322987690568'},
#   {'gameTime': '1 - 1:21',
#    'label': 'Goal',
#    'position': '81123',
#    'half': '1',
#    'confidence': '0.0002658498124219477'},
#   {'gameTime': '1 - 39:25',
#    'label': 'Goal',
#    'position': '2365054',
#    'half': '1',
#    'confidence': '0.00024741774541325867'},
#   {'gameTime': '1 - 12:11',
#    'label': 'Goal',
#    'position': '731669',
#    'half': '1',
#    'confidence': '0.0002419929951429367'},
#   {'gameTime': '1 - 31:51',
#    'label': 'Goal',
#    'position': '1911076',
#    'half': '1',
#    'confidence': '0.000229759156354703'},
#   {'gameTime': '1 - 41:58',
#    'label': 'Goal',
#    'position': '2518460',
#    'half': '1',
#    'confidence': '0.00021565129281952977'},
#   {'gameTime': '1 - 21:26',
#    'label': 'Goal',
#    'position': '1286531',
#    'half': '1',
#    'confidence': '0.0002151041990146041'},
#   {'gameTime': '1 - 13:18',
#    'label': 'Goal',
#    'position': '798751',
#    'half': '1',
#    'confidence': '0.00021336387726478279'},
#   {'gameTime': '1 - 23:30',
#    'label': 'Goal',
#    'position': '1410816',
#    'half': '1',
#    'confidence': '0.0002060569095192477'},
#   {'gameTime': '1 - 22:36',
#    'label': 'Goal',
#    'position': '1356734',
#    'half': '1',
#    'confidence': '0.00020022391981910914'},
#   {'gameTime': '1 - 12:28',
#    'label': 'Goal',
#    'position': '748829',
#    'half': '1',
#    'confidence': '0.00019515224266797304'},
#   {'gameTime': '1 - 8:2',
#    'label': 'Goal',
#    'position': '482579',
#    'half': '1',
#    'confidence': '0.00017641260637901723'},
#   {'gameTime': '1 - 27:30',
#    'label': 'Goal',
#    'position': '1650546',
#    'half': '1',
#    'confidence': '0.00017357326578348875'},
#   {'gameTime': '1 - 28:5',
#    'label': 'Goal',
#    'position': '1685387',
#    'half': '1',
#    'confidence': '0.00017337262397632003'},
#   {'gameTime': '1 - 43:31',
#    'label': 'Goal',
#    'position': '2611544',
#    'half': '1',
#    'confidence': '0.00016604765551164746'},
#   {'gameTime': '1 - 30:24',
#    'label': 'Goal',
#    'position': '1824232',
#    'half': '1',
#    'confidence': '0.00016471043636556715'},
#   {'gameTime': '1 - 20:31',
#    'label': 'Goal',
#    'position': '1231409',
#    'half': '1',
#    'confidence': '0.0001644739240873605'},
#   {'gameTime': '1 - 24:6',
#    'label': 'Goal',
#    'position': '1446177',
#    'half': '1',
#    'confidence': '0.00015156911103986204'},
#   {'gameTime': '1 - 40:24',
#    'label': 'Goal',
#    'position': '2424336',
#    'half': '1',
#    'confidence': '0.00014305865624919534'},
#   {'gameTime': '1 - 19:3',
#    'label': 'Goal',
#    'position': '1143525',
#    'half': '1',
#    'confidence': '0.00014285213546827435'},
#   {'gameTime': '1 - 0:6',
#    'label': 'Goal',
#    'position': '6760',
#    'half': '1',
#    'confidence': '0.00014221973833628'},
#   {'gameTime': '1 - 19:57',
#    'label': 'Goal',
#    'position': '1197087',
#    'half': '1',
#    'confidence': '0.00013913899601902813'},
#   {'gameTime': '1 - 26:49',
#    'label': 'Goal',
#    'position': '1609464',
#    'half': '1',
#    'confidence': '0.00013182483962737024'},
#   {'gameTime': '1 - 11:9',
#    'label': 'Goal',
#    'position': '669266',
#    'half': '1',
#    'confidence': '0.0001260751741938293'},
#   {'gameTime': '1 - 11:24',
#    'label': 'Goal',
#    'position': '684347',
#    'half': '1',
#    'confidence': '0.00011371633445378393'},
#   {'gameTime': '1 - 42:29',
#    'label': 'Goal',
#    'position': '2549141',
#    'half': '1',
#    'confidence': '0.00011114363587694243'},
#   {'gameTime': '1 - 13:37',
#    'label': 'Goal',
#    'position': '817992',
#    'half': '1',
#    'confidence': '0.00011052050831494853'},
#   {'gameTime': '1 - 26:3',
#    'label': 'Goal',
#    'position': '1563182',
#    'half': '1',
#    'confidence': '0.00010869906691368669'},
#   {'gameTime': '1 - 3:10',
#    'label': 'Goal',
#    'position': '190327',
#    'half': '1',
#    'confidence': '0.00010562811075942591'},
#   {'gameTime': '1 - 9:7',
#    'label': 'Goal',
#    'position': '547581',
#    'half': '1',
#    'confidence': '0.00010300935537088662'},
#   {'gameTime': '1 - 27:47',
#    'label': 'Goal',
#    'position': '1667706',
#    'half': '1',
#    'confidence': '0.0001021096104523167'},
#   {'gameTime': '1 - 8:29',
#    'label': 'Goal',
#    'position': '509100',
#    'half': '1',
#    'confidence': '0.00010162343096453696'},
#   {'gameTime': '1 - 10:2',
#    'label': 'Goal',
#    'position': '602704',
#    'half': '1',
#    'confidence': '0.00010106679837917909'},
#   {'gameTime': '1 - 15:8',
#    'label': 'Goal',
#    'position': '908476',
#    'half': '1',
#    'confidence': '9.904018952511251e-05'},
#   {'gameTime': '1 - 29:33',
#    'label': 'Goal',
#    'position': '1773270',
#    'half': '1',
#    'confidence': '9.616952593205497e-05'},
#   {'gameTime': '1 - 39:52',
#    'label': 'Goal',
#    'position': '2392615',
#    'half': '1',
# ...
#    'label': 'Shots off target',
#    'position': '1242329',
#    'half': '1',
#    'confidence': '0.0017919904785230756'},
#   {'gameTime': '1 - 8:29',
#    'label': 'Shots off target',
#    'position': '509100',
#    'half': '1',
#    'confidence': '0.0017308968817815185'},
#   {'gameTime': '1 - 3:3',
#    'label': 'Shots off target',
#    'position': '183047',
#    'half': '1',
#    'confidence': '0.001659207628108561'},
#   {'gameTime': '1 - 24:11',
#    'label': 'Shots off target',
#    'position': '1451898',
#    'half': '1',
#    'confidence': '0.0016379341250285506'},
#   {'gameTime': '1 - 13:52',
#    'label': 'Shots off target',
#    'position': '832033',
#    'half': '1',
#    'confidence': '0.0015604529762640595'},
#   {'gameTime': '1 - 13:29',
#    'label': 'Shots off target',
#    'position': '809152',
#    'half': '1',
#    'confidence': '0.001554868184030056'},
#   {'gameTime': '1 - 25:53',
#    'label': 'Shots off target',
#    'position': '1553302',
#    'half': '1',
#    'confidence': '0.0015540317399427295'},
#   {'gameTime': '1 - 38:28',
#    'label': 'Shots off target',
#    'position': '2308892',
#    'half': '1',
#    'confidence': '0.0015514835249632597'},
#   {'gameTime': '1 - 27:27',
#    'label': 'Shots off target',
#    'position': '1647425',
#    'half': '1',
#    'confidence': '0.0015316192293539643'},
#   {'gameTime': '1 - 39:17',
#    'label': 'Shots off target',
#    'position': '2357774',
#    'half': '1',
#    'confidence': '0.0013910095440223813'},
#   {'gameTime': '1 - 16:1',
#    'label': 'Shots off target',
#    'position': '961518',
#    'half': '1',
#    'confidence': '0.001333844382315874'},
#   {'gameTime': '1 - 39:51',
#    'label': 'Shots off target',
#    'position': '2391575',
#    'half': '1',
#    'confidence': '0.0013081601355224848'},
#   {'gameTime': '1 - 12:10',
#    'label': 'Shots off target',
#    'position': '730629',
#    'half': '1',
#    'confidence': '0.0012807260500267148'},
#   {'gameTime': '1 - 12:43',
#    'label': 'Shots off target',
#    'position': '763390',
#    'half': '1',
#    'confidence': '0.0012426954926922917'},
#   {'gameTime': '1 - 36:39',
#    'label': 'Shots off target',
#    'position': '2199167',
#    'half': '1',
#    'confidence': '0.0010525144170969725'},
#   {'gameTime': '1 - 1:14',
#    'label': 'Shots off target',
#    'position': '74362',
#    'half': '1',
#    'confidence': '0.0010414797579869628'},
#   {'gameTime': '1 - 36:56',
#    'label': 'Shots off target',
#    'position': '2216848',
#    'half': '1',
#    'confidence': '0.001028487109579146'},
#   {'gameTime': '1 - 34:3',
#    'label': 'Shots off target',
#    'position': '2043681',
#    'half': '1',
#    'confidence': '0.0010138897923752666'},
#   {'gameTime': '1 - 30:28',
#    'label': 'Shots off target',
#    'position': '1828913',
#    'half': '1',
#    'confidence': '0.000990096596069634'},
#   {'gameTime': '1 - 8:4',
#    'label': 'Shots off target',
#    'position': '484659',
#    'half': '1',
#    'confidence': '0.0009872763184830546'},
#   {'gameTime': '1 - 29:50',
#    'label': 'Shots off target',
#    'position': '1790951',
#    'half': '1',
#    'confidence': '0.000978777534328401'},
#   {'gameTime': '1 - 4:0',
#    'label': 'Shots off target',
#    'position': '240769',
#    'half': '1',
#    'confidence': '0.0009108111844398081'},
#   {'gameTime': '1 - 6:49',
#    'label': 'Shots off target',
#    'position': '409256',
#    'half': '1',
#    'confidence': '0.0008758084732107818'},
#   {'gameTime': '1 - 18:51',
#    'label': 'Shots off target',
#    'position': '1131045',
#    'half': '1',
#    'confidence': '0.0008695757132954895'},
#   {'gameTime': '1 - 31:22',
#    'label': 'Shots off target',
#    'position': '1882995',
#    'half': '1',
#    'confidence': '0.0008564427844248712'},
#   {'gameTime': '1 - 36:1',
#    'label': 'Shots off target',
#    'position': '2161206',
#    'half': '1',
#    'confidence': '0.000845964124891907'},
#   {'gameTime': '1 - 14:37',
#    'label': 'Shots off target',
#    'position': '877275',
#    'half': '1',
#    'confidence': '0.000720368989277631'},
#   {'gameTime': '1 - 5:21',
#    'label': 'Shots off target',
#    'position': '321892',
#    'half': '1',
#    'confidence': '0.000717215589247644'},
#   {'gameTime': '1 - 38:43',
#    'label': 'Shots off target',
#    'position': '2323452',
#    'half': '1',
#    'confidence': '0.0007167116855271161'},
#   {'gameTime': '1 - 4:28',
#    'label': 'Shots off target',
#    'position': '268850',
#    'half': '1',
#    'confidence': '0.0007043156656436622'},
#   {'gameTime': '1 - 7:6',
#    'label': 'Shots off target',
#    'position': '426417',
#    'half': '1',
#    'confidence': '0.0006988478708080947'},
#   {'gameTime': '1 - 16:20',
#    'label': 'Shots off target',
#    'position': '980759',
#    'half': '1',
#    'confidence': '0.0006831337814219296'},
#   {'gameTime': '1 - 9:7',
#    'label': 'Shots off target',
#    'position': '547581',
#    'half': '1',
#    'confidence': '0.0006519936141557992'},
#   {'gameTime': '1 - 1:54',
#    'label': 'Shots off target',
#    'position': '114404',
#    'half': '1',
#    'confidence': '0.0006429814384318888'},
#   {'gameTime': '1 - 0:24',
#    'label': 'Shots off target',
#    'position': '24960',
#    'half': '1',
#    'confidence': '0.0006429079221561551'},
#   {'gameTime': '1 - 43:46',
#    'label': 'Shots off target',
#    'position': '2626625',
#    'half': '1',
#    'confidence': '0.0006416545948013663'},
#   {'gameTime': '1 - 20:6',
#    'label': 'Shots off target',
#    'position': '1206968',
#    'half': '1',
#    'confidence': '0.0006166996899992228'},
#   {'gameTime': '1 - 17:0',
#    'label': 'Shots off target',
#    'position': '1020800',
#    'half': '1',
#    'confidence': '0.0005952098872512579'},
#   {'gameTime': '1 - 23:0',
#    'label': 'Shots off target',
#    'position': '1380135',
#    'half': '1',
#    'confidence': '0.0005904931458644569'},
#   {'gameTime': '1 - 10:30',
#    'label': 'Shots off target',
#    'position': '630265',
#    'half': '1',
#    'confidence': '0.0005450786557048559'},
#   {'gameTime': '1 - 24:38',
#    'label': 'Shots off target',
#    'position': '1478419',
#    'half': '1',
#    'confidence': '0.0005405974225141108'},
#   {'gameTime': '1 - 28:22',
#    'label': 'Shots off target',
#    'position': '1702028',
#    'half': '1',
#    'confidence': '0.0005041143740527332'},
#   {'gameTime': '1 - 10:5',
#    'label': 'Shots off target',
#    'position': '605304',
#    'half': '1',
#    'confidence': '0.0005035822978243232'},
#   {'gameTime': '1 - 30:9',
#    'label': 'Shots off target',
#    'position': '1809152',
#    'half': '1',
#    'confidence': '0.0004809626843780279'},
#   {'gameTime': '1 - 37:11',
#    'label': 'Shots off target',
#    'position': '2231409',
#    'half': '1',
#    'confidence': '0.0004679793491959572'},
#   {'gameTime': '1 - 40:52',
#    'label': 'Shots off target',
#    'position': '2452938',
#    'half': '1',
#    'confidence': '0.00046739549725316465'},
#   {'gameTime': '1 - 19:7',
#    'label': 'Shots off target',
#    'position': '1147685',
#    'half': '1',
#    'confidence': '0.0004497823538258672'},
#   {'gameTime': '1 - 31:5',
#    'label': 'Shots off target',
#    'position': '1865314',
#    'half': '1',
#    'confidence': '0.00044816648005507886'},
#   {'gameTime': '1 - 33:17',
#    'label': 'Shots off target',
#    'position': '1997399',
#    'half': '1',
#    'confidence': '0.0004459525807760656'},
#   {'gameTime': '1 - 22:9',
#    'label': 'Shots off target',
#    'position': '1329173',
#    'half': '1',
#    'confidence': '0.00041225561290048063'},
#   {'gameTime': '1 - 41:51',
#    'label': 'Shots off target',
#    'position': '2511700',
#    'half': '1',
#    'confidence': '0.00041183611028827727'},
#   {'gameTime': '1 - 2:11',
#    'label': 'Shots off target',
#    'position': '131565',
#    'half': '1',
#    'confidence': '0.00039925420423969626'},
#   {'gameTime': '1 - 0:55',
#    'label': 'Shots off target',
#    'position': '55122',
#    'half': '1',
#    'confidence': '0.0003855795366689563'},
#   {'gameTime': '1 - 21:40',
#    'label': 'Shots off target',
#    'position': '1300572',
#    'half': '1',
#    'confidence': '0.0003830556233879179'},
#   {'gameTime': '1 - 34:56',
#    'label': 'Shots off target',
#    'position': '2096723',
#    'half': '1',
#    'confidence': '0.00036708300467580557'},
#   {'gameTime': '1 - 42:52',
#    'label': 'Shots off target',
#    'position': '2572542',
#    'half': '1',
#    'confidence': '0.00036028370959684253'},
#   {'gameTime': '1 - 11:1',
#    'label': 'Shots off target',
#    'position': '661466',
#    'half': '1',
#    'confidence': '0.00035861131618730724'},
#   {'gameTime': '1 - 19:49',
#    'label': 'Shots off target',
#    'position': '1189287',
#    'half': '1',
#    'confidence': '0.00033578777220100164'},
#   {'gameTime': '1 - 23:53',
#    'label': 'Shots off target',
#    'position': '1433177',
#    'half': '1',
#    'confidence': '0.00031297365785576403'},
#   {'gameTime': '1 - 44:32',
#    'label': 'Shots off target',
#    'position': '2672386',
#    'half': '1',
#    'confidence': '0.00031154623138718307'},
#   {'gameTime': '1 - 11:40',
#    'label': 'Shots off target',
#    'position': '700468',
#    'half': '1',
#    'confidence': '0.0002996009134221822'},
#   {'gameTime': '1 - 29:34',
#    'label': 'Shots off target',
#    'position': '1774310',
#    'half': '1',
#    'confidence': '0.00028831601957790554'},
#   {'gameTime': '1 - 3:22',
#    'label': 'Shots off target',
#    'position': '202808',
#    'half': '1',
#    'confidence': '0.0002553311933297664'},
#   {'gameTime': '1 - 15:20',
#    'label': 'Shots off target',
#    'position': '920956',
#    'half': '1',
#    'confidence': '0.00025468520470894873'},
#   {'gameTime': '1 - 14:51',
#    'label': 'Shots off target',
#    'position': '891835',
#    'half': '1',
#    'confidence': '0.00023909934679977596'},
#   {'gameTime': '1 - 18:28',
#    'label': 'Shots off target',
#    'position': '1108164',
#    'half': '1',
#    'confidence': '0.0002045621076831594'},
#   {'gameTime': '1 - 6:31',
#    'label': 'Shots off target',
#    'position': '391055',
#    'half': '1',
#    'confidence': '0.00019485493248794228'},
#   {'gameTime': '1 - 35:45',
#    'label': 'Shots off target',
#    'position': '2145605',
#    'half': '1',
#    'confidence': '0.00018301146337762475'},
#   {'gameTime': '1 - 27:48',
#    'label': 'Shots off target',
#    'position': '1668226',
#    'half': '1',
#    'confidence': '0.00018169646500609815'},
#   {'gameTime': '1 - 2:26',
#    'label': 'Shots off target',
#    'position': '146645',
#    'half': '1',
#    'confidence': '0.00017526243755128235'},
#   {'gameTime': '1 - 7:33',
#    'label': 'Shots off target',
#    'position': '453458',
#    'half': '1',
#    'confidence': '0.0001659691333770752'},
#   {'gameTime': '1 - 17:18',
#    'label': 'Shots off target',
#    'position': '1038481',
#    'half': '1',
#    'confidence': '0.00016460225742775947'},
#   {'gameTime': '1 - 39:2',
#    'label': 'Shots off target',
#    'position': '2342173',
#    'half': '1',
#    'confidence': '0.00014983040455263108'},
#   {'gameTime': '1 - 11:55',
#    'label': 'Shots off target',
#    'position': '715028',
#    'half': '1',
#    'confidence': '0.00014721274783369154'},
#   {'gameTime': '1 - 29:4',
#    'label': 'Shots off target',
#    'position': '1744149',
#    'half': '1',
#    'confidence': '0.0001448351686121896'},
#   {'gameTime': '1 - 32:56',
#    'label': 'Shots off target',
#    'position': '1976599',
#    'half': '1',
#    'confidence': '0.00013787453644908965'},
#   {'gameTime': '1 - 40:6',
#    'label': 'Shots off target',
#    'position': '2406136',
#    'half': '1',
#    'confidence': '0.00013238917745184153'},
#   {'gameTime': '1 - 26:11',
#    'label': 'Shots off target',
#    'position': '1571502',
#    'half': '1',
#    'confidence': '0.00012484440230764449'},
#   {'gameTime': '1 - 27:11',
#    'label': 'Shots off target',
#    'position': '1631825',
#    'half': '1',
#    'confidence': '0.0001185739747597836'},
#   {'gameTime': '1 - 23:37',
#    'label': 'Shots off target',
#    'position': '1417576',
#    'half': '1',
#    'confidence': '0.00011374842870282009'},
#   {'gameTime': '1 - 37:44',
#    'label': 'Shots off target',
#    'position': '2264170',
#    'half': '1',
#    'confidence': '9.1790861915797e-05'},
#   {'gameTime': '1 - 20:56',
#    'label': 'Shots off target',
#    'position': '1256890',
#    'half': '1',
#    'confidence': '6.821601709816605e-05'},
#   {'gameTime': '1 - 11:24',
#    'label': 'Clearance',
#    'position': '684867',
#    'half': '1',
#    'confidence': '0.9750975370407104'},
#   {'gameTime': '1 - 6:18',
#    'label': 'Clearance',
#    'position': '378055',
#    'half': '1',
#    'confidence': '0.9706430435180664'},
#   {'gameTime': '1 - 1:51',
#    'label': 'Clearance',
#    'position': '111284',
#    'half': '1',
#    'confidence': '0.8799745440483093'},
#   {'gameTime': '1 - 5:21',
#    'label': 'Clearance',
#    'position': '321892',
#    'half': '1',
#    'confidence': '0.46399787068367004'},
#   {'gameTime': '1 - 20:36',
#    'label': 'Clearance',
#    'position': '1236609',
#    'half': '1',
#    'confidence': '0.42479780316352844'},
#   {'gameTime': '1 - 38:32',
#    'label': 'Clearance',
#    'position': '2312532',
#    'half': '1',
#    'confidence': '0.4046156406402588'},
#   {'gameTime': '1 - 29:11',
#    'label': 'Clearance',
#    'position': '1751430',
#    'half': '1',
#    'confidence': '0.3016529977321625'},
#   {'gameTime': '1 - 39:30',
#    'label': 'Clearance',
#    'position': '2370254',
#    'half': '1',
#    'confidence': '0.23754319548606873'},
#   {'gameTime': '1 - 24:23',
#    'label': 'Clearance',
#    'position': '1463858',
#    'half': '1',
#    'confidence': '0.21078628301620483'},
#   {'gameTime': '1 - 34:51',
#    'label': 'Clearance',
#    'position': '2091003',
#    'half': '1',
#    'confidence': '0.21066686511039734'},
#   {'gameTime': '1 - 30:30',
#    'label': 'Clearance',
#    'position': '1830993',
#    'half': '1',
#    'confidence': '0.13228514790534973'},
#   {'gameTime': '1 - 36:36',
#    'label': 'Clearance',
#    'position': '2196047',
#    'half': '1',
#    'confidence': '0.12687426805496216'},
#   {'gameTime': '1 - 32:26',
#    'label': 'Clearance',
#    'position': '1946437',
#    'half': '1',
#    'confidence': '0.12113958597183228'},
#   {'gameTime': '1 - 28:16',
#    'label': 'Clearance',
#    'position': '1696307',
#    'half': '1',
#    'confidence': '0.11900512874126434'},
#   {'gameTime': '1 - 1:24',
#    'label': 'Clearance',
#    'position': '84243',
#    'half': '1',
#    'confidence': '0.09436103701591492'},
#   {'gameTime': '1 - 30:5',
#    'label': 'Clearance',
#    'position': '1805512',
#    'half': '1',
#    'confidence': '0.08777705579996109'},
#   {'gameTime': '1 - 37:50',
#    'label': 'Clearance',
#    'position': '2270930',
#    'half': '1',
#    'confidence': '0.08045782148838043'},
#   {'gameTime': '1 - 14:33',
#    'label': 'Clearance',
#    'position': '873114',
#    'half': '1',
#    'confidence': '0.06869011372327805'},
#   {'gameTime': '1 - 38:16',
#    'label': 'Clearance',
#    'position': '2296931',
#    'half': '1',
#    'confidence': '0.06468679755926132'},
#   {'gameTime': '1 - 0:4',
#    'label': 'Clearance',
#    'position': '4680',
#    'half': '1',
#    'confidence': '0.06449829787015915'},
#   {'gameTime': '1 - 23:33',
#    'label': 'Clearance',
#    'position': '1413416',
#    'half': '1',
#    'confidence': '0.06272400915622711'},
#   {'gameTime': '1 - 29:35',
#    'label': 'Clearance',
#    'position': '1775351',
#    'half': '1',
#    'confidence': '0.06232732534408569'},
#   {'gameTime': '1 - 25:51',
#    'label': 'Clearance',
#    'position': '1551222',
#    'half': '1',
#    'confidence': '0.050752900540828705'},
#   {'gameTime': '1 - 19:59',
#    'label': 'Clearance',
#    'position': '1199687',
#    'half': '1',
#    'confidence': '0.0488886795938015'},
#   {'gameTime': '1 - 28:38',
#    'label': 'Clearance',
#    'position': '1718668',
#    'half': '1',
#    'confidence': '0.04476385563611984'},
#   {'gameTime': '1 - 9:1',
#    'label': 'Clearance',
#    'position': '541341',
#    'half': '1',
#    'confidence': '0.04185491427779198'},
#   {'gameTime': '1 - 17:11',
#    'label': 'Clearance',
#    'position': '1031201',
#    'half': '1',
#    'confidence': '0.041681405156850815'},
#   {'gameTime': '1 - 21:48',
#    'label': 'Clearance',
#    'position': '1308372',
#    'half': '1',
#    'confidence': '0.03659975528717041'},
#   {'gameTime': '1 - 33:33',
#    'label': 'Clearance',
#    'position': '2013000',
#    'half': '1',
#    'confidence': '0.03462270274758339'},
#   {'gameTime': '1 - 40:46',
#    'label': 'Clearance',
#    'position': '2446177',
#    'half': '1',
#    'confidence': '0.0332154743373394'},
#   {'gameTime': '1 - 35:8',
#    'label': 'Clearance',
#    'position': '2108164',
#    'half': '1',
#    'confidence': '0.0300102811306715'},
#   ...]}

# %%
data['predictions']
# Out:
# [{'gameTime': '1 - 14:16',
#   'label': 'Penalty',
#   'position': '856474',
#   'half': '1',
#   'confidence': '0.006846137344837189'},
#  {'gameTime': '1 - 1:45',
#   'label': 'Penalty',
#   'position': '105564',
#   'half': '1',
#   'confidence': '0.0015244742389768362'},
#  {'gameTime': '1 - 29:20',
#   'label': 'Penalty',
#   'position': '1760270',
#   'half': '1',
#   'confidence': '0.0011110763298347592'},
#  {'gameTime': '1 - 23:31',
#   'label': 'Penalty',
#   'position': '1411336',
#   'half': '1',
#   'confidence': '0.0006935555720701814'},
#  {'gameTime': '1 - 35:0',
#   'label': 'Penalty',
#   'position': '2100884',
#   'half': '1',
#   'confidence': '0.0006670397706329823'},
#  {'gameTime': '1 - 11:22',
#   'label': 'Penalty',
#   'position': '682787',
#   'half': '1',
#   'confidence': '0.0006399552221409976'},
#  {'gameTime': '1 - 39:29',
#   'label': 'Penalty',
#   'position': '2369214',
#   'half': '1',
#   'confidence': '0.0006146698724478483'},
#  {'gameTime': '1 - 1:21',
#   'label': 'Penalty',
#   'position': '81643',
#   'half': '1',
#   'confidence': '0.00026217332924716175'},
#  {'gameTime': '1 - 9:19',
#   'label': 'Penalty',
#   'position': '559542',
#   'half': '1',
#   'confidence': '0.0002607161004561931'},
#  {'gameTime': '1 - 15:42',
#   'label': 'Penalty',
#   'position': '942797',
#   'half': '1',
#   'confidence': '0.00023109978064894676'},
#  {'gameTime': '1 - 9:42',
#   'label': 'Penalty',
#   'position': '582943',
#   'half': '1',
#   'confidence': '0.0002201692695962265'},
#  {'gameTime': '1 - 5:21',
#   'label': 'Penalty',
#   'position': '321892',
#   'half': '1',
#   'confidence': '0.00021712335001211613'},
#  {'gameTime': '1 - 3:54',
#   'label': 'Penalty',
#   'position': '234529',
#   'half': '1',
#   'confidence': '0.00021032981749158353'},
#  {'gameTime': '1 - 40:56',
#   'label': 'Penalty',
#   'position': '2456578',
#   'half': '1',
#   'confidence': '0.00017056186334230006'},
#  {'gameTime': '1 - 8:8',
#   'label': 'Penalty',
#   'position': '488819',
#   'half': '1',
#   'confidence': '0.0001658522232901305'},
#  {'gameTime': '1 - 44:46',
#   'label': 'Penalty',
#   'position': '2686427',
#   'half': '1',
#   'confidence': '0.00015481443551834673'},
#  {'gameTime': '1 - 26:31',
#   'label': 'Penalty',
#   'position': '1591783',
#   'half': '1',
#   'confidence': '0.00012810734915547073'},
#  {'gameTime': '1 - 28:15',
#   'label': 'Penalty',
#   'position': '1695787',
#   'half': '1',
#   'confidence': '9.111769031733274e-05'},
#  {'gameTime': '1 - 16:22',
#   'label': 'Penalty',
#   'position': '982839',
#   'half': '1',
#   'confidence': '7.905145321274176e-05'},
#  {'gameTime': '1 - 41:35',
#   'label': 'Penalty',
#   'position': '2495059',
#   'half': '1',
#   'confidence': '6.409495836123824e-05'},
#  {'gameTime': '1 - 38:10',
#   'label': 'Penalty',
#   'position': '2290171',
#   'half': '1',
#   'confidence': '5.4397205531131476e-05'},
#  {'gameTime': '1 - 40:31',
#   'label': 'Penalty',
#   'position': '2431097',
#   'half': '1',
#   'confidence': '4.574222111841664e-05'},
#  {'gameTime': '1 - 19:57',
#   'label': 'Penalty',
#   'position': '1197607',
#   'half': '1',
#   'confidence': '3.9984228351386264e-05'},
#  {'gameTime': '1 - 6:15',
#   'label': 'Penalty',
#   'position': '375975',
#   'half': '1',
#   'confidence': '3.952312545152381e-05'},
#  {'gameTime': '1 - 34:23',
#   'label': 'Penalty',
#   'position': '2063962',
#   'half': '1',
#   'confidence': '3.459355502855033e-05'},
#  {'gameTime': '1 - 44:12',
#   'label': 'Penalty',
#   'position': '2652106',
#   'half': '1',
#   'confidence': '3.359121910762042e-05'},
#  {'gameTime': '1 - 25:59',
#   'label': 'Penalty',
#   'position': '1559022',
#   'half': '1',
#   'confidence': '2.507745193724986e-05'},
#  {'gameTime': '1 - 20:32',
#   'label': 'Penalty',
#   'position': '1232449',
#   'half': '1',
#   'confidence': '2.4249635316664353e-05'},
#  {'gameTime': '1 - 19:39',
#   'label': 'Penalty',
#   'position': '1179927',
#   'half': '1',
#   'confidence': '2.302145367139019e-05'},
#  {'gameTime': '1 - 37:34',
#   'label': 'Penalty',
#   'position': '2254290',
#   'half': '1',
#   'confidence': '2.1296254999469966e-05'},
#  {'gameTime': '1 - 38:30',
#   'label': 'Penalty',
#   'position': '2310452',
#   'half': '1',
#   'confidence': '1.910197352117393e-05'},
#  {'gameTime': '1 - 35:53',
#   'label': 'Penalty',
#   'position': '2153926',
#   'half': '1',
#   'confidence': '1.9088207409367897e-05'},
#  {'gameTime': '1 - 5:36',
#   'label': 'Penalty',
#   'position': '336453',
#   'half': '1',
#   'confidence': '1.7221009329659864e-05'},
#  {'gameTime': '1 - 13:17',
#   'label': 'Penalty',
#   'position': '797711',
#   'half': '1',
#   'confidence': '1.503171370131895e-05'},
#  {'gameTime': '1 - 13:46',
#   'label': 'Penalty',
#   'position': '826833',
#   'half': '1',
#   'confidence': '1.4186437510943506e-05'},
#  {'gameTime': '1 - 5:58',
#   'label': 'Penalty',
#   'position': '358294',
#   'half': '1',
#   'confidence': '1.369915025861701e-05'},
#  {'gameTime': '1 - 43:33',
#   'label': 'Penalty',
#   'position': '2613624',
#   'half': '1',
#   'confidence': '1.3588850379164796e-05'},
#  {'gameTime': '1 - 32:12',
#   'label': 'Penalty',
#   'position': '1932917',
#   'half': '1',
#   'confidence': '1.3441621376841795e-05'},
#  {'gameTime': '1 - 35:32',
#   'label': 'Penalty',
#   'position': '2132085',
#   'half': '1',
#   'confidence': '1.3093962479615584e-05'},
#  {'gameTime': '1 - 4:13',
#   'label': 'Penalty',
#   'position': '253770',
#   'half': '1',
#   'confidence': '1.258158044947777e-05'},
#  {'gameTime': '1 - 29:51',
#   'label': 'Penalty',
#   'position': '1791471',
#   'half': '1',
#   'confidence': '1.2444681487977505e-05'},
#  {'gameTime': '1 - 21:11',
#   'label': 'Penalty',
#   'position': '1271450',
#   'half': '1',
#   'confidence': '1.1246396752540022e-05'},
#  {'gameTime': '1 - 22:43',
#   'label': 'Penalty',
#   'position': '1363494',
#   'half': '1',
#   'confidence': '1.0647088856785558e-05'},
#  {'gameTime': '1 - 30:7',
#   'label': 'Penalty',
#   'position': '1807072',
#   'half': '1',
#   'confidence': '9.968386621039826e-06'},
#  {'gameTime': '1 - 17:32',
#   'label': 'Penalty',
#   'position': '1052002',
#   'half': '1',
#   'confidence': '9.342513294541277e-06'},
#  {'gameTime': '1 - 39:57',
#   'label': 'Penalty',
#   'position': '2397295',
#   'half': '1',
#   'confidence': '8.966480891103856e-06'},
#  {'gameTime': '1 - 34:39',
#   'label': 'Penalty',
#   'position': '2079043',
#   'half': '1',
#   'confidence': '7.488121354981558e-06'},
#  {'gameTime': '1 - 10:43',
#   'label': 'Penalty',
#   'position': '643265',
#   'half': '1',
#   'confidence': '7.447982625308214e-06'},
#  {'gameTime': '1 - 30:27',
#   'label': 'Penalty',
#   'position': '1827353',
#   'half': '1',
#   'confidence': '7.3791761678876355e-06'},
#  {'gameTime': '1 - 24:10',
#   'label': 'Penalty',
#   'position': '1450338',
#   'half': '1',
#   'confidence': '6.646652764175087e-06'},
#  {'gameTime': '1 - 25:30',
#   'label': 'Penalty',
#   'position': '1530941',
#   'half': '1',
#   'confidence': '6.135233434179099e-06'},
#  {'gameTime': '1 - 33:30',
#   'label': 'Penalty',
#   'position': '2010400',
#   'half': '1',
#   'confidence': '5.932918611506466e-06'},
#  {'gameTime': '1 - 34:8',
#   'label': 'Penalty',
#   'position': '2048361',
#   'half': '1',
#   'confidence': '5.625093763228506e-06'},
#  {'gameTime': '1 - 42:1',
#   'label': 'Penalty',
#   'position': '2521580',
#   'half': '1',
#   'confidence': '5.153246547706658e-06'},
#  {'gameTime': '1 - 17:8',
#   'label': 'Penalty',
#   'position': '1028601',
#   'half': '1',
#   'confidence': '4.2976043914677575e-06'},
#  {'gameTime': '1 - 26:46',
#   'label': 'Penalty',
#   'position': '1606344',
#   'half': '1',
#   'confidence': '4.111650468985317e-06'},
#  {'gameTime': '1 - 21:26',
#   'label': 'Penalty',
#   'position': '1286011',
#   'half': '1',
#   'confidence': '4.075551260029897e-06'},
#  {'gameTime': '1 - 31:55',
#   'label': 'Penalty',
#   'position': '1915756',
#   'half': '1',
#   'confidence': '3.916938567272155e-06'},
#  {'gameTime': '1 - 18:9',
#   'label': 'Penalty',
#   'position': '1089443',
#   'half': '1',
#   'confidence': '3.887476395902922e-06'},
#  {'gameTime': '1 - 28:37',
#   'label': 'Penalty',
#   'position': '1717108',
#   'half': '1',
#   'confidence': '3.861596269416623e-06'},
#  {'gameTime': '1 - 33:45',
#   'label': 'Penalty',
#   'position': '2025481',
#   'half': '1',
#   'confidence': '3.6488938803813653e-06'},
#  {'gameTime': '1 - 41:18',
#   'label': 'Penalty',
#   'position': '2478419',
#   'half': '1',
#   'confidence': '3.5223577015131013e-06'},
#  {'gameTime': '1 - 21:46',
#   'label': 'Penalty',
#   'position': '1306292',
#   'half': '1',
#   'confidence': '3.4798113119904883e-06'},
#  {'gameTime': '1 - 36:38',
#   'label': 'Penalty',
#   'position': '2198647',
#   'half': '1',
#   'confidence': '3.382047452760162e-06'},
#  {'gameTime': '1 - 7:48',
#   'label': 'Penalty',
#   'position': '468018',
#   'half': '1',
#   'confidence': '3.0268301998148672e-06'},
#  {'gameTime': '1 - 5:6',
#   'label': 'Penalty',
#   'position': '306292',
#   'half': '1',
#   'confidence': '2.7916216822632123e-06'},
#  {'gameTime': '1 - 11:7',
#   'label': 'Penalty',
#   'position': '667186',
#   'half': '1',
#   'confidence': '2.6499724299355876e-06'},
#  {'gameTime': '1 - 9:3',
#   'label': 'Penalty',
#   'position': '543941',
#   'half': '1',
#   'confidence': '2.6226664431305835e-06'},
#  {'gameTime': '1 - 22:58',
#   'label': 'Penalty',
#   'position': '1378055',
#   'half': '1',
#   'confidence': '2.5294418719568057e-06'},
#  {'gameTime': '1 - 4:42',
#   'label': 'Penalty',
#   'position': '282891',
#   'half': '1',
#   'confidence': '2.3841766960686073e-06'},
#  {'gameTime': '1 - 27:48',
#   'label': 'Penalty',
#   'position': '1668746',
#   'half': '1',
#   'confidence': '2.345197572140023e-06'},
#  {'gameTime': '1 - 30:47',
#   'label': 'Penalty',
#   'position': '1847633',
#   'half': '1',
#   'confidence': '2.1436253518913873e-06'},
#  {'gameTime': '1 - 36:21',
#   'label': 'Penalty',
#   'position': '2181487',
#   'half': '1',
#   'confidence': '2.0048969417985063e-06'},
#  {'gameTime': '1 - 42:18',
#   'label': 'Penalty',
#   'position': '2538221',
#   'half': '1',
#   'confidence': '1.9507976958266227e-06'},
#  {'gameTime': '1 - 6:48',
#   'label': 'Penalty',
#   'position': '408216',
#   'half': '1',
#   'confidence': '1.9326432720845332e-06'},
#  {'gameTime': '1 - 42:36',
#   'label': 'Penalty',
#   'position': '2556422',
#   'half': '1',
#   'confidence': '1.9179508399247425e-06'},
#  {'gameTime': '1 - 43:6',
#   'label': 'Penalty',
#   'position': '2586063',
#   'half': '1',
#   'confidence': '1.915961775011965e-06'},
#  {'gameTime': '1 - 0:49',
#   'label': 'Penalty',
#   'position': '49401',
#   'half': '1',
#   'confidence': '1.7866428834167891e-06'},
#  {'gameTime': '1 - 32:27',
#   'label': 'Penalty',
#   'position': '1947997',
#   'half': '1',
#   'confidence': '1.6853056195031968e-06'},
#  {'gameTime': '1 - 8:44',
#   'label': 'Penalty',
#   'position': '524700',
#   'half': '1',
#   'confidence': '1.4972005146773881e-06'},
#  {'gameTime': '1 - 28:59',
#   'label': 'Penalty',
#   'position': '1739989',
#   'half': '1',
#   'confidence': '1.4790507520956453e-06'},
#  {'gameTime': '1 - 37:50',
#   'label': 'Penalty',
#   'position': '2270930',
#   'half': '1',
#   'confidence': '1.3700657746085199e-06'},
#  {'gameTime': '1 - 16:41',
#   'label': 'Penalty',
#   'position': '1001560',
#   'half': '1',
#   'confidence': '1.356179495815013e-06'},
#  {'gameTime': '1 - 12:56',
#   'label': 'Penalty',
#   'position': '776911',
#   'half': '1',
#   'confidence': '1.3466643622450647e-06'},
#  {'gameTime': '1 - 17:48',
#   'label': 'Penalty',
#   'position': '1068642',
#   'half': '1',
#   'confidence': '1.3101167724016705e-06'},
#  {'gameTime': '1 - 19:1',
#   'label': 'Penalty',
#   'position': '1141965',
#   'half': '1',
#   'confidence': '1.1971452522629988e-06'},
#  {'gameTime': '1 - 25:2',
#   'label': 'Penalty',
#   'position': '1502340',
#   'half': '1',
#   'confidence': '1.1116666200905456e-06'},
#  {'gameTime': '1 - 33:12',
#   'label': 'Penalty',
#   'position': '1992199',
#   'half': '1',
#   'confidence': '1.11045437733992e-06'},
#  {'gameTime': '1 - 12:11',
#   'label': 'Penalty',
#   'position': '731669',
#   'half': '1',
#   'confidence': '1.0901474070124095e-06'},
#  {'gameTime': '1 - 29:34',
#   'label': 'Penalty',
#   'position': '1774830',
#   'half': '1',
#   'confidence': '1.044776468006603e-06'},
#  {'gameTime': '1 - 31:19',
#   'label': 'Penalty',
#   'position': '1879355',
#   'half': '1',
#   'confidence': '8.027275271160761e-07'},
#  {'gameTime': '1 - 2:43',
#   'label': 'Penalty',
#   'position': '163806',
#   'half': '1',
#   'confidence': '7.713662171227043e-07'},
#  {'gameTime': '1 - 11:37',
#   'label': 'Penalty',
#   'position': '697867',
#   'half': '1',
#   'confidence': '7.038436251605162e-07'},
#  {'gameTime': '1 - 7:5',
#   'label': 'Penalty',
#   'position': '425897',
#   'half': '1',
#   'confidence': '7.032558642094955e-07'},
#  {'gameTime': '1 - 27:6',
#   'label': 'Penalty',
#   'position': '1626625',
#   'half': '1',
#   'confidence': '6.73763963732199e-07'},
#  {'gameTime': '1 - 20:12',
#   'label': 'Penalty',
#   'position': '1212168',
#   'half': '1',
#   'confidence': '6.553515277119004e-07'},
#  {'gameTime': '1 - 15:1',
#   'label': 'Penalty',
#   'position': '901196',
#   'half': '1',
#   'confidence': '6.355229515975225e-07'},
#  {'gameTime': '1 - 27:25',
#   'label': 'Penalty',
#   'position': '1645345',
#   'half': '1',
#   'confidence': '5.882152436242905e-07'},
#  {'gameTime': '1 - 37:15',
#   'label': 'Penalty',
#   'position': '2235569',
#   'half': '1',
#   'confidence': '5.734565888815268e-07'},
#  {'gameTime': '1 - 3:9',
#   'label': 'Penalty',
#   'position': '189287',
#   'half': '1',
#   'confidence': '5.019396098759898e-07'},
#  {'gameTime': '1 - 12:27',
#   'label': 'Penalty',
#   'position': '747269',
#   'half': '1',
#   'confidence': '4.936325694870902e-07'},
#  {'gameTime': '1 - 44:26',
#   'label': 'Penalty',
#   'position': '2666666',
#   'half': '1',
#   'confidence': '4.883014526058105e-07'},
#  {'gameTime': '1 - 14:33',
#   'label': 'Penalty',
#   'position': '873634',
#   'half': '1',
#   'confidence': '4.773385171574773e-07'},
#  {'gameTime': '1 - 23:48',
#   'label': 'Penalty',
#   'position': '1428497',
#   'half': '1',
#   'confidence': '4.266273094799544e-07'},
#  {'gameTime': '1 - 8:24',
#   'label': 'Penalty',
#   'position': '504420',
#   'half': '1',
#   'confidence': '3.652256168606982e-07'},
#  {'gameTime': '1 - 0:7',
#   'label': 'Penalty',
#   'position': '7280',
#   'half': '1',
#   'confidence': '3.5695987321560096e-07'},
#  {'gameTime': '1 - 20:51',
#   'label': 'Penalty',
#   'position': '1251690',
#   'half': '1',
#   'confidence': '3.2694592277948686e-07'},
#  {'gameTime': '1 - 35:15',
#   'label': 'Penalty',
#   'position': '2115444',
#   'half': '1',
#   'confidence': '3.2486352097294e-07'},
#  {'gameTime': '1 - 15:22',
#   'label': 'Penalty',
#   'position': '922516',
#   'half': '1',
#   'confidence': '3.1687596901974757e-07'},
#  {'gameTime': '1 - 10:2',
#   'label': 'Penalty',
#   'position': '602704',
#   'half': '1',
#   'confidence': '3.099677030604653e-07'},
#  {'gameTime': '1 - 38:50',
#   'label': 'Penalty',
#   'position': '2330213',
#   'half': '1',
#   'confidence': '2.377645813567142e-07'},
#  {'gameTime': '1 - 10:24',
#   'label': 'Penalty',
#   'position': '624544',
#   'half': '1',
#   'confidence': '2.1295301166901481e-07'},
#  {'gameTime': '1 - 6:31',
#   'label': 'Penalty',
#   'position': '391055',
#   'half': '1',
#   'confidence': '2.0499209085755865e-07'},
#  {'gameTime': '1 - 0:22',
#   'label': 'Penalty',
#   'position': '22880',
#   'half': '1',
#   'confidence': '1.8243747490487294e-07'},
#  {'gameTime': '1 - 16:2',
#   'label': 'Penalty',
#   'position': '962038',
#   'half': '1',
#   'confidence': '1.7458199863540358e-07'},
#  {'gameTime': '1 - 18:28',
#   'label': 'Penalty',
#   'position': '1108164',
#   'half': '1',
#   'confidence': '1.6675706149271718e-07'},
#  {'gameTime': '1 - 24:24',
#   'label': 'Penalty',
#   'position': '1464898',
#   'half': '1',
#   'confidence': '1.6399835089941917e-07'},
#  {'gameTime': '1 - 19:24',
#   'label': 'Penalty',
#   'position': '1164326',
#   'half': '1',
#   'confidence': '1.1587322745754136e-07'},
#  {'gameTime': '1 - 3:37',
#   'label': 'Penalty',
#   'position': '217888',
#   'half': '1',
#   'confidence': '1.1533499844063044e-07'},
#  {'gameTime': '1 - 31:2',
#   'label': 'Penalty',
#   'position': '1862194',
#   'half': '1',
#   'confidence': '1.0914523329574877e-07'},
#  {'gameTime': '1 - 18:43',
#   'label': 'Penalty',
#   'position': '1123764',
#   'half': '1',
#   'confidence': '1.0567366359737207e-07'},
#  {'gameTime': '1 - 32:45',
#   'label': 'Penalty',
#   'position': '1965158',
#   'half': '1',
#   'confidence': '1.0244431081218863e-07'},
#  {'gameTime': '1 - 36:56',
#   'label': 'Penalty',
#   'position': '2216328',
#   'half': '1',
#   'confidence': '1.0175434539405614e-07'},
#  {'gameTime': '1 - 2:12',
#   'label': 'Penalty',
#   'position': '132085',
#   'half': '1',
#   'confidence': '8.509016424795846e-08'},
#  {'gameTime': '1 - 22:9',
#   'label': 'Penalty',
#   'position': '1329693',
#   'half': '1',
#   'confidence': '6.796594220759289e-08'},
#  {'gameTime': '1 - 43:48',
#   'label': 'Penalty',
#   'position': '2628185',
#   'half': '1',
#   'confidence': '5.804936975550845e-08'},
#  {'gameTime': '1 - 23:15',
#   'label': 'Penalty',
#   'position': '1395215',
#   'half': '1',
#   'confidence': '5.797820890052208e-08'},
#  {'gameTime': '1 - 39:4',
#   'label': 'Penalty',
#   'position': '2344773',
#   'half': '1',
#   'confidence': '5.388703172570786e-08'},
#  {'gameTime': '1 - 11:52',
#   'label': 'Penalty',
#   'position': '712948',
#   'half': '1',
#   'confidence': '5.291082416647441e-08'},
#  {'gameTime': '1 - 7:28',
#   'label': 'Penalty',
#   'position': '448777',
#   'half': '1',
#   'confidence': '4.822605248477885e-08'},
#  {'gameTime': '1 - 24:39',
#   'label': 'Penalty',
#   'position': '1479459',
#   'half': '1',
#   'confidence': '4.121021390801616e-08'},
#  {'gameTime': '1 - 31:40',
#   'label': 'Penalty',
#   'position': '1900156',
#   'half': '1',
#   'confidence': '2.6992371005007953e-08'},
#  {'gameTime': '1 - 40:14',
#   'label': 'Penalty',
#   'position': '2414976',
#   'half': '1',
#   'confidence': '2.0753322615973957e-08'},
#  {'gameTime': '1 - 22:27',
#   'label': 'Penalty',
#   'position': '1347893',
#   'half': '1',
#   'confidence': '2.0212535645214302e-08'},
#  {'gameTime': '1 - 26:13',
#   'label': 'Penalty',
#   'position': '1573582',
#   'half': '1',
#   'confidence': '1.548499106718282e-08'},
#  {'gameTime': '1 - 1:3',
#   'label': 'Penalty',
#   'position': '63962',
#   'half': '1',
#   'confidence': '1.2838928142855366e-08'},
#  {'gameTime': '1 - 2:26',
#   'label': 'Penalty',
#   'position': '146645',
#   'half': '1',
#   'confidence': '3.837588025135119e-09'},
#  {'gameTime': '1 - 0:3',
#   'label': 'Kick-off',
#   'position': '3640',
#   'half': '1',
#   'confidence': '0.8227239847183228'},
#  {'gameTime': '1 - 34:32',
#   'label': 'Kick-off',
#   'position': '2072282',
#   'half': '1',
#   'confidence': '0.629787266254425'},
#  {'gameTime': '1 - 30:32',
#   'label': 'Kick-off',
#   'position': '1832553',
#   'half': '1',
#   'confidence': '0.563677191734314'},
#  {'gameTime': '1 - 30:10',
#   'label': 'Kick-off',
#   'position': '1810712',
#   'half': '1',
#   'confidence': '0.17333339154720306'},
#  {'gameTime': '1 - 40:48',
#   'label': 'Kick-off',
#   'position': '2448257',
#   'half': '1',
#   'confidence': '0.1327262818813324'},
#  {'gameTime': '1 - 37:51',
#   'label': 'Kick-off',
#   'position': '2271450',
#   'half': '1',
#   'confidence': '0.1071808859705925'},
#  {'gameTime': '1 - 29:51',
#   'label': 'Kick-off',
#   'position': '1791471',
#   'half': '1',
#   'confidence': '0.025893084704875946'},
#  {'gameTime': '1 - 29:23',
#   'label': 'Kick-off',
#   'position': '1763390',
#   'half': '1',
#   'confidence': '0.023289820179343224'},
#  {'gameTime': '1 - 32:20',
#   'label': 'Kick-off',
#   'position': '1940717',
#   'half': '1',
#   'confidence': '0.017049934715032578'},
#  {'gameTime': '1 - 17:11',
#   'label': 'Kick-off',
#   'position': '1031201',
#   'half': '1',
#   'confidence': '0.016889099031686783'},
#  {'gameTime': '1 - 1:48',
#   'label': 'Kick-off',
#   'position': '108164',
#   'half': '1',
#   'confidence': '0.016105707734823227'},
#  {'gameTime': '1 - 34:47',
#   'label': 'Kick-off',
#   'position': '2087363',
#   'half': '1',
#   'confidence': '0.015975814312696457'},
#  {'gameTime': '1 - 21:46',
#   'label': 'Kick-off',
#   'position': '1306812',
#   'half': '1',
#   'confidence': '0.01215140987187624'},
#  {'gameTime': '1 - 8:57',
#   'label': 'Kick-off',
#   'position': '537701',
#   'half': '1',
#   'confidence': '0.010846549645066261'},
#  {'gameTime': '1 - 36:35',
#   'label': 'Kick-off',
#   'position': '2195527',
#   'half': '1',
#   'confidence': '0.010215315967798233'},
#  {'gameTime': '1 - 21:31',
#   'label': 'Kick-off',
#   'position': '1291211',
#   'half': '1',
#   'confidence': '0.01012840773910284'},
#  {'gameTime': '1 - 13:30',
#   'label': 'Kick-off',
#   'position': '810192',
#   'half': '1',
#   'confidence': '0.009231092408299446'},
#  {'gameTime': '1 - 25:51',
#   'label': 'Kick-off',
#   'position': '1551222',
#   'half': '1',
#   'confidence': '0.008768356405198574'},
#  {'gameTime': '1 - 10:21',
#   'label': 'Kick-off',
#   'position': '621944',
#   'half': '1',
#   'confidence': '0.008733829483389854'},
#  {'gameTime': '1 - 5:44',
#   'label': 'Kick-off',
#   'position': '344253',
#   'half': '1',
#   'confidence': '0.008678598329424858'},
#  {'gameTime': '1 - 1:28',
#   'label': 'Kick-off',
#   'position': '88403',
#   'half': '1',
#   'confidence': '0.008590775541961193'},
#  {'gameTime': '1 - 37:12',
#   'label': 'Kick-off',
#   'position': '2232449',
#   'half': '1',
#   'confidence': '0.008585833944380283'},
#  {'gameTime': '1 - 38:23',
#   'label': 'Kick-off',
#   'position': '2303692',
#   'half': '1',
#   'confidence': '0.008439830504357815'},
#  {'gameTime': '1 - 14:22',
#   'label': 'Kick-off',
#   'position': '862714',
#   'half': '1',
#   'confidence': '0.008417521603405476'},
#  {'gameTime': '1 - 26:7',
#   'label': 'Kick-off',
#   'position': '1567342',
#   'half': '1',
#   'confidence': '0.008370599709451199'},
#  {'gameTime': '1 - 41:9',
#   'label': 'Kick-off',
#   'position': '2469578',
#   'half': '1',
#   'confidence': '0.006670542526990175'},
#  {'gameTime': '1 - 26:21',
#   'label': 'Kick-off',
#   'position': '1581903',
#   'half': '1',
#   'confidence': '0.006417859811335802'},
#  {'gameTime': '1 - 9:33',
#   'label': 'Kick-off',
#   'position': '573062',
#   'half': '1',
#   'confidence': '0.005785392597317696'},
#  {'gameTime': '1 - 34:2',
#   'label': 'Kick-off',
#   'position': '2042121',
#   'half': '1',
#   'confidence': '0.005684868898242712'},
#  {'gameTime': '1 - 11:7',
#   'label': 'Kick-off',
#   'position': '667706',
#   'half': '1',
#   'confidence': '0.005298256874084473'},
#  {'gameTime': '1 - 29:7',
#   'label': 'Kick-off',
#   'position': '1747269',
#   'half': '1',
#   'confidence': '0.004964878316968679'},
#  {'gameTime': '1 - 39:31',
#   'label': 'Kick-off',
#   'position': '2371814',
#   'half': '1',
#   'confidence': '0.004683171398937702'},
#  {'gameTime': '1 - 5:25',
#   'label': 'Kick-off',
#   'position': '325013',
#   'half': '1',
#   'confidence': '0.004503646399825811'},
#  {'gameTime': '1 - 41:25',
#   'label': 'Kick-off',
#   'position': '2485699',
#   'half': '1',
#   'confidence': '0.0041840155608952045'},
#  {'gameTime': '1 - 28:40',
#   'label': 'Kick-off',
#   'position': '1720228',
#   'half': '1',
#   'confidence': '0.004044514615088701'},
#  {'gameTime': '1 - 16:55',
#   'label': 'Kick-off',
#   'position': '1015080',
#   'half': '1',
#   'confidence': '0.0037464171182364225'},
#  {'gameTime': '1 - 36:5',
#   'label': 'Kick-off',
#   'position': '2165366',
#   'half': '1',
#   'confidence': '0.003691013203933835'},
#  {'gameTime': '1 - 12:11',
#   'label': 'Kick-off',
#   'position': '731669',
#   'half': '1',
#   'confidence': '0.00357580604031682'},
#  {'gameTime': '1 - 44:47',
#   'label': 'Kick-off',
#   'position': '2687467',
#   'half': '1',
#   'confidence': '0.0033732042647898197'},
#  {'gameTime': '1 - 19:59',
#   'label': 'Kick-off',
#   'position': '1199167',
#   'half': '1',
#   'confidence': '0.003367007477208972'},
#  {'gameTime': '1 - 31:56',
#   'label': 'Kick-off',
#   'position': '1916276',
#   'half': '1',
#   'confidence': '0.003273556474596262'},
#  {'gameTime': '1 - 11:22',
#   'label': 'Kick-off',
#   'position': '682787',
#   'half': '1',
#   'confidence': '0.0031570664141327143'},
#  {'gameTime': '1 - 16:15',
#   'label': 'Kick-off',
#   'position': '975559',
#   'half': '1',
#   'confidence': '0.0030603851191699505'},
#  {'gameTime': '1 - 6:5',
#   'label': 'Kick-off',
#   'position': '365054',
#   'half': '1',
#   'confidence': '0.003030788851901889'},
#  {'gameTime': '1 - 19:1',
#   'label': 'Kick-off',
#   'position': '1141445',
#   'half': '1',
#   'confidence': '0.0029256967827677727'},
#  {'gameTime': '1 - 42:15',
#   'label': 'Kick-off',
#   'position': '2535101',
#   'half': '1',
#   'confidence': '0.0026359541807323694'},
#  {'gameTime': '1 - 24:24',
#   'label': 'Kick-off',
#   'position': '1464378',
#   'half': '1',
#   'confidence': '0.0022800355218350887'},
#  {'gameTime': '1 - 13:58',
#   'label': 'Kick-off',
#   'position': '838273',
#   'half': '1',
#   'confidence': '0.00217813509516418'},
#  {'gameTime': '1 - 15:53',
#   'label': 'Kick-off',
#   'position': '953198',
#   'half': '1',
#   'confidence': '0.0021771518513560295'},
#  {'gameTime': '1 - 35:2',
#   'label': 'Kick-off',
#   'position': '2102964',
#   'half': '1',
#   'confidence': '0.0019417374860495329'},
#  {'gameTime': '1 - 23:37',
#   'label': 'Kick-off',
#   'position': '1417056',
#   'half': '1',
#   'confidence': '0.001932341605424881'},
#  {'gameTime': '1 - 27:49',
#   'label': 'Kick-off',
#   'position': '1669786',
#   'half': '1',
#   'confidence': '0.0018806663574650884'},
#  {'gameTime': '1 - 20:57',
#   'label': 'Kick-off',
#   'position': '1257410',
#   'half': '1',
#   'confidence': '0.0017975567607209086'},
#  {'gameTime': '1 - 41:47',
#   'label': 'Kick-off',
#   'position': '2507540',
#   'half': '1',
#   'confidence': '0.001777368364855647'},
#  {'gameTime': '1 - 24:52',
#   'label': 'Kick-off',
#   'position': '1492979',
#   'half': '1',
#   'confidence': '0.0017125607701018453'},
#  {'gameTime': '1 - 5:8',
#   'label': 'Kick-off',
#   'position': '308372',
#   'half': '1',
#   'confidence': '0.0015293930191546679'},
#  {'gameTime': '1 - 3:24',
#   'label': 'Kick-off',
#   'position': '204888',
#   'half': '1',
#   'confidence': '0.0013225121656432748'},
#  {'gameTime': '1 - 43:23',
#   'label': 'Kick-off',
#   'position': '2603224',
#   'half': '1',
#   'confidence': '0.0013013564748689532'},
#  {'gameTime': '1 - 35:47',
#   'label': 'Kick-off',
#   'position': '2147685',
#   'half': '1',
#   'confidence': '0.0012880837311968207'},
#  {'gameTime': '1 - 42:59',
#   'label': 'Kick-off',
#   'position': '2579303',
#   'half': '1',
#   'confidence': '0.001269470783881843'},
#  {'gameTime': '1 - 4:16',
#   'label': 'Kick-off',
#   'position': '256370',
#   'half': '1',
#   'confidence': '0.0012398260878399014'},
#  {'gameTime': '1 - 15:22',
#   'label': 'Kick-off',
#   'position': '922516',
#   'half': '1',
#   'confidence': '0.0012281062081456184'},
#  {'gameTime': '1 - 28:18',
#   'label': 'Kick-off',
#   'position': '1698387',
#   'half': '1',
#   'confidence': '0.0011426650453358889'},
#  {'gameTime': '1 - 35:28',
#   'label': 'Kick-off',
#   'position': '2128965',
#   'half': '1',
#   'confidence': '0.001130438526161015'},
#  {'gameTime': '1 - 22:59',
#   'label': 'Kick-off',
#   'position': '1379615',
#   'half': '1',
#   'confidence': '0.001101760077290237'},
#  {'gameTime': '1 - 30:47',
#   'label': 'Kick-off',
#   'position': '1847633',
#   'half': '1',
#   'confidence': '0.0010126680135726929'},
#  {'gameTime': '1 - 37:35',
#   'label': 'Kick-off',
#   'position': '2255850',
#   'half': '1',
#   'confidence': '0.0009953409899026155'},
#  {'gameTime': '1 - 40:16',
#   'label': 'Kick-off',
#   'position': '2416016',
#   'half': '1',
#   'confidence': '0.0009647483821026981'},
#  {'gameTime': '1 - 3:45',
#   'label': 'Kick-off',
#   'position': '225689',
#   'half': '1',
#   'confidence': '0.0009419210837222636'},
#  {'gameTime': '1 - 23:56',
#   'label': 'Kick-off',
#   'position': '1436297',
#   'half': '1',
#   'confidence': '0.0009035221301019192'},
#  {'gameTime': '1 - 33:32',
#   'label': 'Kick-off',
#   'position': '2012480',
#   'half': '1',
#   'confidence': '0.0008739245240576565'},
#  {'gameTime': '1 - 17:32',
#   'label': 'Kick-off',
#   'position': '1052522',
#   'half': '1',
#   'confidence': '0.0008436550269834697'},
#  {'gameTime': '1 - 27:27',
#   'label': 'Kick-off',
#   'position': '1647425',
#   'half': '1',
#   'confidence': '0.0008210606756620109'},
#  {'gameTime': '1 - 7:1',
#   'label': 'Kick-off',
#   'position': '421216',
#   'half': '1',
#   'confidence': '0.000816616287920624'},
#  {'gameTime': '1 - 21:13',
#   'label': 'Kick-off',
#   'position': '1273530',
#   'half': '1',
#   'confidence': '0.0007731980876997113'},
#  {'gameTime': '1 - 11:45',
#   'label': 'Kick-off',
#   'position': '705668',
#   'half': '1',
#   'confidence': '0.00069490319583565'},
#  {'gameTime': '1 - 32:58',
#   'label': 'Kick-off',
#   'position': '1978679',
#   'half': '1',
#   'confidence': '0.0006912588141858578'},
#  {'gameTime': '1 - 22:39',
#   'label': 'Kick-off',
#   'position': '1359334',
#   'half': '1',
#   'confidence': '0.0006894788239151239'},
#  {'gameTime': '1 - 12:56',
#   'label': 'Kick-off',
#   'position': '776911',
#   'half': '1',
#   'confidence': '0.0006642569787800312'},
#  {'gameTime': '1 - 15:5',
#   'label': 'Kick-off',
#   'position': '905356',
#   'half': '1',
#   'confidence': '0.000663356448058039'},
#  {'gameTime': '1 - 8:33',
#   'label': 'Kick-off',
#   'position': '513260',
#   'half': '1',
#   'confidence': '0.0006571455160155892'},
#  {'gameTime': '1 - 27:9',
#   'label': 'Kick-off',
#   'position': '1629745',
#   'half': '1',
#   'confidence': '0.000656111107673496'},
#  {'gameTime': '1 - 44:12',
#   'label': 'Kick-off',
#   'position': '2652106',
#   'half': '1',
#   'confidence': '0.000653033668641001'},
#  {'gameTime': '1 - 43:48',
#   'label': 'Kick-off',
#   'position': '2628705',
#   'half': '1',
#   'confidence': '0.0006442570011131465'},
#  {'gameTime': '1 - 19:29',
#   'label': 'Kick-off',
#   'position': '1169006',
#   'half': '1',
#   'confidence': '0.0006337744416669011'},
#  {'gameTime': '1 - 38:7',
#   'label': 'Kick-off',
#   'position': '2287571',
#   'half': '1',
#   'confidence': '0.0006290921592153609'},
#  {'gameTime': '1 - 0:50',
#   'label': 'Kick-off',
#   'position': '50442',
#   'half': '1',
#   'confidence': '0.000606427900493145'},
#  {'gameTime': '1 - 20:32',
#   'label': 'Kick-off',
#   'position': '1232969',
#   'half': '1',
#   'confidence': '0.0006013694801367819'},
#  {'gameTime': '1 - 4:40',
#   'label': 'Kick-off',
#   'position': '280811',
#   'half': '1',
#   'confidence': '0.0005983536248095334'},
#  {'gameTime': '1 - 9:17',
#   'label': 'Kick-off',
#   'position': '557462',
#   'half': '1',
#   'confidence': '0.0005917498492635787'},
#  {'gameTime': '1 - 40:31',
#   'label': 'Kick-off',
#   'position': '2431097',
#   'half': '1',
#   'confidence': '0.0005796288605779409'},
#  {'gameTime': '1 - 42:36',
#   'label': 'Kick-off',
#   'position': '2556942',
#   'half': '1',
#   'confidence': '0.0005782708758488297'},
#  {'gameTime': '1 - 18:23',
#   'label': 'Kick-off',
#   'position': '1103484',
#   'half': '1',
#   'confidence': '0.0005321222124621272'},
#  {'gameTime': '1 - 39:57',
#   'label': 'Kick-off',
#   'position': '2397815',
#   'half': '1',
#   'confidence': '0.0004934347234666348'},
#  {'gameTime': '1 - 17:53',
#   'label': 'Kick-off',
#   'position': '1073842',
#   'half': '1',
#   'confidence': '0.000437448441516608'},
#  {'gameTime': '1 - 10:39',
#   'label': 'Kick-off',
#   'position': '639105',
#   'half': '1',
#   'confidence': '0.0004231007187627256'},
#  {'gameTime': '1 - 39:16',
#   'label': 'Kick-off',
#   'position': '2356214',
#   'half': '1',
#   'confidence': '0.00042274920269846916'},
#  {'gameTime': '1 - 33:16',
#   'label': 'Kick-off',
#   'position': '1996359',
#   'half': '1',
#   'confidence': '0.0004175201174803078'},
#  {'gameTime': '1 - 25:8',
#   'label': 'Kick-off',
#   'position': '1508580',
#   'half': '1',
#   'confidence': '0.0004083089006599039'},
#  {'gameTime': '1 - 12:30',
#   'label': 'Kick-off',
#   'position': '750910',
#   'half': '1',
#   'confidence': '0.00037627865094691515'},
#  {'gameTime': '1 - 9:50',
#   'label': 'Kick-off',
#   'position': '590223',
#   'half': '1',
#   'confidence': '0.0003699893713928759'},
#  {'gameTime': '1 - 16:30',
#   'label': 'Kick-off',
#   'position': '990639',
#   'half': '1',
#   'confidence': '0.0003538327000569552'},
#  {'gameTime': '1 - 31:35',
#   'label': 'Kick-off',
#   'position': '1895995',
#   'half': '1',
#   'confidence': '0.00033114408142864704'},
#  {'gameTime': '1 - 8:16',
#   'label': 'Kick-off',
#   'position': '496099',
#   'half': '1',
#   'confidence': '0.00031615799525752664'},
#  {'gameTime': '1 - 6:24',
#   'label': 'Kick-off',
#   'position': '384295',
#   'half': '1',
#   'confidence': '0.0003137429303023964'},
#  {'gameTime': '1 - 2:57',
#   'label': 'Kick-off',
#   'position': '177847',
#   'half': '1',
#   'confidence': '0.0003078096779063344'},
#  {'gameTime': '1 - 31:12',
#   'label': 'Kick-off',
#   'position': '1872074',
#   'half': '1',
#   'confidence': '0.0002785642573144287'},
#  {'gameTime': '1 - 20:13',
#   'label': 'Kick-off',
#   'position': '1213728',
#   'half': '1',
#   'confidence': '0.00027119959122501314'},
#  {'gameTime': '1 - 38:57',
#   'label': 'Kick-off',
#   'position': '2337493',
#   'half': '1',
#   'confidence': '0.00024115829728543758'},
#  {'gameTime': '1 - 18:39',
#   'label': 'Kick-off',
#   'position': '1119084',
#   'half': '1',
#   'confidence': '0.00023904898262117058'},
#  {'gameTime': '1 - 25:26',
#   'label': 'Kick-off',
#   'position': '1526781',
#   'half': '1',
#   'confidence': '0.00022650562459602952'},
#  {'gameTime': '1 - 0:25',
#   'label': 'Kick-off',
#   'position': '25481',
#   'half': '1',
#   'confidence': '0.00022129480203147978'},
#  {'gameTime': '1 - 32:39',
#   'label': 'Kick-off',
#   'position': '1959958',
#   'half': '1',
#   'confidence': '0.00020066714205313474'},
#  {'gameTime': '1 - 2:24',
#   'label': 'Kick-off',
#   'position': '144045',
#   'half': '1',
#   'confidence': '0.00019429464009590447'},
#  {'gameTime': '1 - 7:32',
#   'label': 'Kick-off',
#   'position': '452418',
#   'half': '1',
#   'confidence': '0.0001938085915753618'},
#  {'gameTime': '1 - 7:46',
#   'label': 'Kick-off',
#   'position': '466978',
#   'half': '1',
#   'confidence': '0.00019342736050020903'},
#  {'gameTime': '1 - 6:39',
#   'label': 'Kick-off',
#   'position': '399895',
#   'half': '1',
#   'confidence': '0.00019228048040531576'},
#  {'gameTime': '1 - 23:18',
#   'label': 'Kick-off',
#   'position': '1398855',
#   'half': '1',
#   'confidence': '0.00019096951291430742'},
#  {'gameTime': '1 - 7:16',
#   'label': 'Kick-off',
#   'position': '436297',
#   'half': '1',
#   'confidence': '0.00018881635332945734'},
#  {'gameTime': '1 - 10:5',
#   'label': 'Kick-off',
#   'position': '605824',
#   'half': '1',
#   'confidence': '0.00016584937111474574'},
#  {'gameTime': '1 - 36:19',
#   'label': 'Kick-off',
#   'position': '2179927',
#   'half': '1',
#   'confidence': '0.00015806304872967303'},
#  {'gameTime': '1 - 26:52',
#   'label': 'Kick-off',
#   'position': '1612064',
#   'half': '1',
#   'confidence': '0.00013651321933139116'},
#  {'gameTime': '1 - 2:5',
#   'label': 'Kick-off',
#   'position': '125325',
#   'half': '1',
#   'confidence': '0.00012974855781067163'},
#  {'gameTime': '1 - 1:12',
#   'label': 'Kick-off',
#   'position': '72802',
#   'half': '1',
#   'confidence': '0.00012280659575480968'},
#  {'gameTime': '1 - 14:49',
#   'label': 'Kick-off',
#   'position': '889755',
#   'half': '1',
#   'confidence': '0.00012232543667778373'},
#  {'gameTime': '1 - 38:38',
#   'label': 'Kick-off',
#   'position': '2318772',
#   'half': '1',
#   'confidence': '9.834517550189048e-05'},
#  {'gameTime': '1 - 13:11',
#   'label': 'Kick-off',
#   'position': '791991',
#   'half': '1',
#   'confidence': '9.475518891122192e-05'},
#  {'gameTime': '1 - 22:11',
#   'label': 'Kick-off',
#   'position': '1331253',
#   'half': '1',
#   'confidence': '9.316405339632183e-05'},
#  {'gameTime': '1 - 36:56',
#   'label': 'Kick-off',
#   'position': '2216848',
#   'half': '1',
#   'confidence': '9.218664490617812e-05'},
#  {'gameTime': '1 - 2:39',
#   'label': 'Kick-off',
#   'position': '159126',
#   'half': '1',
#   'confidence': '7.783703040331602e-05'},
#  {'gameTime': '1 - 15:37',
#   'label': 'Kick-off',
#   'position': '937077',
#   'half': '1',
#   'confidence': '7.634700159542263e-05'},
#  {'gameTime': '1 - 44:26',
#   'label': 'Kick-off',
#   'position': '2666666',
#   'half': '1',
#   'confidence': '6.247621058719233e-05'},
#  {'gameTime': '1 - 19:43',
#   'label': 'Kick-off',
#   'position': '1183567',
#   'half': '1',
#   'confidence': '4.737475683214143e-05'},
#  {'gameTime': '1 - 34:16',
#   'label': 'Kick-off',
#   'position': '2056682',
#   'half': '1',
#   'confidence': '4.5446122385328636e-05'},
#  {'gameTime': '1 - 26:36',
#   'label': 'Kick-off',
#   'position': '1596463',
#   'half': '1',
#   'confidence': '3.065117562073283e-05'},
#  {'gameTime': '1 - 4:0',
#   'label': 'Kick-off',
#   'position': '240249',
#   'half': '1',
#   'confidence': '1.3445391232380643e-05'},
#  {'gameTime': '1 - 29:18',
#   'label': 'Goal',
#   'position': '1758710',
#   'half': '1',
#   'confidence': '0.9090672731399536'},
#  {'gameTime': '1 - 38:9',
#   'label': 'Goal',
#   'position': '2289131',
#   'half': '1',
#   'confidence': '0.6094940304756165'},
#  {'gameTime': '1 - 34:39',
#   'label': 'Goal',
#   'position': '2079043',
#   'half': '1',
#   'confidence': '0.31079378724098206'},
#  {'gameTime': '1 - 14:16',
#   'label': 'Goal',
#   'position': '856474',
#   'half': '1',
#   'confidence': '0.07277961075305939'},
#  {'gameTime': '1 - 1:44',
#   'label': 'Goal',
#   'position': '104004',
#   'half': '1',
#   'confidence': '0.03936433419585228'},
#  {'gameTime': '1 - 34:17',
#   'label': 'Goal',
#   'position': '2057722',
#   'half': '1',
#   'confidence': '0.025584500283002853'},
#  {'gameTime': '1 - 17:30',
#   'label': 'Goal',
#   'position': '1050962',
#   'half': '1',
#   'confidence': '0.013703158125281334'},
#  {'gameTime': '1 - 8:45',
#   'label': 'Goal',
#   'position': '525221',
#   'half': '1',
#   'confidence': '0.012913712300360203'},
#  {'gameTime': '1 - 42:14',
#   'label': 'Goal',
#   'position': '2534061',
#   'half': '1',
#   'confidence': '0.012075785547494888'},
#  {'gameTime': '1 - 32:6',
#   'label': 'Goal',
#   'position': '1926677',
#   'half': '1',
#   'confidence': '0.008597568608820438'},
#  {'gameTime': '1 - 21:11',
#   'label': 'Goal',
#   'position': '1271970',
#   'half': '1',
#   'confidence': '0.0074130697175860405'},
#  {'gameTime': '1 - 37:31',
#   'label': 'Goal',
#   'position': '2251690',
#   'half': '1',
#   'confidence': '0.005706348456442356'},
#  {'gameTime': '1 - 43:8',
#   'label': 'Goal',
#   'position': '2588143',
#   'half': '1',
#   'confidence': '0.003967789933085442'},
#  {'gameTime': '1 - 5:36',
#   'label': 'Goal',
#   'position': '336973',
#   'half': '1',
#   'confidence': '0.003585884580388665'},
#  {'gameTime': '1 - 40:56',
#   'label': 'Goal',
#   'position': '2456058',
#   'half': '1',
#   'confidence': '0.0028360930737107992'},
#  {'gameTime': '1 - 9:23',
#   'label': 'Goal',
#   'position': '563702',
#   'half': '1',
#   'confidence': '0.0022442257031798363'},
#  {'gameTime': '1 - 44:47',
#   'label': 'Goal',
#   'position': '2687987',
#   'half': '1',
#   'confidence': '0.0020196845289319754'},
#  {'gameTime': '1 - 19:34',
#   'label': 'Goal',
#   'position': '1174206',
#   'half': '1',
#   'confidence': '0.0020168167538940907'},
#  {'gameTime': '1 - 44:16',
#   'label': 'Goal',
#   'position': '2656786',
#   'half': '1',
#   'confidence': '0.001652008737437427'},
#  {'gameTime': '1 - 25:31',
#   'label': 'Goal',
#   'position': '1531461',
#   'half': '1',
#   'confidence': '0.0015455348184332252'},
#  {'gameTime': '1 - 33:29',
#   'label': 'Goal',
#   'position': '2009360',
#   'half': '1',
#   'confidence': '0.0010780113516375422'},
#  {'gameTime': '1 - 16:12',
#   'label': 'Goal',
#   'position': '972438',
#   'half': '1',
#   'confidence': '0.0009277274366468191'},
#  {'gameTime': '1 - 3:43',
#   'label': 'Goal',
#   'position': '223088',
#   'half': '1',
#   'confidence': '0.0007455943268723786'},
#  {'gameTime': '1 - 29:50',
#   'label': 'Goal',
#   'position': '1790951',
#   'half': '1',
#   'confidence': '0.0006795339286327362'},
#  {'gameTime': '1 - 26:26',
#   'label': 'Goal',
#   'position': '1586583',
#   'half': '1',
#   'confidence': '0.0006724072736687958'},
#  {'gameTime': '1 - 41:15',
#   'label': 'Goal',
#   'position': '2475819',
#   'half': '1',
#   'confidence': '0.0005738334730267525'},
#  {'gameTime': '1 - 15:30',
#   'label': 'Goal',
#   'position': '930317',
#   'half': '1',
#   'confidence': '0.000489833066239953'},
#  {'gameTime': '1 - 15:44',
#   'label': 'Goal',
#   'position': '944877',
#   'half': '1',
#   'confidence': '0.00047896517207846045'},
#  {'gameTime': '1 - 10:42',
#   'label': 'Goal',
#   'position': '642225',
#   'half': '1',
#   'confidence': '0.00044775637798011303'},
#  {'gameTime': '1 - 38:28',
#   'label': 'Goal',
#   'position': '2308372',
#   'half': '1',
#   'confidence': '0.0004414842987898737'},
#  {'gameTime': '1 - 9:47',
#   'label': 'Goal',
#   'position': '587103',
#   'half': '1',
#   'confidence': '0.00041037981281988323'},
#  {'gameTime': '1 - 16:38',
#   'label': 'Goal',
#   'position': '998959',
#   'half': '1',
#   'confidence': '0.0003943475312553346'},
#  {'gameTime': '1 - 41:33',
#   'label': 'Goal',
#   'position': '2493499',
#   'half': '1',
#   'confidence': '0.0003608142433222383'},
#  {'gameTime': '1 - 34:59',
#   'label': 'Goal',
#   'position': '2099843',
#   'half': '1',
#   'confidence': '0.00034077579039148986'},
#  {'gameTime': '1 - 6:50',
#   'label': 'Goal',
#   'position': '410816',
#   'half': '1',
#   'confidence': '0.00033324796822853386'},
#  {'gameTime': '1 - 4:38',
#   'label': 'Goal',
#   'position': '278211',
#   'half': '1',
#   'confidence': '0.0003299233503639698'},
#  {'gameTime': '1 - 33:43',
#   'label': 'Goal',
#   'position': '2023920',
#   'half': '1',
#   'confidence': '0.0003243402752559632'},
#  {'gameTime': '1 - 4:7',
#   'label': 'Goal',
#   'position': '247009',
#   'half': '1',
#   'confidence': '0.00031307036988437176'},
#  {'gameTime': '1 - 36:27',
#   'label': 'Goal',
#   'position': '2187727',
#   'half': '1',
#   'confidence': '0.00030803101253695786'},
#  {'gameTime': '1 - 30:5',
#   'label': 'Goal',
#   'position': '1805512',
#   'half': '1',
#   'confidence': '0.0003075087442994118'},
#  {'gameTime': '1 - 12:54',
#   'label': 'Goal',
#   'position': '774310',
#   'half': '1',
#   'confidence': '0.00030402810079976916'},
#  {'gameTime': '1 - 31:8',
#   'label': 'Goal',
#   'position': '1868434',
#   'half': '1',
#   'confidence': '0.00030231926939450204'},
#  {'gameTime': '1 - 7:48',
#   'label': 'Goal',
#   'position': '468018',
#   'half': '1',
#   'confidence': '0.00030203579808585346'},
#  {'gameTime': '1 - 34:0',
#   'label': 'Goal',
#   'position': '2040561',
#   'half': '1',
#   'confidence': '0.00030136475106701255'},
#  {'gameTime': '1 - 5:16',
#   'label': 'Goal',
#   'position': '316692',
#   'half': '1',
#   'confidence': '0.00029723692568950355'},
#  {'gameTime': '1 - 17:58',
#   'label': 'Goal',
#   'position': '1078523',
#   'half': '1',
#   'confidence': '0.00027374905766919255'},
#  {'gameTime': '1 - 30:50',
#   'label': 'Goal',
#   'position': '1850234',
#   'half': '1',
#   'confidence': '0.0002667322987690568'},
#  {'gameTime': '1 - 1:21',
#   'label': 'Goal',
#   'position': '81123',
#   'half': '1',
#   'confidence': '0.0002658498124219477'},
#  {'gameTime': '1 - 39:25',
#   'label': 'Goal',
#   'position': '2365054',
#   'half': '1',
#   'confidence': '0.00024741774541325867'},
#  {'gameTime': '1 - 12:11',
#   'label': 'Goal',
#   'position': '731669',
#   'half': '1',
#   'confidence': '0.0002419929951429367'},
#  {'gameTime': '1 - 31:51',
#   'label': 'Goal',
#   'position': '1911076',
#   'half': '1',
#   'confidence': '0.000229759156354703'},
#  {'gameTime': '1 - 41:58',
#   'label': 'Goal',
#   'position': '2518460',
#   'half': '1',
#   'confidence': '0.00021565129281952977'},
#  {'gameTime': '1 - 21:26',
#   'label': 'Goal',
#   'position': '1286531',
#   'half': '1',
#   'confidence': '0.0002151041990146041'},
#  {'gameTime': '1 - 13:18',
#   'label': 'Goal',
#   'position': '798751',
#   'half': '1',
#   'confidence': '0.00021336387726478279'},
#  {'gameTime': '1 - 23:30',
#   'label': 'Goal',
#   'position': '1410816',
#   'half': '1',
#   'confidence': '0.0002060569095192477'},
#  {'gameTime': '1 - 22:36',
#   'label': 'Goal',
#   'position': '1356734',
#   'half': '1',
#   'confidence': '0.00020022391981910914'},
#  {'gameTime': '1 - 12:28',
#   'label': 'Goal',
#   'position': '748829',
#   'half': '1',
#   'confidence': '0.00019515224266797304'},
#  {'gameTime': '1 - 8:2',
#   'label': 'Goal',
#   'position': '482579',
#   'half': '1',
#   'confidence': '0.00017641260637901723'},
#  {'gameTime': '1 - 27:30',
#   'label': 'Goal',
#   'position': '1650546',
#   'half': '1',
#   'confidence': '0.00017357326578348875'},
#  {'gameTime': '1 - 28:5',
#   'label': 'Goal',
#   'position': '1685387',
#   'half': '1',
#   'confidence': '0.00017337262397632003'},
#  {'gameTime': '1 - 43:31',
#   'label': 'Goal',
#   'position': '2611544',
#   'half': '1',
#   'confidence': '0.00016604765551164746'},
#  {'gameTime': '1 - 30:24',
#   'label': 'Goal',
#   'position': '1824232',
#   'half': '1',
#   'confidence': '0.00016471043636556715'},
#  {'gameTime': '1 - 20:31',
#   'label': 'Goal',
#   'position': '1231409',
#   'half': '1',
#   'confidence': '0.0001644739240873605'},
#  {'gameTime': '1 - 24:6',
#   'label': 'Goal',
#   'position': '1446177',
#   'half': '1',
#   'confidence': '0.00015156911103986204'},
#  {'gameTime': '1 - 40:24',
#   'label': 'Goal',
#   'position': '2424336',
#   'half': '1',
#   'confidence': '0.00014305865624919534'},
#  {'gameTime': '1 - 19:3',
#   'label': 'Goal',
#   'position': '1143525',
#   'half': '1',
#   'confidence': '0.00014285213546827435'},
#  {'gameTime': '1 - 0:6',
#   'label': 'Goal',
#   'position': '6760',
#   'half': '1',
#   'confidence': '0.00014221973833628'},
#  {'gameTime': '1 - 19:57',
#   'label': 'Goal',
#   'position': '1197087',
#   'half': '1',
#   'confidence': '0.00013913899601902813'},
#  {'gameTime': '1 - 26:49',
#   'label': 'Goal',
#   'position': '1609464',
#   'half': '1',
#   'confidence': '0.00013182483962737024'},
#  {'gameTime': '1 - 11:9',
#   'label': 'Goal',
#   'position': '669266',
#   'half': '1',
#   'confidence': '0.0001260751741938293'},
#  {'gameTime': '1 - 11:24',
#   'label': 'Goal',
#   'position': '684347',
#   'half': '1',
#   'confidence': '0.00011371633445378393'},
#  {'gameTime': '1 - 42:29',
#   'label': 'Goal',
#   'position': '2549141',
#   'half': '1',
#   'confidence': '0.00011114363587694243'},
#  {'gameTime': '1 - 13:37',
#   'label': 'Goal',
#   'position': '817992',
#   'half': '1',
#   'confidence': '0.00011052050831494853'},
#  {'gameTime': '1 - 26:3',
#   'label': 'Goal',
#   'position': '1563182',
#   'half': '1',
#   'confidence': '0.00010869906691368669'},
#  {'gameTime': '1 - 3:10',
#   'label': 'Goal',
#   'position': '190327',
#   'half': '1',
#   'confidence': '0.00010562811075942591'},
#  {'gameTime': '1 - 9:7',
#   'label': 'Goal',
#   'position': '547581',
#   'half': '1',
#   'confidence': '0.00010300935537088662'},
#  {'gameTime': '1 - 27:47',
#   'label': 'Goal',
#   'position': '1667706',
#   'half': '1',
#   'confidence': '0.0001021096104523167'},
#  {'gameTime': '1 - 8:29',
#   'label': 'Goal',
#   'position': '509100',
#   'half': '1',
#   'confidence': '0.00010162343096453696'},
#  {'gameTime': '1 - 10:2',
#   'label': 'Goal',
#   'position': '602704',
#   'half': '1',
#   'confidence': '0.00010106679837917909'},
#  {'gameTime': '1 - 15:8',
#   'label': 'Goal',
#   'position': '908476',
#   'half': '1',
#   'confidence': '9.904018952511251e-05'},
#  {'gameTime': '1 - 29:33',
#   'label': 'Goal',
#   'position': '1773270',
#   'half': '1',
#   'confidence': '9.616952593205497e-05'},
#  {'gameTime': '1 - 39:52',
#   'label': 'Goal',
#   'position': '2392615',
#   'half': '1',
#   'confidence': '9.599645272828639e-05'},
#  {'gameTime': '1 - 13:58',
#   'label': 'Goal',
#   'position': '838273',
#   'half': '1',
#   'confidence': '9.480200969846919e-05'},
#  {'gameTime': '1 - 20:54',
#   'label': 'Goal',
#   'position': '1254810',
#   'half': '1',
#   'confidence': '8.030910248635337e-05'},
#  {'gameTime': '1 - 25:47',
#   'label': 'Goal',
#   'position': '1547581',
#   'half': '1',
#   'confidence': '7.99008848844096e-05'},
#  {'gameTime': '1 - 21:45',
#   'label': 'Goal',
#   'position': '1305772',
#   'half': '1',
#   'confidence': '7.829724927432835e-05'},
#  {'gameTime': '1 - 0:44',
#   'label': 'Goal',
#   'position': '44201',
#   'half': '1',
#   'confidence': '7.718282722635195e-05'},
#  {'gameTime': '1 - 25:2',
#   'label': 'Goal',
#   'position': '1502860',
#   'half': '1',
#   'confidence': '7.283099694177508e-05'},
#  {'gameTime': '1 - 2:44',
#   'label': 'Goal',
#   'position': '164326',
#   'half': '1',
#   'confidence': '7.127947174012661e-05'},
#  {'gameTime': '1 - 10:18',
#   'label': 'Goal',
#   'position': '618824',
#   'half': '1',
#   'confidence': '6.6319880716037e-05'},
#  {'gameTime': '1 - 44:1',
#   'label': 'Goal',
#   'position': '2641185',
#   'half': '1',
#   'confidence': '6.070903327781707e-05'},
#  {'gameTime': '1 - 23:3',
#   'label': 'Goal',
#   'position': '1383775',
#   'half': '1',
#   'confidence': '5.818252611788921e-05'},
#  {'gameTime': '1 - 32:34',
#   'label': 'Goal',
#   'position': '1954238',
#   'half': '1',
#   'confidence': '5.723249341826886e-05'},
#  {'gameTime': '1 - 35:38',
#   'label': 'Goal',
#   'position': '2138845',
#   'half': '1',
#   'confidence': '5.5531647376483306e-05'},
#  {'gameTime': '1 - 5:52',
#   'label': 'Goal',
#   'position': '352054',
#   'half': '1',
#   'confidence': '5.307887477101758e-05'},
#  {'gameTime': '1 - 7:28',
#   'label': 'Goal',
#   'position': '448777',
#   'half': '1',
#   'confidence': '5.012598921894096e-05'},
#  {'gameTime': '1 - 36:46',
#   'label': 'Goal',
#   'position': '2206448',
#   'half': '1',
# ...
#   'label': 'Shots off target',
#   'position': '1057202',
#   'half': '1',
#   'confidence': '0.0022092924918979406'},
#  {'gameTime': '1 - 40:24',
#   'label': 'Shots off target',
#   'position': '2424856',
#   'half': '1',
#   'confidence': '0.002095369156450033'},
#  {'gameTime': '1 - 25:2',
#   'label': 'Shots off target',
#   'position': '1502340',
#   'half': '1',
#   'confidence': '0.0019253058126196265'},
#  {'gameTime': '1 - 5:54',
#   'label': 'Shots off target',
#   'position': '354134',
#   'half': '1',
#   'confidence': '0.0018758998485282063'},
#  {'gameTime': '1 - 20:42',
#   'label': 'Shots off target',
#   'position': '1242329',
#   'half': '1',
#   'confidence': '0.0017919904785230756'},
#  {'gameTime': '1 - 8:29',
#   'label': 'Shots off target',
#   'position': '509100',
#   'half': '1',
#   'confidence': '0.0017308968817815185'},
#  {'gameTime': '1 - 3:3',
#   'label': 'Shots off target',
#   'position': '183047',
#   'half': '1',
#   'confidence': '0.001659207628108561'},
#  {'gameTime': '1 - 24:11',
#   'label': 'Shots off target',
#   'position': '1451898',
#   'half': '1',
#   'confidence': '0.0016379341250285506'},
#  {'gameTime': '1 - 13:52',
#   'label': 'Shots off target',
#   'position': '832033',
#   'half': '1',
#   'confidence': '0.0015604529762640595'},
#  {'gameTime': '1 - 13:29',
#   'label': 'Shots off target',
#   'position': '809152',
#   'half': '1',
#   'confidence': '0.001554868184030056'},
#  {'gameTime': '1 - 25:53',
#   'label': 'Shots off target',
#   'position': '1553302',
#   'half': '1',
#   'confidence': '0.0015540317399427295'},
#  {'gameTime': '1 - 38:28',
#   'label': 'Shots off target',
#   'position': '2308892',
#   'half': '1',
#   'confidence': '0.0015514835249632597'},
#  {'gameTime': '1 - 27:27',
#   'label': 'Shots off target',
#   'position': '1647425',
#   'half': '1',
#   'confidence': '0.0015316192293539643'},
#  {'gameTime': '1 - 39:17',
#   'label': 'Shots off target',
#   'position': '2357774',
#   'half': '1',
#   'confidence': '0.0013910095440223813'},
#  {'gameTime': '1 - 16:1',
#   'label': 'Shots off target',
#   'position': '961518',
#   'half': '1',
#   'confidence': '0.001333844382315874'},
#  {'gameTime': '1 - 39:51',
#   'label': 'Shots off target',
#   'position': '2391575',
#   'half': '1',
#   'confidence': '0.0013081601355224848'},
#  {'gameTime': '1 - 12:10',
#   'label': 'Shots off target',
#   'position': '730629',
#   'half': '1',
#   'confidence': '0.0012807260500267148'},
#  {'gameTime': '1 - 12:43',
#   'label': 'Shots off target',
#   'position': '763390',
#   'half': '1',
#   'confidence': '0.0012426954926922917'},
#  {'gameTime': '1 - 36:39',
#   'label': 'Shots off target',
#   'position': '2199167',
#   'half': '1',
#   'confidence': '0.0010525144170969725'},
#  {'gameTime': '1 - 1:14',
#   'label': 'Shots off target',
#   'position': '74362',
#   'half': '1',
#   'confidence': '0.0010414797579869628'},
#  {'gameTime': '1 - 36:56',
#   'label': 'Shots off target',
#   'position': '2216848',
#   'half': '1',
#   'confidence': '0.001028487109579146'},
#  {'gameTime': '1 - 34:3',
#   'label': 'Shots off target',
#   'position': '2043681',
#   'half': '1',
#   'confidence': '0.0010138897923752666'},
#  {'gameTime': '1 - 30:28',
#   'label': 'Shots off target',
#   'position': '1828913',
#   'half': '1',
#   'confidence': '0.000990096596069634'},
#  {'gameTime': '1 - 8:4',
#   'label': 'Shots off target',
#   'position': '484659',
#   'half': '1',
#   'confidence': '0.0009872763184830546'},
#  {'gameTime': '1 - 29:50',
#   'label': 'Shots off target',
#   'position': '1790951',
#   'half': '1',
#   'confidence': '0.000978777534328401'},
#  {'gameTime': '1 - 4:0',
#   'label': 'Shots off target',
#   'position': '240769',
#   'half': '1',
#   'confidence': '0.0009108111844398081'},
#  {'gameTime': '1 - 6:49',
#   'label': 'Shots off target',
#   'position': '409256',
#   'half': '1',
#   'confidence': '0.0008758084732107818'},
#  {'gameTime': '1 - 18:51',
#   'label': 'Shots off target',
#   'position': '1131045',
#   'half': '1',
#   'confidence': '0.0008695757132954895'},
#  {'gameTime': '1 - 31:22',
#   'label': 'Shots off target',
#   'position': '1882995',
#   'half': '1',
#   'confidence': '0.0008564427844248712'},
#  {'gameTime': '1 - 36:1',
#   'label': 'Shots off target',
#   'position': '2161206',
#   'half': '1',
#   'confidence': '0.000845964124891907'},
#  {'gameTime': '1 - 14:37',
#   'label': 'Shots off target',
#   'position': '877275',
#   'half': '1',
#   'confidence': '0.000720368989277631'},
#  {'gameTime': '1 - 5:21',
#   'label': 'Shots off target',
#   'position': '321892',
#   'half': '1',
#   'confidence': '0.000717215589247644'},
#  {'gameTime': '1 - 38:43',
#   'label': 'Shots off target',
#   'position': '2323452',
#   'half': '1',
#   'confidence': '0.0007167116855271161'},
#  {'gameTime': '1 - 4:28',
#   'label': 'Shots off target',
#   'position': '268850',
#   'half': '1',
#   'confidence': '0.0007043156656436622'},
#  {'gameTime': '1 - 7:6',
#   'label': 'Shots off target',
#   'position': '426417',
#   'half': '1',
#   'confidence': '0.0006988478708080947'},
#  {'gameTime': '1 - 16:20',
#   'label': 'Shots off target',
#   'position': '980759',
#   'half': '1',
#   'confidence': '0.0006831337814219296'},
#  {'gameTime': '1 - 9:7',
#   'label': 'Shots off target',
#   'position': '547581',
#   'half': '1',
#   'confidence': '0.0006519936141557992'},
#  {'gameTime': '1 - 1:54',
#   'label': 'Shots off target',
#   'position': '114404',
#   'half': '1',
#   'confidence': '0.0006429814384318888'},
#  {'gameTime': '1 - 0:24',
#   'label': 'Shots off target',
#   'position': '24960',
#   'half': '1',
#   'confidence': '0.0006429079221561551'},
#  {'gameTime': '1 - 43:46',
#   'label': 'Shots off target',
#   'position': '2626625',
#   'half': '1',
#   'confidence': '0.0006416545948013663'},
#  {'gameTime': '1 - 20:6',
#   'label': 'Shots off target',
#   'position': '1206968',
#   'half': '1',
#   'confidence': '0.0006166996899992228'},
#  {'gameTime': '1 - 17:0',
#   'label': 'Shots off target',
#   'position': '1020800',
#   'half': '1',
#   'confidence': '0.0005952098872512579'},
#  {'gameTime': '1 - 23:0',
#   'label': 'Shots off target',
#   'position': '1380135',
#   'half': '1',
#   'confidence': '0.0005904931458644569'},
#  {'gameTime': '1 - 10:30',
#   'label': 'Shots off target',
#   'position': '630265',
#   'half': '1',
#   'confidence': '0.0005450786557048559'},
#  {'gameTime': '1 - 24:38',
#   'label': 'Shots off target',
#   'position': '1478419',
#   'half': '1',
#   'confidence': '0.0005405974225141108'},
#  {'gameTime': '1 - 28:22',
#   'label': 'Shots off target',
#   'position': '1702028',
#   'half': '1',
#   'confidence': '0.0005041143740527332'},
#  {'gameTime': '1 - 10:5',
#   'label': 'Shots off target',
#   'position': '605304',
#   'half': '1',
#   'confidence': '0.0005035822978243232'},
#  {'gameTime': '1 - 30:9',
#   'label': 'Shots off target',
#   'position': '1809152',
#   'half': '1',
#   'confidence': '0.0004809626843780279'},
#  {'gameTime': '1 - 37:11',
#   'label': 'Shots off target',
#   'position': '2231409',
#   'half': '1',
#   'confidence': '0.0004679793491959572'},
#  {'gameTime': '1 - 40:52',
#   'label': 'Shots off target',
#   'position': '2452938',
#   'half': '1',
#   'confidence': '0.00046739549725316465'},
#  {'gameTime': '1 - 19:7',
#   'label': 'Shots off target',
#   'position': '1147685',
#   'half': '1',
#   'confidence': '0.0004497823538258672'},
#  {'gameTime': '1 - 31:5',
#   'label': 'Shots off target',
#   'position': '1865314',
#   'half': '1',
#   'confidence': '0.00044816648005507886'},
#  {'gameTime': '1 - 33:17',
#   'label': 'Shots off target',
#   'position': '1997399',
#   'half': '1',
#   'confidence': '0.0004459525807760656'},
#  {'gameTime': '1 - 22:9',
#   'label': 'Shots off target',
#   'position': '1329173',
#   'half': '1',
#   'confidence': '0.00041225561290048063'},
#  {'gameTime': '1 - 41:51',
#   'label': 'Shots off target',
#   'position': '2511700',
#   'half': '1',
#   'confidence': '0.00041183611028827727'},
#  {'gameTime': '1 - 2:11',
#   'label': 'Shots off target',
#   'position': '131565',
#   'half': '1',
#   'confidence': '0.00039925420423969626'},
#  {'gameTime': '1 - 0:55',
#   'label': 'Shots off target',
#   'position': '55122',
#   'half': '1',
#   'confidence': '0.0003855795366689563'},
#  {'gameTime': '1 - 21:40',
#   'label': 'Shots off target',
#   'position': '1300572',
#   'half': '1',
#   'confidence': '0.0003830556233879179'},
#  {'gameTime': '1 - 34:56',
#   'label': 'Shots off target',
#   'position': '2096723',
#   'half': '1',
#   'confidence': '0.00036708300467580557'},
#  {'gameTime': '1 - 42:52',
#   'label': 'Shots off target',
#   'position': '2572542',
#   'half': '1',
#   'confidence': '0.00036028370959684253'},
#  {'gameTime': '1 - 11:1',
#   'label': 'Shots off target',
#   'position': '661466',
#   'half': '1',
#   'confidence': '0.00035861131618730724'},
#  {'gameTime': '1 - 19:49',
#   'label': 'Shots off target',
#   'position': '1189287',
#   'half': '1',
#   'confidence': '0.00033578777220100164'},
#  {'gameTime': '1 - 23:53',
#   'label': 'Shots off target',
#   'position': '1433177',
#   'half': '1',
#   'confidence': '0.00031297365785576403'},
#  {'gameTime': '1 - 44:32',
#   'label': 'Shots off target',
#   'position': '2672386',
#   'half': '1',
#   'confidence': '0.00031154623138718307'},
#  {'gameTime': '1 - 11:40',
#   'label': 'Shots off target',
#   'position': '700468',
#   'half': '1',
#   'confidence': '0.0002996009134221822'},
#  {'gameTime': '1 - 29:34',
#   'label': 'Shots off target',
#   'position': '1774310',
#   'half': '1',
#   'confidence': '0.00028831601957790554'},
#  {'gameTime': '1 - 3:22',
#   'label': 'Shots off target',
#   'position': '202808',
#   'half': '1',
#   'confidence': '0.0002553311933297664'},
#  {'gameTime': '1 - 15:20',
#   'label': 'Shots off target',
#   'position': '920956',
#   'half': '1',
#   'confidence': '0.00025468520470894873'},
#  {'gameTime': '1 - 14:51',
#   'label': 'Shots off target',
#   'position': '891835',
#   'half': '1',
#   'confidence': '0.00023909934679977596'},
#  {'gameTime': '1 - 18:28',
#   'label': 'Shots off target',
#   'position': '1108164',
#   'half': '1',
#   'confidence': '0.0002045621076831594'},
#  {'gameTime': '1 - 6:31',
#   'label': 'Shots off target',
#   'position': '391055',
#   'half': '1',
#   'confidence': '0.00019485493248794228'},
#  {'gameTime': '1 - 35:45',
#   'label': 'Shots off target',
#   'position': '2145605',
#   'half': '1',
#   'confidence': '0.00018301146337762475'},
#  {'gameTime': '1 - 27:48',
#   'label': 'Shots off target',
#   'position': '1668226',
#   'half': '1',
#   'confidence': '0.00018169646500609815'},
#  {'gameTime': '1 - 2:26',
#   'label': 'Shots off target',
#   'position': '146645',
#   'half': '1',
#   'confidence': '0.00017526243755128235'},
#  {'gameTime': '1 - 7:33',
#   'label': 'Shots off target',
#   'position': '453458',
#   'half': '1',
#   'confidence': '0.0001659691333770752'},
#  {'gameTime': '1 - 17:18',
#   'label': 'Shots off target',
#   'position': '1038481',
#   'half': '1',
#   'confidence': '0.00016460225742775947'},
#  {'gameTime': '1 - 39:2',
#   'label': 'Shots off target',
#   'position': '2342173',
#   'half': '1',
#   'confidence': '0.00014983040455263108'},
#  {'gameTime': '1 - 11:55',
#   'label': 'Shots off target',
#   'position': '715028',
#   'half': '1',
#   'confidence': '0.00014721274783369154'},
#  {'gameTime': '1 - 29:4',
#   'label': 'Shots off target',
#   'position': '1744149',
#   'half': '1',
#   'confidence': '0.0001448351686121896'},
#  {'gameTime': '1 - 32:56',
#   'label': 'Shots off target',
#   'position': '1976599',
#   'half': '1',
#   'confidence': '0.00013787453644908965'},
#  {'gameTime': '1 - 40:6',
#   'label': 'Shots off target',
#   'position': '2406136',
#   'half': '1',
#   'confidence': '0.00013238917745184153'},
#  {'gameTime': '1 - 26:11',
#   'label': 'Shots off target',
#   'position': '1571502',
#   'half': '1',
#   'confidence': '0.00012484440230764449'},
#  {'gameTime': '1 - 27:11',
#   'label': 'Shots off target',
#   'position': '1631825',
#   'half': '1',
#   'confidence': '0.0001185739747597836'},
#  {'gameTime': '1 - 23:37',
#   'label': 'Shots off target',
#   'position': '1417576',
#   'half': '1',
#   'confidence': '0.00011374842870282009'},
#  {'gameTime': '1 - 37:44',
#   'label': 'Shots off target',
#   'position': '2264170',
#   'half': '1',
#   'confidence': '9.1790861915797e-05'},
#  {'gameTime': '1 - 20:56',
#   'label': 'Shots off target',
#   'position': '1256890',
#   'half': '1',
#   'confidence': '6.821601709816605e-05'},
#  {'gameTime': '1 - 11:24',
#   'label': 'Clearance',
#   'position': '684867',
#   'half': '1',
#   'confidence': '0.9750975370407104'},
#  {'gameTime': '1 - 6:18',
#   'label': 'Clearance',
#   'position': '378055',
#   'half': '1',
#   'confidence': '0.9706430435180664'},
#  {'gameTime': '1 - 1:51',
#   'label': 'Clearance',
#   'position': '111284',
#   'half': '1',
#   'confidence': '0.8799745440483093'},
#  {'gameTime': '1 - 5:21',
#   'label': 'Clearance',
#   'position': '321892',
#   'half': '1',
#   'confidence': '0.46399787068367004'},
#  {'gameTime': '1 - 20:36',
#   'label': 'Clearance',
#   'position': '1236609',
#   'half': '1',
#   'confidence': '0.42479780316352844'},
#  {'gameTime': '1 - 38:32',
#   'label': 'Clearance',
#   'position': '2312532',
#   'half': '1',
#   'confidence': '0.4046156406402588'},
#  {'gameTime': '1 - 29:11',
#   'label': 'Clearance',
#   'position': '1751430',
#   'half': '1',
#   'confidence': '0.3016529977321625'},
#  {'gameTime': '1 - 39:30',
#   'label': 'Clearance',
#   'position': '2370254',
#   'half': '1',
#   'confidence': '0.23754319548606873'},
#  {'gameTime': '1 - 24:23',
#   'label': 'Clearance',
#   'position': '1463858',
#   'half': '1',
#   'confidence': '0.21078628301620483'},
#  {'gameTime': '1 - 34:51',
#   'label': 'Clearance',
#   'position': '2091003',
#   'half': '1',
#   'confidence': '0.21066686511039734'},
#  {'gameTime': '1 - 30:30',
#   'label': 'Clearance',
#   'position': '1830993',
#   'half': '1',
#   'confidence': '0.13228514790534973'},
#  {'gameTime': '1 - 36:36',
#   'label': 'Clearance',
#   'position': '2196047',
#   'half': '1',
#   'confidence': '0.12687426805496216'},
#  {'gameTime': '1 - 32:26',
#   'label': 'Clearance',
#   'position': '1946437',
#   'half': '1',
#   'confidence': '0.12113958597183228'},
#  {'gameTime': '1 - 28:16',
#   'label': 'Clearance',
#   'position': '1696307',
#   'half': '1',
#   'confidence': '0.11900512874126434'},
#  {'gameTime': '1 - 1:24',
#   'label': 'Clearance',
#   'position': '84243',
#   'half': '1',
#   'confidence': '0.09436103701591492'},
#  {'gameTime': '1 - 30:5',
#   'label': 'Clearance',
#   'position': '1805512',
#   'half': '1',
#   'confidence': '0.08777705579996109'},
#  {'gameTime': '1 - 37:50',
#   'label': 'Clearance',
#   'position': '2270930',
#   'half': '1',
#   'confidence': '0.08045782148838043'},
#  {'gameTime': '1 - 14:33',
#   'label': 'Clearance',
#   'position': '873114',
#   'half': '1',
#   'confidence': '0.06869011372327805'},
#  {'gameTime': '1 - 38:16',
#   'label': 'Clearance',
#   'position': '2296931',
#   'half': '1',
#   'confidence': '0.06468679755926132'},
#  {'gameTime': '1 - 0:4',
#   'label': 'Clearance',
#   'position': '4680',
#   'half': '1',
#   'confidence': '0.06449829787015915'},
#  {'gameTime': '1 - 23:33',
#   'label': 'Clearance',
#   'position': '1413416',
#   'half': '1',
#   'confidence': '0.06272400915622711'},
#  {'gameTime': '1 - 29:35',
#   'label': 'Clearance',
#   'position': '1775351',
#   'half': '1',
#   'confidence': '0.06232732534408569'},
#  {'gameTime': '1 - 25:51',
#   'label': 'Clearance',
#   'position': '1551222',
#   'half': '1',
#   'confidence': '0.050752900540828705'},
#  {'gameTime': '1 - 19:59',
#   'label': 'Clearance',
#   'position': '1199687',
#   'half': '1',
#   'confidence': '0.0488886795938015'},
#  {'gameTime': '1 - 28:38',
#   'label': 'Clearance',
#   'position': '1718668',
#   'half': '1',
#   'confidence': '0.04476385563611984'},
#  {'gameTime': '1 - 9:1',
#   'label': 'Clearance',
#   'position': '541341',
#   'half': '1',
#   'confidence': '0.04185491427779198'},
#  {'gameTime': '1 - 17:11',
#   'label': 'Clearance',
#   'position': '1031201',
#   'half': '1',
#   'confidence': '0.041681405156850815'},
#  {'gameTime': '1 - 21:48',
#   'label': 'Clearance',
#   'position': '1308372',
#   'half': '1',
#   'confidence': '0.03659975528717041'},
#  {'gameTime': '1 - 33:33',
#   'label': 'Clearance',
#   'position': '2013000',
#   'half': '1',
#   'confidence': '0.03462270274758339'},
#  {'gameTime': '1 - 40:46',
#   'label': 'Clearance',
#   'position': '2446177',
#   'half': '1',
#   'confidence': '0.0332154743373394'},
#  {'gameTime': '1 - 35:8',
#   'label': 'Clearance',
#   'position': '2108164',
#   'half': '1',
#   'confidence': '0.0300102811306715'},
#  ...]

# %%
data
# Out:
# {'UrlLocal': 'england_epl/2014-2015/2015-05-17 - 18-00 Manchester United 1 - 1 Arsenal',
#  'predictions': [{'gameTime': '1 - 14:16',
#    'label': 'Penalty',
#    'position': '856474',
#    'half': '1',
#    'confidence': '0.006846137344837189'},
#   {'gameTime': '1 - 1:45',
#    'label': 'Penalty',
#    'position': '105564',
#    'half': '1',
#    'confidence': '0.0015244742389768362'},
#   {'gameTime': '1 - 29:20',
#    'label': 'Penalty',
#    'position': '1760270',
#    'half': '1',
#    'confidence': '0.0011110763298347592'},
#   {'gameTime': '1 - 23:31',
#    'label': 'Penalty',
#    'position': '1411336',
#    'half': '1',
#    'confidence': '0.0006935555720701814'},
#   {'gameTime': '1 - 35:0',
#    'label': 'Penalty',
#    'position': '2100884',
#    'half': '1',
#    'confidence': '0.0006670397706329823'},
#   {'gameTime': '1 - 11:22',
#    'label': 'Penalty',
#    'position': '682787',
#    'half': '1',
#    'confidence': '0.0006399552221409976'},
#   {'gameTime': '1 - 39:29',
#    'label': 'Penalty',
#    'position': '2369214',
#    'half': '1',
#    'confidence': '0.0006146698724478483'},
#   {'gameTime': '1 - 1:21',
#    'label': 'Penalty',
#    'position': '81643',
#    'half': '1',
#    'confidence': '0.00026217332924716175'},
#   {'gameTime': '1 - 9:19',
#    'label': 'Penalty',
#    'position': '559542',
#    'half': '1',
#    'confidence': '0.0002607161004561931'},
#   {'gameTime': '1 - 15:42',
#    'label': 'Penalty',
#    'position': '942797',
#    'half': '1',
#    'confidence': '0.00023109978064894676'},
#   {'gameTime': '1 - 9:42',
#    'label': 'Penalty',
#    'position': '582943',
#    'half': '1',
#    'confidence': '0.0002201692695962265'},
#   {'gameTime': '1 - 5:21',
#    'label': 'Penalty',
#    'position': '321892',
#    'half': '1',
#    'confidence': '0.00021712335001211613'},
#   {'gameTime': '1 - 3:54',
#    'label': 'Penalty',
#    'position': '234529',
#    'half': '1',
#    'confidence': '0.00021032981749158353'},
#   {'gameTime': '1 - 40:56',
#    'label': 'Penalty',
#    'position': '2456578',
#    'half': '1',
#    'confidence': '0.00017056186334230006'},
#   {'gameTime': '1 - 8:8',
#    'label': 'Penalty',
#    'position': '488819',
#    'half': '1',
#    'confidence': '0.0001658522232901305'},
#   {'gameTime': '1 - 44:46',
#    'label': 'Penalty',
#    'position': '2686427',
#    'half': '1',
#    'confidence': '0.00015481443551834673'},
#   {'gameTime': '1 - 26:31',
#    'label': 'Penalty',
#    'position': '1591783',
#    'half': '1',
#    'confidence': '0.00012810734915547073'},
#   {'gameTime': '1 - 28:15',
#    'label': 'Penalty',
#    'position': '1695787',
#    'half': '1',
#    'confidence': '9.111769031733274e-05'},
#   {'gameTime': '1 - 16:22',
#    'label': 'Penalty',
#    'position': '982839',
#    'half': '1',
#    'confidence': '7.905145321274176e-05'},
#   {'gameTime': '1 - 41:35',
#    'label': 'Penalty',
#    'position': '2495059',
#    'half': '1',
#    'confidence': '6.409495836123824e-05'},
#   {'gameTime': '1 - 38:10',
#    'label': 'Penalty',
#    'position': '2290171',
#    'half': '1',
#    'confidence': '5.4397205531131476e-05'},
#   {'gameTime': '1 - 40:31',
#    'label': 'Penalty',
#    'position': '2431097',
#    'half': '1',
#    'confidence': '4.574222111841664e-05'},
#   {'gameTime': '1 - 19:57',
#    'label': 'Penalty',
#    'position': '1197607',
#    'half': '1',
#    'confidence': '3.9984228351386264e-05'},
#   {'gameTime': '1 - 6:15',
#    'label': 'Penalty',
#    'position': '375975',
#    'half': '1',
#    'confidence': '3.952312545152381e-05'},
#   {'gameTime': '1 - 34:23',
#    'label': 'Penalty',
#    'position': '2063962',
#    'half': '1',
#    'confidence': '3.459355502855033e-05'},
#   {'gameTime': '1 - 44:12',
#    'label': 'Penalty',
#    'position': '2652106',
#    'half': '1',
#    'confidence': '3.359121910762042e-05'},
#   {'gameTime': '1 - 25:59',
#    'label': 'Penalty',
#    'position': '1559022',
#    'half': '1',
#    'confidence': '2.507745193724986e-05'},
#   {'gameTime': '1 - 20:32',
#    'label': 'Penalty',
#    'position': '1232449',
#    'half': '1',
#    'confidence': '2.4249635316664353e-05'},
#   {'gameTime': '1 - 19:39',
#    'label': 'Penalty',
#    'position': '1179927',
#    'half': '1',
#    'confidence': '2.302145367139019e-05'},
#   {'gameTime': '1 - 37:34',
#    'label': 'Penalty',
#    'position': '2254290',
#    'half': '1',
#    'confidence': '2.1296254999469966e-05'},
#   {'gameTime': '1 - 38:30',
#    'label': 'Penalty',
#    'position': '2310452',
#    'half': '1',
#    'confidence': '1.910197352117393e-05'},
#   {'gameTime': '1 - 35:53',
#    'label': 'Penalty',
#    'position': '2153926',
#    'half': '1',
#    'confidence': '1.9088207409367897e-05'},
#   {'gameTime': '1 - 5:36',
#    'label': 'Penalty',
#    'position': '336453',
#    'half': '1',
#    'confidence': '1.7221009329659864e-05'},
#   {'gameTime': '1 - 13:17',
#    'label': 'Penalty',
#    'position': '797711',
#    'half': '1',
#    'confidence': '1.503171370131895e-05'},
#   {'gameTime': '1 - 13:46',
#    'label': 'Penalty',
#    'position': '826833',
#    'half': '1',
#    'confidence': '1.4186437510943506e-05'},
#   {'gameTime': '1 - 5:58',
#    'label': 'Penalty',
#    'position': '358294',
#    'half': '1',
#    'confidence': '1.369915025861701e-05'},
#   {'gameTime': '1 - 43:33',
#    'label': 'Penalty',
#    'position': '2613624',
#    'half': '1',
#    'confidence': '1.3588850379164796e-05'},
#   {'gameTime': '1 - 32:12',
#    'label': 'Penalty',
#    'position': '1932917',
#    'half': '1',
#    'confidence': '1.3441621376841795e-05'},
#   {'gameTime': '1 - 35:32',
#    'label': 'Penalty',
#    'position': '2132085',
#    'half': '1',
#    'confidence': '1.3093962479615584e-05'},
#   {'gameTime': '1 - 4:13',
#    'label': 'Penalty',
#    'position': '253770',
#    'half': '1',
#    'confidence': '1.258158044947777e-05'},
#   {'gameTime': '1 - 29:51',
#    'label': 'Penalty',
#    'position': '1791471',
#    'half': '1',
#    'confidence': '1.2444681487977505e-05'},
#   {'gameTime': '1 - 21:11',
#    'label': 'Penalty',
#    'position': '1271450',
#    'half': '1',
#    'confidence': '1.1246396752540022e-05'},
#   {'gameTime': '1 - 22:43',
#    'label': 'Penalty',
#    'position': '1363494',
#    'half': '1',
#    'confidence': '1.0647088856785558e-05'},
#   {'gameTime': '1 - 30:7',
#    'label': 'Penalty',
#    'position': '1807072',
#    'half': '1',
#    'confidence': '9.968386621039826e-06'},
#   {'gameTime': '1 - 17:32',
#    'label': 'Penalty',
#    'position': '1052002',
#    'half': '1',
#    'confidence': '9.342513294541277e-06'},
#   {'gameTime': '1 - 39:57',
#    'label': 'Penalty',
#    'position': '2397295',
#    'half': '1',
#    'confidence': '8.966480891103856e-06'},
#   {'gameTime': '1 - 34:39',
#    'label': 'Penalty',
#    'position': '2079043',
#    'half': '1',
#    'confidence': '7.488121354981558e-06'},
#   {'gameTime': '1 - 10:43',
#    'label': 'Penalty',
#    'position': '643265',
#    'half': '1',
#    'confidence': '7.447982625308214e-06'},
#   {'gameTime': '1 - 30:27',
#    'label': 'Penalty',
#    'position': '1827353',
#    'half': '1',
#    'confidence': '7.3791761678876355e-06'},
#   {'gameTime': '1 - 24:10',
#    'label': 'Penalty',
#    'position': '1450338',
#    'half': '1',
#    'confidence': '6.646652764175087e-06'},
#   {'gameTime': '1 - 25:30',
#    'label': 'Penalty',
#    'position': '1530941',
#    'half': '1',
#    'confidence': '6.135233434179099e-06'},
#   {'gameTime': '1 - 33:30',
#    'label': 'Penalty',
#    'position': '2010400',
#    'half': '1',
#    'confidence': '5.932918611506466e-06'},
#   {'gameTime': '1 - 34:8',
#    'label': 'Penalty',
#    'position': '2048361',
#    'half': '1',
#    'confidence': '5.625093763228506e-06'},
#   {'gameTime': '1 - 42:1',
#    'label': 'Penalty',
#    'position': '2521580',
#    'half': '1',
#    'confidence': '5.153246547706658e-06'},
#   {'gameTime': '1 - 17:8',
#    'label': 'Penalty',
#    'position': '1028601',
#    'half': '1',
#    'confidence': '4.2976043914677575e-06'},
#   {'gameTime': '1 - 26:46',
#    'label': 'Penalty',
#    'position': '1606344',
#    'half': '1',
#    'confidence': '4.111650468985317e-06'},
#   {'gameTime': '1 - 21:26',
#    'label': 'Penalty',
#    'position': '1286011',
#    'half': '1',
#    'confidence': '4.075551260029897e-06'},
#   {'gameTime': '1 - 31:55',
#    'label': 'Penalty',
#    'position': '1915756',
#    'half': '1',
#    'confidence': '3.916938567272155e-06'},
#   {'gameTime': '1 - 18:9',
#    'label': 'Penalty',
#    'position': '1089443',
#    'half': '1',
#    'confidence': '3.887476395902922e-06'},
#   {'gameTime': '1 - 28:37',
#    'label': 'Penalty',
#    'position': '1717108',
#    'half': '1',
#    'confidence': '3.861596269416623e-06'},
#   {'gameTime': '1 - 33:45',
#    'label': 'Penalty',
#    'position': '2025481',
#    'half': '1',
#    'confidence': '3.6488938803813653e-06'},
#   {'gameTime': '1 - 41:18',
#    'label': 'Penalty',
#    'position': '2478419',
#    'half': '1',
#    'confidence': '3.5223577015131013e-06'},
#   {'gameTime': '1 - 21:46',
#    'label': 'Penalty',
#    'position': '1306292',
#    'half': '1',
#    'confidence': '3.4798113119904883e-06'},
#   {'gameTime': '1 - 36:38',
#    'label': 'Penalty',
#    'position': '2198647',
#    'half': '1',
#    'confidence': '3.382047452760162e-06'},
#   {'gameTime': '1 - 7:48',
#    'label': 'Penalty',
#    'position': '468018',
#    'half': '1',
#    'confidence': '3.0268301998148672e-06'},
#   {'gameTime': '1 - 5:6',
#    'label': 'Penalty',
#    'position': '306292',
#    'half': '1',
#    'confidence': '2.7916216822632123e-06'},
#   {'gameTime': '1 - 11:7',
#    'label': 'Penalty',
#    'position': '667186',
#    'half': '1',
#    'confidence': '2.6499724299355876e-06'},
#   {'gameTime': '1 - 9:3',
#    'label': 'Penalty',
#    'position': '543941',
#    'half': '1',
#    'confidence': '2.6226664431305835e-06'},
#   {'gameTime': '1 - 22:58',
#    'label': 'Penalty',
#    'position': '1378055',
#    'half': '1',
#    'confidence': '2.5294418719568057e-06'},
#   {'gameTime': '1 - 4:42',
#    'label': 'Penalty',
#    'position': '282891',
#    'half': '1',
#    'confidence': '2.3841766960686073e-06'},
#   {'gameTime': '1 - 27:48',
#    'label': 'Penalty',
#    'position': '1668746',
#    'half': '1',
#    'confidence': '2.345197572140023e-06'},
#   {'gameTime': '1 - 30:47',
#    'label': 'Penalty',
#    'position': '1847633',
#    'half': '1',
#    'confidence': '2.1436253518913873e-06'},
#   {'gameTime': '1 - 36:21',
#    'label': 'Penalty',
#    'position': '2181487',
#    'half': '1',
#    'confidence': '2.0048969417985063e-06'},
#   {'gameTime': '1 - 42:18',
#    'label': 'Penalty',
#    'position': '2538221',
#    'half': '1',
#    'confidence': '1.9507976958266227e-06'},
#   {'gameTime': '1 - 6:48',
#    'label': 'Penalty',
#    'position': '408216',
#    'half': '1',
#    'confidence': '1.9326432720845332e-06'},
#   {'gameTime': '1 - 42:36',
#    'label': 'Penalty',
#    'position': '2556422',
#    'half': '1',
#    'confidence': '1.9179508399247425e-06'},
#   {'gameTime': '1 - 43:6',
#    'label': 'Penalty',
#    'position': '2586063',
#    'half': '1',
#    'confidence': '1.915961775011965e-06'},
#   {'gameTime': '1 - 0:49',
#    'label': 'Penalty',
#    'position': '49401',
#    'half': '1',
#    'confidence': '1.7866428834167891e-06'},
#   {'gameTime': '1 - 32:27',
#    'label': 'Penalty',
#    'position': '1947997',
#    'half': '1',
#    'confidence': '1.6853056195031968e-06'},
#   {'gameTime': '1 - 8:44',
#    'label': 'Penalty',
#    'position': '524700',
#    'half': '1',
#    'confidence': '1.4972005146773881e-06'},
#   {'gameTime': '1 - 28:59',
#    'label': 'Penalty',
#    'position': '1739989',
#    'half': '1',
#    'confidence': '1.4790507520956453e-06'},
#   {'gameTime': '1 - 37:50',
#    'label': 'Penalty',
#    'position': '2270930',
#    'half': '1',
#    'confidence': '1.3700657746085199e-06'},
#   {'gameTime': '1 - 16:41',
#    'label': 'Penalty',
#    'position': '1001560',
#    'half': '1',
#    'confidence': '1.356179495815013e-06'},
#   {'gameTime': '1 - 12:56',
#    'label': 'Penalty',
#    'position': '776911',
#    'half': '1',
#    'confidence': '1.3466643622450647e-06'},
#   {'gameTime': '1 - 17:48',
#    'label': 'Penalty',
#    'position': '1068642',
#    'half': '1',
#    'confidence': '1.3101167724016705e-06'},
#   {'gameTime': '1 - 19:1',
#    'label': 'Penalty',
#    'position': '1141965',
#    'half': '1',
#    'confidence': '1.1971452522629988e-06'},
#   {'gameTime': '1 - 25:2',
#    'label': 'Penalty',
#    'position': '1502340',
#    'half': '1',
#    'confidence': '1.1116666200905456e-06'},
#   {'gameTime': '1 - 33:12',
#    'label': 'Penalty',
#    'position': '1992199',
#    'half': '1',
#    'confidence': '1.11045437733992e-06'},
#   {'gameTime': '1 - 12:11',
#    'label': 'Penalty',
#    'position': '731669',
#    'half': '1',
#    'confidence': '1.0901474070124095e-06'},
#   {'gameTime': '1 - 29:34',
#    'label': 'Penalty',
#    'position': '1774830',
#    'half': '1',
#    'confidence': '1.044776468006603e-06'},
#   {'gameTime': '1 - 31:19',
#    'label': 'Penalty',
#    'position': '1879355',
#    'half': '1',
#    'confidence': '8.027275271160761e-07'},
#   {'gameTime': '1 - 2:43',
#    'label': 'Penalty',
#    'position': '163806',
#    'half': '1',
#    'confidence': '7.713662171227043e-07'},
#   {'gameTime': '1 - 11:37',
#    'label': 'Penalty',
#    'position': '697867',
#    'half': '1',
#    'confidence': '7.038436251605162e-07'},
#   {'gameTime': '1 - 7:5',
#    'label': 'Penalty',
#    'position': '425897',
#    'half': '1',
#    'confidence': '7.032558642094955e-07'},
#   {'gameTime': '1 - 27:6',
#    'label': 'Penalty',
#    'position': '1626625',
#    'half': '1',
#    'confidence': '6.73763963732199e-07'},
#   {'gameTime': '1 - 20:12',
#    'label': 'Penalty',
#    'position': '1212168',
#    'half': '1',
#    'confidence': '6.553515277119004e-07'},
#   {'gameTime': '1 - 15:1',
#    'label': 'Penalty',
#    'position': '901196',
#    'half': '1',
#    'confidence': '6.355229515975225e-07'},
#   {'gameTime': '1 - 27:25',
#    'label': 'Penalty',
#    'position': '1645345',
#    'half': '1',
#    'confidence': '5.882152436242905e-07'},
#   {'gameTime': '1 - 37:15',
#    'label': 'Penalty',
#    'position': '2235569',
#    'half': '1',
#    'confidence': '5.734565888815268e-07'},
#   {'gameTime': '1 - 3:9',
#    'label': 'Penalty',
#    'position': '189287',
#    'half': '1',
#    'confidence': '5.019396098759898e-07'},
#   {'gameTime': '1 - 12:27',
#    'label': 'Penalty',
#    'position': '747269',
#    'half': '1',
#    'confidence': '4.936325694870902e-07'},
#   {'gameTime': '1 - 44:26',
#    'label': 'Penalty',
#    'position': '2666666',
#    'half': '1',
#    'confidence': '4.883014526058105e-07'},
#   {'gameTime': '1 - 14:33',
#    'label': 'Penalty',
#    'position': '873634',
#    'half': '1',
#    'confidence': '4.773385171574773e-07'},
#   {'gameTime': '1 - 23:48',
#    'label': 'Penalty',
#    'position': '1428497',
#    'half': '1',
#    'confidence': '4.266273094799544e-07'},
#   {'gameTime': '1 - 8:24',
#    'label': 'Penalty',
#    'position': '504420',
#    'half': '1',
#    'confidence': '3.652256168606982e-07'},
#   {'gameTime': '1 - 0:7',
#    'label': 'Penalty',
#    'position': '7280',
#    'half': '1',
#    'confidence': '3.5695987321560096e-07'},
#   {'gameTime': '1 - 20:51',
#    'label': 'Penalty',
#    'position': '1251690',
#    'half': '1',
#    'confidence': '3.2694592277948686e-07'},
#   {'gameTime': '1 - 35:15',
#    'label': 'Penalty',
#    'position': '2115444',
#    'half': '1',
#    'confidence': '3.2486352097294e-07'},
#   {'gameTime': '1 - 15:22',
#    'label': 'Penalty',
#    'position': '922516',
#    'half': '1',
#    'confidence': '3.1687596901974757e-07'},
#   {'gameTime': '1 - 10:2',
#    'label': 'Penalty',
#    'position': '602704',
#    'half': '1',
#    'confidence': '3.099677030604653e-07'},
#   {'gameTime': '1 - 38:50',
#    'label': 'Penalty',
#    'position': '2330213',
#    'half': '1',
#    'confidence': '2.377645813567142e-07'},
#   {'gameTime': '1 - 10:24',
#    'label': 'Penalty',
#    'position': '624544',
#    'half': '1',
#    'confidence': '2.1295301166901481e-07'},
#   {'gameTime': '1 - 6:31',
#    'label': 'Penalty',
#    'position': '391055',
#    'half': '1',
#    'confidence': '2.0499209085755865e-07'},
#   {'gameTime': '1 - 0:22',
#    'label': 'Penalty',
#    'position': '22880',
#    'half': '1',
#    'confidence': '1.8243747490487294e-07'},
#   {'gameTime': '1 - 16:2',
#    'label': 'Penalty',
#    'position': '962038',
#    'half': '1',
#    'confidence': '1.7458199863540358e-07'},
#   {'gameTime': '1 - 18:28',
#    'label': 'Penalty',
#    'position': '1108164',
#    'half': '1',
#    'confidence': '1.6675706149271718e-07'},
#   {'gameTime': '1 - 24:24',
#    'label': 'Penalty',
#    'position': '1464898',
#    'half': '1',
#    'confidence': '1.6399835089941917e-07'},
#   {'gameTime': '1 - 19:24',
#    'label': 'Penalty',
#    'position': '1164326',
#    'half': '1',
#    'confidence': '1.1587322745754136e-07'},
#   {'gameTime': '1 - 3:37',
#    'label': 'Penalty',
#    'position': '217888',
#    'half': '1',
#    'confidence': '1.1533499844063044e-07'},
#   {'gameTime': '1 - 31:2',
#    'label': 'Penalty',
#    'position': '1862194',
#    'half': '1',
#    'confidence': '1.0914523329574877e-07'},
#   {'gameTime': '1 - 18:43',
#    'label': 'Penalty',
#    'position': '1123764',
#    'half': '1',
#    'confidence': '1.0567366359737207e-07'},
#   {'gameTime': '1 - 32:45',
#    'label': 'Penalty',
#    'position': '1965158',
#    'half': '1',
#    'confidence': '1.0244431081218863e-07'},
#   {'gameTime': '1 - 36:56',
#    'label': 'Penalty',
#    'position': '2216328',
#    'half': '1',
#    'confidence': '1.0175434539405614e-07'},
#   {'gameTime': '1 - 2:12',
#    'label': 'Penalty',
#    'position': '132085',
#    'half': '1',
#    'confidence': '8.509016424795846e-08'},
#   {'gameTime': '1 - 22:9',
#    'label': 'Penalty',
#    'position': '1329693',
#    'half': '1',
#    'confidence': '6.796594220759289e-08'},
#   {'gameTime': '1 - 43:48',
#    'label': 'Penalty',
#    'position': '2628185',
#    'half': '1',
#    'confidence': '5.804936975550845e-08'},
#   {'gameTime': '1 - 23:15',
#    'label': 'Penalty',
#    'position': '1395215',
#    'half': '1',
#    'confidence': '5.797820890052208e-08'},
#   {'gameTime': '1 - 39:4',
#    'label': 'Penalty',
#    'position': '2344773',
#    'half': '1',
#    'confidence': '5.388703172570786e-08'},
#   {'gameTime': '1 - 11:52',
#    'label': 'Penalty',
#    'position': '712948',
#    'half': '1',
#    'confidence': '5.291082416647441e-08'},
#   {'gameTime': '1 - 7:28',
#    'label': 'Penalty',
#    'position': '448777',
#    'half': '1',
#    'confidence': '4.822605248477885e-08'},
#   {'gameTime': '1 - 24:39',
#    'label': 'Penalty',
#    'position': '1479459',
#    'half': '1',
#    'confidence': '4.121021390801616e-08'},
#   {'gameTime': '1 - 31:40',
#    'label': 'Penalty',
#    'position': '1900156',
#    'half': '1',
#    'confidence': '2.6992371005007953e-08'},
#   {'gameTime': '1 - 40:14',
#    'label': 'Penalty',
#    'position': '2414976',
#    'half': '1',
#    'confidence': '2.0753322615973957e-08'},
#   {'gameTime': '1 - 22:27',
#    'label': 'Penalty',
#    'position': '1347893',
#    'half': '1',
#    'confidence': '2.0212535645214302e-08'},
#   {'gameTime': '1 - 26:13',
#    'label': 'Penalty',
#    'position': '1573582',
#    'half': '1',
#    'confidence': '1.548499106718282e-08'},
#   {'gameTime': '1 - 1:3',
#    'label': 'Penalty',
#    'position': '63962',
#    'half': '1',
#    'confidence': '1.2838928142855366e-08'},
#   {'gameTime': '1 - 2:26',
#    'label': 'Penalty',
#    'position': '146645',
#    'half': '1',
#    'confidence': '3.837588025135119e-09'},
#   {'gameTime': '1 - 0:3',
#    'label': 'Kick-off',
#    'position': '3640',
#    'half': '1',
#    'confidence': '0.8227239847183228'},
#   {'gameTime': '1 - 34:32',
#    'label': 'Kick-off',
#    'position': '2072282',
#    'half': '1',
#    'confidence': '0.629787266254425'},
#   {'gameTime': '1 - 30:32',
#    'label': 'Kick-off',
#    'position': '1832553',
#    'half': '1',
#    'confidence': '0.563677191734314'},
#   {'gameTime': '1 - 30:10',
#    'label': 'Kick-off',
#    'position': '1810712',
#    'half': '1',
#    'confidence': '0.17333339154720306'},
#   {'gameTime': '1 - 40:48',
#    'label': 'Kick-off',
#    'position': '2448257',
#    'half': '1',
#    'confidence': '0.1327262818813324'},
#   {'gameTime': '1 - 37:51',
#    'label': 'Kick-off',
#    'position': '2271450',
#    'half': '1',
#    'confidence': '0.1071808859705925'},
#   {'gameTime': '1 - 29:51',
#    'label': 'Kick-off',
#    'position': '1791471',
#    'half': '1',
#    'confidence': '0.025893084704875946'},
#   {'gameTime': '1 - 29:23',
#    'label': 'Kick-off',
#    'position': '1763390',
#    'half': '1',
#    'confidence': '0.023289820179343224'},
#   {'gameTime': '1 - 32:20',
#    'label': 'Kick-off',
#    'position': '1940717',
#    'half': '1',
#    'confidence': '0.017049934715032578'},
#   {'gameTime': '1 - 17:11',
#    'label': 'Kick-off',
#    'position': '1031201',
#    'half': '1',
#    'confidence': '0.016889099031686783'},
#   {'gameTime': '1 - 1:48',
#    'label': 'Kick-off',
#    'position': '108164',
#    'half': '1',
#    'confidence': '0.016105707734823227'},
#   {'gameTime': '1 - 34:47',
#    'label': 'Kick-off',
#    'position': '2087363',
#    'half': '1',
#    'confidence': '0.015975814312696457'},
#   {'gameTime': '1 - 21:46',
#    'label': 'Kick-off',
#    'position': '1306812',
#    'half': '1',
#    'confidence': '0.01215140987187624'},
#   {'gameTime': '1 - 8:57',
#    'label': 'Kick-off',
#    'position': '537701',
#    'half': '1',
#    'confidence': '0.010846549645066261'},
#   {'gameTime': '1 - 36:35',
#    'label': 'Kick-off',
#    'position': '2195527',
#    'half': '1',
#    'confidence': '0.010215315967798233'},
#   {'gameTime': '1 - 21:31',
#    'label': 'Kick-off',
#    'position': '1291211',
#    'half': '1',
#    'confidence': '0.01012840773910284'},
#   {'gameTime': '1 - 13:30',
#    'label': 'Kick-off',
#    'position': '810192',
#    'half': '1',
#    'confidence': '0.009231092408299446'},
#   {'gameTime': '1 - 25:51',
#    'label': 'Kick-off',
#    'position': '1551222',
#    'half': '1',
#    'confidence': '0.008768356405198574'},
#   {'gameTime': '1 - 10:21',
#    'label': 'Kick-off',
#    'position': '621944',
#    'half': '1',
#    'confidence': '0.008733829483389854'},
#   {'gameTime': '1 - 5:44',
#    'label': 'Kick-off',
#    'position': '344253',
#    'half': '1',
#    'confidence': '0.008678598329424858'},
#   {'gameTime': '1 - 1:28',
#    'label': 'Kick-off',
#    'position': '88403',
#    'half': '1',
#    'confidence': '0.008590775541961193'},
#   {'gameTime': '1 - 37:12',
#    'label': 'Kick-off',
#    'position': '2232449',
#    'half': '1',
#    'confidence': '0.008585833944380283'},
#   {'gameTime': '1 - 38:23',
#    'label': 'Kick-off',
#    'position': '2303692',
#    'half': '1',
#    'confidence': '0.008439830504357815'},
#   {'gameTime': '1 - 14:22',
#    'label': 'Kick-off',
#    'position': '862714',
#    'half': '1',
#    'confidence': '0.008417521603405476'},
#   {'gameTime': '1 - 26:7',
#    'label': 'Kick-off',
#    'position': '1567342',
#    'half': '1',
#    'confidence': '0.008370599709451199'},
#   {'gameTime': '1 - 41:9',
#    'label': 'Kick-off',
#    'position': '2469578',
#    'half': '1',
#    'confidence': '0.006670542526990175'},
#   {'gameTime': '1 - 26:21',
#    'label': 'Kick-off',
#    'position': '1581903',
#    'half': '1',
#    'confidence': '0.006417859811335802'},
#   {'gameTime': '1 - 9:33',
#    'label': 'Kick-off',
#    'position': '573062',
#    'half': '1',
#    'confidence': '0.005785392597317696'},
#   {'gameTime': '1 - 34:2',
#    'label': 'Kick-off',
#    'position': '2042121',
#    'half': '1',
#    'confidence': '0.005684868898242712'},
#   {'gameTime': '1 - 11:7',
#    'label': 'Kick-off',
#    'position': '667706',
#    'half': '1',
#    'confidence': '0.005298256874084473'},
#   {'gameTime': '1 - 29:7',
#    'label': 'Kick-off',
#    'position': '1747269',
#    'half': '1',
#    'confidence': '0.004964878316968679'},
#   {'gameTime': '1 - 39:31',
#    'label': 'Kick-off',
#    'position': '2371814',
#    'half': '1',
#    'confidence': '0.004683171398937702'},
#   {'gameTime': '1 - 5:25',
#    'label': 'Kick-off',
#    'position': '325013',
#    'half': '1',
#    'confidence': '0.004503646399825811'},
#   {'gameTime': '1 - 41:25',
#    'label': 'Kick-off',
#    'position': '2485699',
#    'half': '1',
#    'confidence': '0.0041840155608952045'},
#   {'gameTime': '1 - 28:40',
#    'label': 'Kick-off',
#    'position': '1720228',
#    'half': '1',
#    'confidence': '0.004044514615088701'},
#   {'gameTime': '1 - 16:55',
#    'label': 'Kick-off',
#    'position': '1015080',
#    'half': '1',
#    'confidence': '0.0037464171182364225'},
#   {'gameTime': '1 - 36:5',
#    'label': 'Kick-off',
#    'position': '2165366',
#    'half': '1',
#    'confidence': '0.003691013203933835'},
#   {'gameTime': '1 - 12:11',
#    'label': 'Kick-off',
#    'position': '731669',
#    'half': '1',
#    'confidence': '0.00357580604031682'},
#   {'gameTime': '1 - 44:47',
#    'label': 'Kick-off',
#    'position': '2687467',
#    'half': '1',
#    'confidence': '0.0033732042647898197'},
#   {'gameTime': '1 - 19:59',
#    'label': 'Kick-off',
#    'position': '1199167',
#    'half': '1',
#    'confidence': '0.003367007477208972'},
#   {'gameTime': '1 - 31:56',
#    'label': 'Kick-off',
#    'position': '1916276',
#    'half': '1',
#    'confidence': '0.003273556474596262'},
#   {'gameTime': '1 - 11:22',
#    'label': 'Kick-off',
#    'position': '682787',
#    'half': '1',
#    'confidence': '0.0031570664141327143'},
#   {'gameTime': '1 - 16:15',
#    'label': 'Kick-off',
#    'position': '975559',
#    'half': '1',
#    'confidence': '0.0030603851191699505'},
#   {'gameTime': '1 - 6:5',
#    'label': 'Kick-off',
#    'position': '365054',
#    'half': '1',
#    'confidence': '0.003030788851901889'},
#   {'gameTime': '1 - 19:1',
#    'label': 'Kick-off',
#    'position': '1141445',
#    'half': '1',
#    'confidence': '0.0029256967827677727'},
#   {'gameTime': '1 - 42:15',
#    'label': 'Kick-off',
#    'position': '2535101',
#    'half': '1',
#    'confidence': '0.0026359541807323694'},
#   {'gameTime': '1 - 24:24',
#    'label': 'Kick-off',
#    'position': '1464378',
#    'half': '1',
#    'confidence': '0.0022800355218350887'},
#   {'gameTime': '1 - 13:58',
#    'label': 'Kick-off',
#    'position': '838273',
#    'half': '1',
#    'confidence': '0.00217813509516418'},
#   {'gameTime': '1 - 15:53',
#    'label': 'Kick-off',
#    'position': '953198',
#    'half': '1',
#    'confidence': '0.0021771518513560295'},
#   {'gameTime': '1 - 35:2',
#    'label': 'Kick-off',
#    'position': '2102964',
#    'half': '1',
#    'confidence': '0.0019417374860495329'},
#   {'gameTime': '1 - 23:37',
#    'label': 'Kick-off',
#    'position': '1417056',
#    'half': '1',
#    'confidence': '0.001932341605424881'},
#   {'gameTime': '1 - 27:49',
#    'label': 'Kick-off',
#    'position': '1669786',
#    'half': '1',
#    'confidence': '0.0018806663574650884'},
#   {'gameTime': '1 - 20:57',
#    'label': 'Kick-off',
#    'position': '1257410',
#    'half': '1',
#    'confidence': '0.0017975567607209086'},
#   {'gameTime': '1 - 41:47',
#    'label': 'Kick-off',
#    'position': '2507540',
#    'half': '1',
#    'confidence': '0.001777368364855647'},
#   {'gameTime': '1 - 24:52',
#    'label': 'Kick-off',
#    'position': '1492979',
#    'half': '1',
#    'confidence': '0.0017125607701018453'},
#   {'gameTime': '1 - 5:8',
#    'label': 'Kick-off',
#    'position': '308372',
#    'half': '1',
#    'confidence': '0.0015293930191546679'},
#   {'gameTime': '1 - 3:24',
#    'label': 'Kick-off',
#    'position': '204888',
#    'half': '1',
#    'confidence': '0.0013225121656432748'},
#   {'gameTime': '1 - 43:23',
#    'label': 'Kick-off',
#    'position': '2603224',
#    'half': '1',
#    'confidence': '0.0013013564748689532'},
#   {'gameTime': '1 - 35:47',
#    'label': 'Kick-off',
#    'position': '2147685',
#    'half': '1',
#    'confidence': '0.0012880837311968207'},
#   {'gameTime': '1 - 42:59',
#    'label': 'Kick-off',
#    'position': '2579303',
#    'half': '1',
#    'confidence': '0.001269470783881843'},
#   {'gameTime': '1 - 4:16',
#    'label': 'Kick-off',
#    'position': '256370',
#    'half': '1',
#    'confidence': '0.0012398260878399014'},
#   {'gameTime': '1 - 15:22',
#    'label': 'Kick-off',
#    'position': '922516',
#    'half': '1',
#    'confidence': '0.0012281062081456184'},
#   {'gameTime': '1 - 28:18',
#    'label': 'Kick-off',
#    'position': '1698387',
#    'half': '1',
#    'confidence': '0.0011426650453358889'},
#   {'gameTime': '1 - 35:28',
#    'label': 'Kick-off',
#    'position': '2128965',
#    'half': '1',
#    'confidence': '0.001130438526161015'},
#   {'gameTime': '1 - 22:59',
#    'label': 'Kick-off',
#    'position': '1379615',
#    'half': '1',
#    'confidence': '0.001101760077290237'},
#   {'gameTime': '1 - 30:47',
#    'label': 'Kick-off',
#    'position': '1847633',
#    'half': '1',
#    'confidence': '0.0010126680135726929'},
#   {'gameTime': '1 - 37:35',
#    'label': 'Kick-off',
#    'position': '2255850',
#    'half': '1',
#    'confidence': '0.0009953409899026155'},
#   {'gameTime': '1 - 40:16',
#    'label': 'Kick-off',
#    'position': '2416016',
#    'half': '1',
#    'confidence': '0.0009647483821026981'},
#   {'gameTime': '1 - 3:45',
#    'label': 'Kick-off',
#    'position': '225689',
#    'half': '1',
#    'confidence': '0.0009419210837222636'},
#   {'gameTime': '1 - 23:56',
#    'label': 'Kick-off',
#    'position': '1436297',
#    'half': '1',
#    'confidence': '0.0009035221301019192'},
#   {'gameTime': '1 - 33:32',
#    'label': 'Kick-off',
#    'position': '2012480',
#    'half': '1',
#    'confidence': '0.0008739245240576565'},
#   {'gameTime': '1 - 17:32',
#    'label': 'Kick-off',
#    'position': '1052522',
#    'half': '1',
#    'confidence': '0.0008436550269834697'},
#   {'gameTime': '1 - 27:27',
#    'label': 'Kick-off',
#    'position': '1647425',
#    'half': '1',
#    'confidence': '0.0008210606756620109'},
#   {'gameTime': '1 - 7:1',
#    'label': 'Kick-off',
#    'position': '421216',
#    'half': '1',
#    'confidence': '0.000816616287920624'},
#   {'gameTime': '1 - 21:13',
#    'label': 'Kick-off',
#    'position': '1273530',
#    'half': '1',
#    'confidence': '0.0007731980876997113'},
#   {'gameTime': '1 - 11:45',
#    'label': 'Kick-off',
#    'position': '705668',
#    'half': '1',
#    'confidence': '0.00069490319583565'},
#   {'gameTime': '1 - 32:58',
#    'label': 'Kick-off',
#    'position': '1978679',
#    'half': '1',
#    'confidence': '0.0006912588141858578'},
#   {'gameTime': '1 - 22:39',
#    'label': 'Kick-off',
#    'position': '1359334',
#    'half': '1',
#    'confidence': '0.0006894788239151239'},
#   {'gameTime': '1 - 12:56',
#    'label': 'Kick-off',
#    'position': '776911',
#    'half': '1',
#    'confidence': '0.0006642569787800312'},
#   {'gameTime': '1 - 15:5',
#    'label': 'Kick-off',
#    'position': '905356',
#    'half': '1',
#    'confidence': '0.000663356448058039'},
#   {'gameTime': '1 - 8:33',
#    'label': 'Kick-off',
#    'position': '513260',
#    'half': '1',
#    'confidence': '0.0006571455160155892'},
#   {'gameTime': '1 - 27:9',
#    'label': 'Kick-off',
#    'position': '1629745',
#    'half': '1',
#    'confidence': '0.000656111107673496'},
#   {'gameTime': '1 - 44:12',
#    'label': 'Kick-off',
#    'position': '2652106',
#    'half': '1',
#    'confidence': '0.000653033668641001'},
#   {'gameTime': '1 - 43:48',
#    'label': 'Kick-off',
#    'position': '2628705',
#    'half': '1',
#    'confidence': '0.0006442570011131465'},
#   {'gameTime': '1 - 19:29',
#    'label': 'Kick-off',
#    'position': '1169006',
#    'half': '1',
#    'confidence': '0.0006337744416669011'},
#   {'gameTime': '1 - 38:7',
#    'label': 'Kick-off',
#    'position': '2287571',
#    'half': '1',
#    'confidence': '0.0006290921592153609'},
#   {'gameTime': '1 - 0:50',
#    'label': 'Kick-off',
#    'position': '50442',
#    'half': '1',
#    'confidence': '0.000606427900493145'},
#   {'gameTime': '1 - 20:32',
#    'label': 'Kick-off',
#    'position': '1232969',
#    'half': '1',
#    'confidence': '0.0006013694801367819'},
#   {'gameTime': '1 - 4:40',
#    'label': 'Kick-off',
#    'position': '280811',
#    'half': '1',
#    'confidence': '0.0005983536248095334'},
#   {'gameTime': '1 - 9:17',
#    'label': 'Kick-off',
#    'position': '557462',
#    'half': '1',
#    'confidence': '0.0005917498492635787'},
#   {'gameTime': '1 - 40:31',
#    'label': 'Kick-off',
#    'position': '2431097',
#    'half': '1',
#    'confidence': '0.0005796288605779409'},
#   {'gameTime': '1 - 42:36',
#    'label': 'Kick-off',
#    'position': '2556942',
#    'half': '1',
#    'confidence': '0.0005782708758488297'},
#   {'gameTime': '1 - 18:23',
#    'label': 'Kick-off',
#    'position': '1103484',
#    'half': '1',
#    'confidence': '0.0005321222124621272'},
#   {'gameTime': '1 - 39:57',
#    'label': 'Kick-off',
#    'position': '2397815',
#    'half': '1',
#    'confidence': '0.0004934347234666348'},
#   {'gameTime': '1 - 17:53',
#    'label': 'Kick-off',
#    'position': '1073842',
#    'half': '1',
#    'confidence': '0.000437448441516608'},
#   {'gameTime': '1 - 10:39',
#    'label': 'Kick-off',
#    'position': '639105',
#    'half': '1',
#    'confidence': '0.0004231007187627256'},
#   {'gameTime': '1 - 39:16',
#    'label': 'Kick-off',
#    'position': '2356214',
#    'half': '1',
#    'confidence': '0.00042274920269846916'},
#   {'gameTime': '1 - 33:16',
#    'label': 'Kick-off',
#    'position': '1996359',
#    'half': '1',
#    'confidence': '0.0004175201174803078'},
#   {'gameTime': '1 - 25:8',
#    'label': 'Kick-off',
#    'position': '1508580',
#    'half': '1',
#    'confidence': '0.0004083089006599039'},
#   {'gameTime': '1 - 12:30',
#    'label': 'Kick-off',
#    'position': '750910',
#    'half': '1',
#    'confidence': '0.00037627865094691515'},
#   {'gameTime': '1 - 9:50',
#    'label': 'Kick-off',
#    'position': '590223',
#    'half': '1',
#    'confidence': '0.0003699893713928759'},
#   {'gameTime': '1 - 16:30',
#    'label': 'Kick-off',
#    'position': '990639',
#    'half': '1',
#    'confidence': '0.0003538327000569552'},
#   {'gameTime': '1 - 31:35',
#    'label': 'Kick-off',
#    'position': '1895995',
#    'half': '1',
#    'confidence': '0.00033114408142864704'},
#   {'gameTime': '1 - 8:16',
#    'label': 'Kick-off',
#    'position': '496099',
#    'half': '1',
#    'confidence': '0.00031615799525752664'},
#   {'gameTime': '1 - 6:24',
#    'label': 'Kick-off',
#    'position': '384295',
#    'half': '1',
#    'confidence': '0.0003137429303023964'},
#   {'gameTime': '1 - 2:57',
#    'label': 'Kick-off',
#    'position': '177847',
#    'half': '1',
#    'confidence': '0.0003078096779063344'},
#   {'gameTime': '1 - 31:12',
#    'label': 'Kick-off',
#    'position': '1872074',
#    'half': '1',
#    'confidence': '0.0002785642573144287'},
#   {'gameTime': '1 - 20:13',
#    'label': 'Kick-off',
#    'position': '1213728',
#    'half': '1',
#    'confidence': '0.00027119959122501314'},
#   {'gameTime': '1 - 38:57',
#    'label': 'Kick-off',
#    'position': '2337493',
#    'half': '1',
#    'confidence': '0.00024115829728543758'},
#   {'gameTime': '1 - 18:39',
#    'label': 'Kick-off',
#    'position': '1119084',
#    'half': '1',
#    'confidence': '0.00023904898262117058'},
#   {'gameTime': '1 - 25:26',
#    'label': 'Kick-off',
#    'position': '1526781',
#    'half': '1',
#    'confidence': '0.00022650562459602952'},
#   {'gameTime': '1 - 0:25',
#    'label': 'Kick-off',
#    'position': '25481',
#    'half': '1',
#    'confidence': '0.00022129480203147978'},
#   {'gameTime': '1 - 32:39',
#    'label': 'Kick-off',
#    'position': '1959958',
#    'half': '1',
#    'confidence': '0.00020066714205313474'},
#   {'gameTime': '1 - 2:24',
#    'label': 'Kick-off',
#    'position': '144045',
#    'half': '1',
#    'confidence': '0.00019429464009590447'},
#   {'gameTime': '1 - 7:32',
#    'label': 'Kick-off',
#    'position': '452418',
#    'half': '1',
#    'confidence': '0.0001938085915753618'},
#   {'gameTime': '1 - 7:46',
#    'label': 'Kick-off',
#    'position': '466978',
#    'half': '1',
#    'confidence': '0.00019342736050020903'},
#   {'gameTime': '1 - 6:39',
#    'label': 'Kick-off',
#    'position': '399895',
#    'half': '1',
#    'confidence': '0.00019228048040531576'},
#   {'gameTime': '1 - 23:18',
#    'label': 'Kick-off',
#    'position': '1398855',
#    'half': '1',
#    'confidence': '0.00019096951291430742'},
#   {'gameTime': '1 - 7:16',
#    'label': 'Kick-off',
#    'position': '436297',
#    'half': '1',
#    'confidence': '0.00018881635332945734'},
#   {'gameTime': '1 - 10:5',
#    'label': 'Kick-off',
#    'position': '605824',
#    'half': '1',
#    'confidence': '0.00016584937111474574'},
#   {'gameTime': '1 - 36:19',
#    'label': 'Kick-off',
#    'position': '2179927',
#    'half': '1',
#    'confidence': '0.00015806304872967303'},
#   {'gameTime': '1 - 26:52',
#    'label': 'Kick-off',
#    'position': '1612064',
#    'half': '1',
#    'confidence': '0.00013651321933139116'},
#   {'gameTime': '1 - 2:5',
#    'label': 'Kick-off',
#    'position': '125325',
#    'half': '1',
#    'confidence': '0.00012974855781067163'},
#   {'gameTime': '1 - 1:12',
#    'label': 'Kick-off',
#    'position': '72802',
#    'half': '1',
#    'confidence': '0.00012280659575480968'},
#   {'gameTime': '1 - 14:49',
#    'label': 'Kick-off',
#    'position': '889755',
#    'half': '1',
#    'confidence': '0.00012232543667778373'},
#   {'gameTime': '1 - 38:38',
#    'label': 'Kick-off',
#    'position': '2318772',
#    'half': '1',
#    'confidence': '9.834517550189048e-05'},
#   {'gameTime': '1 - 13:11',
#    'label': 'Kick-off',
#    'position': '791991',
#    'half': '1',
#    'confidence': '9.475518891122192e-05'},
#   {'gameTime': '1 - 22:11',
#    'label': 'Kick-off',
#    'position': '1331253',
#    'half': '1',
#    'confidence': '9.316405339632183e-05'},
#   {'gameTime': '1 - 36:56',
#    'label': 'Kick-off',
#    'position': '2216848',
#    'half': '1',
#    'confidence': '9.218664490617812e-05'},
#   {'gameTime': '1 - 2:39',
#    'label': 'Kick-off',
#    'position': '159126',
#    'half': '1',
#    'confidence': '7.783703040331602e-05'},
#   {'gameTime': '1 - 15:37',
#    'label': 'Kick-off',
#    'position': '937077',
#    'half': '1',
#    'confidence': '7.634700159542263e-05'},
#   {'gameTime': '1 - 44:26',
#    'label': 'Kick-off',
#    'position': '2666666',
#    'half': '1',
#    'confidence': '6.247621058719233e-05'},
#   {'gameTime': '1 - 19:43',
#    'label': 'Kick-off',
#    'position': '1183567',
#    'half': '1',
#    'confidence': '4.737475683214143e-05'},
#   {'gameTime': '1 - 34:16',
#    'label': 'Kick-off',
#    'position': '2056682',
#    'half': '1',
#    'confidence': '4.5446122385328636e-05'},
#   {'gameTime': '1 - 26:36',
#    'label': 'Kick-off',
#    'position': '1596463',
#    'half': '1',
#    'confidence': '3.065117562073283e-05'},
#   {'gameTime': '1 - 4:0',
#    'label': 'Kick-off',
#    'position': '240249',
#    'half': '1',
#    'confidence': '1.3445391232380643e-05'},
#   {'gameTime': '1 - 29:18',
#    'label': 'Goal',
#    'position': '1758710',
#    'half': '1',
#    'confidence': '0.9090672731399536'},
#   {'gameTime': '1 - 38:9',
#    'label': 'Goal',
#    'position': '2289131',
#    'half': '1',
#    'confidence': '0.6094940304756165'},
#   {'gameTime': '1 - 34:39',
#    'label': 'Goal',
#    'position': '2079043',
#    'half': '1',
#    'confidence': '0.31079378724098206'},
#   {'gameTime': '1 - 14:16',
#    'label': 'Goal',
#    'position': '856474',
#    'half': '1',
#    'confidence': '0.07277961075305939'},
#   {'gameTime': '1 - 1:44',
#    'label': 'Goal',
#    'position': '104004',
#    'half': '1',
#    'confidence': '0.03936433419585228'},
#   {'gameTime': '1 - 34:17',
#    'label': 'Goal',
#    'position': '2057722',
#    'half': '1',
#    'confidence': '0.025584500283002853'},
#   {'gameTime': '1 - 17:30',
#    'label': 'Goal',
#    'position': '1050962',
#    'half': '1',
#    'confidence': '0.013703158125281334'},
#   {'gameTime': '1 - 8:45',
#    'label': 'Goal',
#    'position': '525221',
#    'half': '1',
#    'confidence': '0.012913712300360203'},
#   {'gameTime': '1 - 42:14',
#    'label': 'Goal',
#    'position': '2534061',
#    'half': '1',
#    'confidence': '0.012075785547494888'},
#   {'gameTime': '1 - 32:6',
#    'label': 'Goal',
#    'position': '1926677',
#    'half': '1',
#    'confidence': '0.008597568608820438'},
#   {'gameTime': '1 - 21:11',
#    'label': 'Goal',
#    'position': '1271970',
#    'half': '1',
#    'confidence': '0.0074130697175860405'},
#   {'gameTime': '1 - 37:31',
#    'label': 'Goal',
#    'position': '2251690',
#    'half': '1',
#    'confidence': '0.005706348456442356'},
#   {'gameTime': '1 - 43:8',
#    'label': 'Goal',
#    'position': '2588143',
#    'half': '1',
#    'confidence': '0.003967789933085442'},
#   {'gameTime': '1 - 5:36',
#    'label': 'Goal',
#    'position': '336973',
#    'half': '1',
#    'confidence': '0.003585884580388665'},
#   {'gameTime': '1 - 40:56',
#    'label': 'Goal',
#    'position': '2456058',
#    'half': '1',
#    'confidence': '0.0028360930737107992'},
#   {'gameTime': '1 - 9:23',
#    'label': 'Goal',
#    'position': '563702',
#    'half': '1',
#    'confidence': '0.0022442257031798363'},
#   {'gameTime': '1 - 44:47',
#    'label': 'Goal',
#    'position': '2687987',
#    'half': '1',
#    'confidence': '0.0020196845289319754'},
#   {'gameTime': '1 - 19:34',
#    'label': 'Goal',
#    'position': '1174206',
#    'half': '1',
#    'confidence': '0.0020168167538940907'},
#   {'gameTime': '1 - 44:16',
#    'label': 'Goal',
#    'position': '2656786',
#    'half': '1',
#    'confidence': '0.001652008737437427'},
#   {'gameTime': '1 - 25:31',
#    'label': 'Goal',
#    'position': '1531461',
#    'half': '1',
#    'confidence': '0.0015455348184332252'},
#   {'gameTime': '1 - 33:29',
#    'label': 'Goal',
#    'position': '2009360',
#    'half': '1',
#    'confidence': '0.0010780113516375422'},
#   {'gameTime': '1 - 16:12',
#    'label': 'Goal',
#    'position': '972438',
#    'half': '1',
#    'confidence': '0.0009277274366468191'},
#   {'gameTime': '1 - 3:43',
#    'label': 'Goal',
#    'position': '223088',
#    'half': '1',
#    'confidence': '0.0007455943268723786'},
#   {'gameTime': '1 - 29:50',
#    'label': 'Goal',
#    'position': '1790951',
#    'half': '1',
#    'confidence': '0.0006795339286327362'},
#   {'gameTime': '1 - 26:26',
#    'label': 'Goal',
#    'position': '1586583',
#    'half': '1',
#    'confidence': '0.0006724072736687958'},
#   {'gameTime': '1 - 41:15',
#    'label': 'Goal',
#    'position': '2475819',
#    'half': '1',
#    'confidence': '0.0005738334730267525'},
#   {'gameTime': '1 - 15:30',
#    'label': 'Goal',
#    'position': '930317',
#    'half': '1',
#    'confidence': '0.000489833066239953'},
#   {'gameTime': '1 - 15:44',
#    'label': 'Goal',
#    'position': '944877',
#    'half': '1',
#    'confidence': '0.00047896517207846045'},
#   {'gameTime': '1 - 10:42',
#    'label': 'Goal',
#    'position': '642225',
#    'half': '1',
#    'confidence': '0.00044775637798011303'},
#   {'gameTime': '1 - 38:28',
#    'label': 'Goal',
#    'position': '2308372',
#    'half': '1',
#    'confidence': '0.0004414842987898737'},
#   {'gameTime': '1 - 9:47',
#    'label': 'Goal',
#    'position': '587103',
#    'half': '1',
#    'confidence': '0.00041037981281988323'},
#   {'gameTime': '1 - 16:38',
#    'label': 'Goal',
#    'position': '998959',
#    'half': '1',
#    'confidence': '0.0003943475312553346'},
#   {'gameTime': '1 - 41:33',
#    'label': 'Goal',
#    'position': '2493499',
#    'half': '1',
#    'confidence': '0.0003608142433222383'},
#   {'gameTime': '1 - 34:59',
#    'label': 'Goal',
#    'position': '2099843',
#    'half': '1',
#    'confidence': '0.00034077579039148986'},
#   {'gameTime': '1 - 6:50',
#    'label': 'Goal',
#    'position': '410816',
#    'half': '1',
#    'confidence': '0.00033324796822853386'},
#   {'gameTime': '1 - 4:38',
#    'label': 'Goal',
#    'position': '278211',
#    'half': '1',
#    'confidence': '0.0003299233503639698'},
#   {'gameTime': '1 - 33:43',
#    'label': 'Goal',
#    'position': '2023920',
#    'half': '1',
#    'confidence': '0.0003243402752559632'},
#   {'gameTime': '1 - 4:7',
#    'label': 'Goal',
#    'position': '247009',
#    'half': '1',
#    'confidence': '0.00031307036988437176'},
#   {'gameTime': '1 - 36:27',
#    'label': 'Goal',
#    'position': '2187727',
#    'half': '1',
#    'confidence': '0.00030803101253695786'},
#   {'gameTime': '1 - 30:5',
#    'label': 'Goal',
#    'position': '1805512',
#    'half': '1',
#    'confidence': '0.0003075087442994118'},
#   {'gameTime': '1 - 12:54',
#    'label': 'Goal',
#    'position': '774310',
#    'half': '1',
#    'confidence': '0.00030402810079976916'},
#   {'gameTime': '1 - 31:8',
#    'label': 'Goal',
#    'position': '1868434',
#    'half': '1',
#    'confidence': '0.00030231926939450204'},
#   {'gameTime': '1 - 7:48',
#    'label': 'Goal',
#    'position': '468018',
#    'half': '1',
#    'confidence': '0.00030203579808585346'},
#   {'gameTime': '1 - 34:0',
#    'label': 'Goal',
#    'position': '2040561',
#    'half': '1',
#    'confidence': '0.00030136475106701255'},
#   {'gameTime': '1 - 5:16',
#    'label': 'Goal',
#    'position': '316692',
#    'half': '1',
#    'confidence': '0.00029723692568950355'},
#   {'gameTime': '1 - 17:58',
#    'label': 'Goal',
#    'position': '1078523',
#    'half': '1',
#    'confidence': '0.00027374905766919255'},
#   {'gameTime': '1 - 30:50',
#    'label': 'Goal',
#    'position': '1850234',
#    'half': '1',
#    'confidence': '0.0002667322987690568'},
#   {'gameTime': '1 - 1:21',
#    'label': 'Goal',
#    'position': '81123',
#    'half': '1',
#    'confidence': '0.0002658498124219477'},
#   {'gameTime': '1 - 39:25',
#    'label': 'Goal',
#    'position': '2365054',
#    'half': '1',
#    'confidence': '0.00024741774541325867'},
#   {'gameTime': '1 - 12:11',
#    'label': 'Goal',
#    'position': '731669',
#    'half': '1',
#    'confidence': '0.0002419929951429367'},
#   {'gameTime': '1 - 31:51',
#    'label': 'Goal',
#    'position': '1911076',
#    'half': '1',
#    'confidence': '0.000229759156354703'},
#   {'gameTime': '1 - 41:58',
#    'label': 'Goal',
#    'position': '2518460',
#    'half': '1',
#    'confidence': '0.00021565129281952977'},
#   {'gameTime': '1 - 21:26',
#    'label': 'Goal',
#    'position': '1286531',
#    'half': '1',
#    'confidence': '0.0002151041990146041'},
#   {'gameTime': '1 - 13:18',
#    'label': 'Goal',
#    'position': '798751',
#    'half': '1',
#    'confidence': '0.00021336387726478279'},
#   {'gameTime': '1 - 23:30',
#    'label': 'Goal',
#    'position': '1410816',
#    'half': '1',
#    'confidence': '0.0002060569095192477'},
#   {'gameTime': '1 - 22:36',
#    'label': 'Goal',
#    'position': '1356734',
#    'half': '1',
#    'confidence': '0.00020022391981910914'},
#   {'gameTime': '1 - 12:28',
#    'label': 'Goal',
#    'position': '748829',
#    'half': '1',
#    'confidence': '0.00019515224266797304'},
#   {'gameTime': '1 - 8:2',
#    'label': 'Goal',
#    'position': '482579',
#    'half': '1',
#    'confidence': '0.00017641260637901723'},
#   {'gameTime': '1 - 27:30',
#    'label': 'Goal',
#    'position': '1650546',
#    'half': '1',
#    'confidence': '0.00017357326578348875'},
#   {'gameTime': '1 - 28:5',
#    'label': 'Goal',
#    'position': '1685387',
#    'half': '1',
#    'confidence': '0.00017337262397632003'},
#   {'gameTime': '1 - 43:31',
#    'label': 'Goal',
#    'position': '2611544',
#    'half': '1',
#    'confidence': '0.00016604765551164746'},
#   {'gameTime': '1 - 30:24',
#    'label': 'Goal',
#    'position': '1824232',
#    'half': '1',
#    'confidence': '0.00016471043636556715'},
#   {'gameTime': '1 - 20:31',
#    'label': 'Goal',
#    'position': '1231409',
#    'half': '1',
#    'confidence': '0.0001644739240873605'},
#   {'gameTime': '1 - 24:6',
#    'label': 'Goal',
#    'position': '1446177',
#    'half': '1',
#    'confidence': '0.00015156911103986204'},
#   {'gameTime': '1 - 40:24',
#    'label': 'Goal',
#    'position': '2424336',
#    'half': '1',
#    'confidence': '0.00014305865624919534'},
#   {'gameTime': '1 - 19:3',
#    'label': 'Goal',
#    'position': '1143525',
#    'half': '1',
#    'confidence': '0.00014285213546827435'},
#   {'gameTime': '1 - 0:6',
#    'label': 'Goal',
#    'position': '6760',
#    'half': '1',
#    'confidence': '0.00014221973833628'},
#   {'gameTime': '1 - 19:57',
#    'label': 'Goal',
#    'position': '1197087',
#    'half': '1',
#    'confidence': '0.00013913899601902813'},
#   {'gameTime': '1 - 26:49',
#    'label': 'Goal',
#    'position': '1609464',
#    'half': '1',
#    'confidence': '0.00013182483962737024'},
#   {'gameTime': '1 - 11:9',
#    'label': 'Goal',
#    'position': '669266',
#    'half': '1',
#    'confidence': '0.0001260751741938293'},
#   {'gameTime': '1 - 11:24',
#    'label': 'Goal',
#    'position': '684347',
#    'half': '1',
#    'confidence': '0.00011371633445378393'},
#   {'gameTime': '1 - 42:29',
#    'label': 'Goal',
#    'position': '2549141',
#    'half': '1',
#    'confidence': '0.00011114363587694243'},
#   {'gameTime': '1 - 13:37',
#    'label': 'Goal',
#    'position': '817992',
#    'half': '1',
#    'confidence': '0.00011052050831494853'},
#   {'gameTime': '1 - 26:3',
#    'label': 'Goal',
#    'position': '1563182',
#    'half': '1',
#    'confidence': '0.00010869906691368669'},
#   {'gameTime': '1 - 3:10',
#    'label': 'Goal',
#    'position': '190327',
#    'half': '1',
#    'confidence': '0.00010562811075942591'},
#   {'gameTime': '1 - 9:7',
#    'label': 'Goal',
#    'position': '547581',
#    'half': '1',
#    'confidence': '0.00010300935537088662'},
#   {'gameTime': '1 - 27:47',
#    'label': 'Goal',
#    'position': '1667706',
#    'half': '1',
#    'confidence': '0.0001021096104523167'},
#   {'gameTime': '1 - 8:29',
#    'label': 'Goal',
#    'position': '509100',
#    'half': '1',
#    'confidence': '0.00010162343096453696'},
#   {'gameTime': '1 - 10:2',
#    'label': 'Goal',
#    'position': '602704',
#    'half': '1',
#    'confidence': '0.00010106679837917909'},
#   {'gameTime': '1 - 15:8',
#    'label': 'Goal',
#    'position': '908476',
#    'half': '1',
#    'confidence': '9.904018952511251e-05'},
#   {'gameTime': '1 - 29:33',
#    'label': 'Goal',
#    'position': '1773270',
#    'half': '1',
#    'confidence': '9.616952593205497e-05'},
#   {'gameTime': '1 - 39:52',
#    'label': 'Goal',
#    'position': '2392615',
#    'half': '1',
# ...
#    'label': 'Shots off target',
#    'position': '1242329',
#    'half': '1',
#    'confidence': '0.0017919904785230756'},
#   {'gameTime': '1 - 8:29',
#    'label': 'Shots off target',
#    'position': '509100',
#    'half': '1',
#    'confidence': '0.0017308968817815185'},
#   {'gameTime': '1 - 3:3',
#    'label': 'Shots off target',
#    'position': '183047',
#    'half': '1',
#    'confidence': '0.001659207628108561'},
#   {'gameTime': '1 - 24:11',
#    'label': 'Shots off target',
#    'position': '1451898',
#    'half': '1',
#    'confidence': '0.0016379341250285506'},
#   {'gameTime': '1 - 13:52',
#    'label': 'Shots off target',
#    'position': '832033',
#    'half': '1',
#    'confidence': '0.0015604529762640595'},
#   {'gameTime': '1 - 13:29',
#    'label': 'Shots off target',
#    'position': '809152',
#    'half': '1',
#    'confidence': '0.001554868184030056'},
#   {'gameTime': '1 - 25:53',
#    'label': 'Shots off target',
#    'position': '1553302',
#    'half': '1',
#    'confidence': '0.0015540317399427295'},
#   {'gameTime': '1 - 38:28',
#    'label': 'Shots off target',
#    'position': '2308892',
#    'half': '1',
#    'confidence': '0.0015514835249632597'},
#   {'gameTime': '1 - 27:27',
#    'label': 'Shots off target',
#    'position': '1647425',
#    'half': '1',
#    'confidence': '0.0015316192293539643'},
#   {'gameTime': '1 - 39:17',
#    'label': 'Shots off target',
#    'position': '2357774',
#    'half': '1',
#    'confidence': '0.0013910095440223813'},
#   {'gameTime': '1 - 16:1',
#    'label': 'Shots off target',
#    'position': '961518',
#    'half': '1',
#    'confidence': '0.001333844382315874'},
#   {'gameTime': '1 - 39:51',
#    'label': 'Shots off target',
#    'position': '2391575',
#    'half': '1',
#    'confidence': '0.0013081601355224848'},
#   {'gameTime': '1 - 12:10',
#    'label': 'Shots off target',
#    'position': '730629',
#    'half': '1',
#    'confidence': '0.0012807260500267148'},
#   {'gameTime': '1 - 12:43',
#    'label': 'Shots off target',
#    'position': '763390',
#    'half': '1',
#    'confidence': '0.0012426954926922917'},
#   {'gameTime': '1 - 36:39',
#    'label': 'Shots off target',
#    'position': '2199167',
#    'half': '1',
#    'confidence': '0.0010525144170969725'},
#   {'gameTime': '1 - 1:14',
#    'label': 'Shots off target',
#    'position': '74362',
#    'half': '1',
#    'confidence': '0.0010414797579869628'},
#   {'gameTime': '1 - 36:56',
#    'label': 'Shots off target',
#    'position': '2216848',
#    'half': '1',
#    'confidence': '0.001028487109579146'},
#   {'gameTime': '1 - 34:3',
#    'label': 'Shots off target',
#    'position': '2043681',
#    'half': '1',
#    'confidence': '0.0010138897923752666'},
#   {'gameTime': '1 - 30:28',
#    'label': 'Shots off target',
#    'position': '1828913',
#    'half': '1',
#    'confidence': '0.000990096596069634'},
#   {'gameTime': '1 - 8:4',
#    'label': 'Shots off target',
#    'position': '484659',
#    'half': '1',
#    'confidence': '0.0009872763184830546'},
#   {'gameTime': '1 - 29:50',
#    'label': 'Shots off target',
#    'position': '1790951',
#    'half': '1',
#    'confidence': '0.000978777534328401'},
#   {'gameTime': '1 - 4:0',
#    'label': 'Shots off target',
#    'position': '240769',
#    'half': '1',
#    'confidence': '0.0009108111844398081'},
#   {'gameTime': '1 - 6:49',
#    'label': 'Shots off target',
#    'position': '409256',
#    'half': '1',
#    'confidence': '0.0008758084732107818'},
#   {'gameTime': '1 - 18:51',
#    'label': 'Shots off target',
#    'position': '1131045',
#    'half': '1',
#    'confidence': '0.0008695757132954895'},
#   {'gameTime': '1 - 31:22',
#    'label': 'Shots off target',
#    'position': '1882995',
#    'half': '1',
#    'confidence': '0.0008564427844248712'},
#   {'gameTime': '1 - 36:1',
#    'label': 'Shots off target',
#    'position': '2161206',
#    'half': '1',
#    'confidence': '0.000845964124891907'},
#   {'gameTime': '1 - 14:37',
#    'label': 'Shots off target',
#    'position': '877275',
#    'half': '1',
#    'confidence': '0.000720368989277631'},
#   {'gameTime': '1 - 5:21',
#    'label': 'Shots off target',
#    'position': '321892',
#    'half': '1',
#    'confidence': '0.000717215589247644'},
#   {'gameTime': '1 - 38:43',
#    'label': 'Shots off target',
#    'position': '2323452',
#    'half': '1',
#    'confidence': '0.0007167116855271161'},
#   {'gameTime': '1 - 4:28',
#    'label': 'Shots off target',
#    'position': '268850',
#    'half': '1',
#    'confidence': '0.0007043156656436622'},
#   {'gameTime': '1 - 7:6',
#    'label': 'Shots off target',
#    'position': '426417',
#    'half': '1',
#    'confidence': '0.0006988478708080947'},
#   {'gameTime': '1 - 16:20',
#    'label': 'Shots off target',
#    'position': '980759',
#    'half': '1',
#    'confidence': '0.0006831337814219296'},
#   {'gameTime': '1 - 9:7',
#    'label': 'Shots off target',
#    'position': '547581',
#    'half': '1',
#    'confidence': '0.0006519936141557992'},
#   {'gameTime': '1 - 1:54',
#    'label': 'Shots off target',
#    'position': '114404',
#    'half': '1',
#    'confidence': '0.0006429814384318888'},
#   {'gameTime': '1 - 0:24',
#    'label': 'Shots off target',
#    'position': '24960',
#    'half': '1',
#    'confidence': '0.0006429079221561551'},
#   {'gameTime': '1 - 43:46',
#    'label': 'Shots off target',
#    'position': '2626625',
#    'half': '1',
#    'confidence': '0.0006416545948013663'},
#   {'gameTime': '1 - 20:6',
#    'label': 'Shots off target',
#    'position': '1206968',
#    'half': '1',
#    'confidence': '0.0006166996899992228'},
#   {'gameTime': '1 - 17:0',
#    'label': 'Shots off target',
#    'position': '1020800',
#    'half': '1',
#    'confidence': '0.0005952098872512579'},
#   {'gameTime': '1 - 23:0',
#    'label': 'Shots off target',
#    'position': '1380135',
#    'half': '1',
#    'confidence': '0.0005904931458644569'},
#   {'gameTime': '1 - 10:30',
#    'label': 'Shots off target',
#    'position': '630265',
#    'half': '1',
#    'confidence': '0.0005450786557048559'},
#   {'gameTime': '1 - 24:38',
#    'label': 'Shots off target',
#    'position': '1478419',
#    'half': '1',
#    'confidence': '0.0005405974225141108'},
#   {'gameTime': '1 - 28:22',
#    'label': 'Shots off target',
#    'position': '1702028',
#    'half': '1',
#    'confidence': '0.0005041143740527332'},
#   {'gameTime': '1 - 10:5',
#    'label': 'Shots off target',
#    'position': '605304',
#    'half': '1',
#    'confidence': '0.0005035822978243232'},
#   {'gameTime': '1 - 30:9',
#    'label': 'Shots off target',
#    'position': '1809152',
#    'half': '1',
#    'confidence': '0.0004809626843780279'},
#   {'gameTime': '1 - 37:11',
#    'label': 'Shots off target',
#    'position': '2231409',
#    'half': '1',
#    'confidence': '0.0004679793491959572'},
#   {'gameTime': '1 - 40:52',
#    'label': 'Shots off target',
#    'position': '2452938',
#    'half': '1',
#    'confidence': '0.00046739549725316465'},
#   {'gameTime': '1 - 19:7',
#    'label': 'Shots off target',
#    'position': '1147685',
#    'half': '1',
#    'confidence': '0.0004497823538258672'},
#   {'gameTime': '1 - 31:5',
#    'label': 'Shots off target',
#    'position': '1865314',
#    'half': '1',
#    'confidence': '0.00044816648005507886'},
#   {'gameTime': '1 - 33:17',
#    'label': 'Shots off target',
#    'position': '1997399',
#    'half': '1',
#    'confidence': '0.0004459525807760656'},
#   {'gameTime': '1 - 22:9',
#    'label': 'Shots off target',
#    'position': '1329173',
#    'half': '1',
#    'confidence': '0.00041225561290048063'},
#   {'gameTime': '1 - 41:51',
#    'label': 'Shots off target',
#    'position': '2511700',
#    'half': '1',
#    'confidence': '0.00041183611028827727'},
#   {'gameTime': '1 - 2:11',
#    'label': 'Shots off target',
#    'position': '131565',
#    'half': '1',
#    'confidence': '0.00039925420423969626'},
#   {'gameTime': '1 - 0:55',
#    'label': 'Shots off target',
#    'position': '55122',
#    'half': '1',
#    'confidence': '0.0003855795366689563'},
#   {'gameTime': '1 - 21:40',
#    'label': 'Shots off target',
#    'position': '1300572',
#    'half': '1',
#    'confidence': '0.0003830556233879179'},
#   {'gameTime': '1 - 34:56',
#    'label': 'Shots off target',
#    'position': '2096723',
#    'half': '1',
#    'confidence': '0.00036708300467580557'},
#   {'gameTime': '1 - 42:52',
#    'label': 'Shots off target',
#    'position': '2572542',
#    'half': '1',
#    'confidence': '0.00036028370959684253'},
#   {'gameTime': '1 - 11:1',
#    'label': 'Shots off target',
#    'position': '661466',
#    'half': '1',
#    'confidence': '0.00035861131618730724'},
#   {'gameTime': '1 - 19:49',
#    'label': 'Shots off target',
#    'position': '1189287',
#    'half': '1',
#    'confidence': '0.00033578777220100164'},
#   {'gameTime': '1 - 23:53',
#    'label': 'Shots off target',
#    'position': '1433177',
#    'half': '1',
#    'confidence': '0.00031297365785576403'},
#   {'gameTime': '1 - 44:32',
#    'label': 'Shots off target',
#    'position': '2672386',
#    'half': '1',
#    'confidence': '0.00031154623138718307'},
#   {'gameTime': '1 - 11:40',
#    'label': 'Shots off target',
#    'position': '700468',
#    'half': '1',
#    'confidence': '0.0002996009134221822'},
#   {'gameTime': '1 - 29:34',
#    'label': 'Shots off target',
#    'position': '1774310',
#    'half': '1',
#    'confidence': '0.00028831601957790554'},
#   {'gameTime': '1 - 3:22',
#    'label': 'Shots off target',
#    'position': '202808',
#    'half': '1',
#    'confidence': '0.0002553311933297664'},
#   {'gameTime': '1 - 15:20',
#    'label': 'Shots off target',
#    'position': '920956',
#    'half': '1',
#    'confidence': '0.00025468520470894873'},
#   {'gameTime': '1 - 14:51',
#    'label': 'Shots off target',
#    'position': '891835',
#    'half': '1',
#    'confidence': '0.00023909934679977596'},
#   {'gameTime': '1 - 18:28',
#    'label': 'Shots off target',
#    'position': '1108164',
#    'half': '1',
#    'confidence': '0.0002045621076831594'},
#   {'gameTime': '1 - 6:31',
#    'label': 'Shots off target',
#    'position': '391055',
#    'half': '1',
#    'confidence': '0.00019485493248794228'},
#   {'gameTime': '1 - 35:45',
#    'label': 'Shots off target',
#    'position': '2145605',
#    'half': '1',
#    'confidence': '0.00018301146337762475'},
#   {'gameTime': '1 - 27:48',
#    'label': 'Shots off target',
#    'position': '1668226',
#    'half': '1',
#    'confidence': '0.00018169646500609815'},
#   {'gameTime': '1 - 2:26',
#    'label': 'Shots off target',
#    'position': '146645',
#    'half': '1',
#    'confidence': '0.00017526243755128235'},
#   {'gameTime': '1 - 7:33',
#    'label': 'Shots off target',
#    'position': '453458',
#    'half': '1',
#    'confidence': '0.0001659691333770752'},
#   {'gameTime': '1 - 17:18',
#    'label': 'Shots off target',
#    'position': '1038481',
#    'half': '1',
#    'confidence': '0.00016460225742775947'},
#   {'gameTime': '1 - 39:2',
#    'label': 'Shots off target',
#    'position': '2342173',
#    'half': '1',
#    'confidence': '0.00014983040455263108'},
#   {'gameTime': '1 - 11:55',
#    'label': 'Shots off target',
#    'position': '715028',
#    'half': '1',
#    'confidence': '0.00014721274783369154'},
#   {'gameTime': '1 - 29:4',
#    'label': 'Shots off target',
#    'position': '1744149',
#    'half': '1',
#    'confidence': '0.0001448351686121896'},
#   {'gameTime': '1 - 32:56',
#    'label': 'Shots off target',
#    'position': '1976599',
#    'half': '1',
#    'confidence': '0.00013787453644908965'},
#   {'gameTime': '1 - 40:6',
#    'label': 'Shots off target',
#    'position': '2406136',
#    'half': '1',
#    'confidence': '0.00013238917745184153'},
#   {'gameTime': '1 - 26:11',
#    'label': 'Shots off target',
#    'position': '1571502',
#    'half': '1',
#    'confidence': '0.00012484440230764449'},
#   {'gameTime': '1 - 27:11',
#    'label': 'Shots off target',
#    'position': '1631825',
#    'half': '1',
#    'confidence': '0.0001185739747597836'},
#   {'gameTime': '1 - 23:37',
#    'label': 'Shots off target',
#    'position': '1417576',
#    'half': '1',
#    'confidence': '0.00011374842870282009'},
#   {'gameTime': '1 - 37:44',
#    'label': 'Shots off target',
#    'position': '2264170',
#    'half': '1',
#    'confidence': '9.1790861915797e-05'},
#   {'gameTime': '1 - 20:56',
#    'label': 'Shots off target',
#    'position': '1256890',
#    'half': '1',
#    'confidence': '6.821601709816605e-05'},
#   {'gameTime': '1 - 11:24',
#    'label': 'Clearance',
#    'position': '684867',
#    'half': '1',
#    'confidence': '0.9750975370407104'},
#   {'gameTime': '1 - 6:18',
#    'label': 'Clearance',
#    'position': '378055',
#    'half': '1',
#    'confidence': '0.9706430435180664'},
#   {'gameTime': '1 - 1:51',
#    'label': 'Clearance',
#    'position': '111284',
#    'half': '1',
#    'confidence': '0.8799745440483093'},
#   {'gameTime': '1 - 5:21',
#    'label': 'Clearance',
#    'position': '321892',
#    'half': '1',
#    'confidence': '0.46399787068367004'},
#   {'gameTime': '1 - 20:36',
#    'label': 'Clearance',
#    'position': '1236609',
#    'half': '1',
#    'confidence': '0.42479780316352844'},
#   {'gameTime': '1 - 38:32',
#    'label': 'Clearance',
#    'position': '2312532',
#    'half': '1',
#    'confidence': '0.4046156406402588'},
#   {'gameTime': '1 - 29:11',
#    'label': 'Clearance',
#    'position': '1751430',
#    'half': '1',
#    'confidence': '0.3016529977321625'},
#   {'gameTime': '1 - 39:30',
#    'label': 'Clearance',
#    'position': '2370254',
#    'half': '1',
#    'confidence': '0.23754319548606873'},
#   {'gameTime': '1 - 24:23',
#    'label': 'Clearance',
#    'position': '1463858',
#    'half': '1',
#    'confidence': '0.21078628301620483'},
#   {'gameTime': '1 - 34:51',
#    'label': 'Clearance',
#    'position': '2091003',
#    'half': '1',
#    'confidence': '0.21066686511039734'},
#   {'gameTime': '1 - 30:30',
#    'label': 'Clearance',
#    'position': '1830993',
#    'half': '1',
#    'confidence': '0.13228514790534973'},
#   {'gameTime': '1 - 36:36',
#    'label': 'Clearance',
#    'position': '2196047',
#    'half': '1',
#    'confidence': '0.12687426805496216'},
#   {'gameTime': '1 - 32:26',
#    'label': 'Clearance',
#    'position': '1946437',
#    'half': '1',
#    'confidence': '0.12113958597183228'},
#   {'gameTime': '1 - 28:16',
#    'label': 'Clearance',
#    'position': '1696307',
#    'half': '1',
#    'confidence': '0.11900512874126434'},
#   {'gameTime': '1 - 1:24',
#    'label': 'Clearance',
#    'position': '84243',
#    'half': '1',
#    'confidence': '0.09436103701591492'},
#   {'gameTime': '1 - 30:5',
#    'label': 'Clearance',
#    'position': '1805512',
#    'half': '1',
#    'confidence': '0.08777705579996109'},
#   {'gameTime': '1 - 37:50',
#    'label': 'Clearance',
#    'position': '2270930',
#    'half': '1',
#    'confidence': '0.08045782148838043'},
#   {'gameTime': '1 - 14:33',
#    'label': 'Clearance',
#    'position': '873114',
#    'half': '1',
#    'confidence': '0.06869011372327805'},
#   {'gameTime': '1 - 38:16',
#    'label': 'Clearance',
#    'position': '2296931',
#    'half': '1',
#    'confidence': '0.06468679755926132'},
#   {'gameTime': '1 - 0:4',
#    'label': 'Clearance',
#    'position': '4680',
#    'half': '1',
#    'confidence': '0.06449829787015915'},
#   {'gameTime': '1 - 23:33',
#    'label': 'Clearance',
#    'position': '1413416',
#    'half': '1',
#    'confidence': '0.06272400915622711'},
#   {'gameTime': '1 - 29:35',
#    'label': 'Clearance',
#    'position': '1775351',
#    'half': '1',
#    'confidence': '0.06232732534408569'},
#   {'gameTime': '1 - 25:51',
#    'label': 'Clearance',
#    'position': '1551222',
#    'half': '1',
#    'confidence': '0.050752900540828705'},
#   {'gameTime': '1 - 19:59',
#    'label': 'Clearance',
#    'position': '1199687',
#    'half': '1',
#    'confidence': '0.0488886795938015'},
#   {'gameTime': '1 - 28:38',
#    'label': 'Clearance',
#    'position': '1718668',
#    'half': '1',
#    'confidence': '0.04476385563611984'},
#   {'gameTime': '1 - 9:1',
#    'label': 'Clearance',
#    'position': '541341',
#    'half': '1',
#    'confidence': '0.04185491427779198'},
#   {'gameTime': '1 - 17:11',
#    'label': 'Clearance',
#    'position': '1031201',
#    'half': '1',
#    'confidence': '0.041681405156850815'},
#   {'gameTime': '1 - 21:48',
#    'label': 'Clearance',
#    'position': '1308372',
#    'half': '1',
#    'confidence': '0.03659975528717041'},
#   {'gameTime': '1 - 33:33',
#    'label': 'Clearance',
#    'position': '2013000',
#    'half': '1',
#    'confidence': '0.03462270274758339'},
#   {'gameTime': '1 - 40:46',
#    'label': 'Clearance',
#    'position': '2446177',
#    'half': '1',
#    'confidence': '0.0332154743373394'},
#   {'gameTime': '1 - 35:8',
#    'label': 'Clearance',
#    'position': '2108164',
#    'half': '1',
#    'confidence': '0.0300102811306715'},
#   ...]}
